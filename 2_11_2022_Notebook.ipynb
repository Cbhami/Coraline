# %% [markdown]
# <a href="https://colab.research.google.com/github/Cbhami/CoralineTest/blob/main/2_11_2022_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notes from 11 Feb 22

# %%
def greeting(name, department):
  print("Welcome, " + name)
  print("You are part of the " + department)

greeting("Cole", "S3 Section")
# Out:
# Welcome, Cole
# You are part of the S3 Section

# %%
'''
Do you think you can flesh out your own function? 
I think you can! Let’s give it a go. 

Flesh out the body of the print_seconds function 
so that it prints the total amount of seconds 
given the hours, minutes, and seconds function parameters. 
Remember that there are 3600 seconds in an hour and 
60 seconds in a minute.
'''

def print_seconds(hours, minutes, seconds):
    print(_____)
    
print_seconds(1,2,3)

# %%
def area_triangle(base, height):
    return base*height/2
area_a = area_triangle(5,4)
area_b = area_triangle(7,3)

sum = area_a + area_b
print(sum)
# Out:
# 20.5

# %%
def get_seconds(hours, minutes, seconds):
    return 3600*hours + 60*minutes + seconds

amount_a = get_seconds(2, 30, 0)
amount_b = get_seconds(0, 45, 15)
result = amount_a + amount_b

print(result)
# Out:
# 11715

# %%
#this isn't correct, minutes shouldn't exceed 60 
def convert_seconds(secondsa):
    hours = secondsa // 3600
    minutes = secondsa // 60
    remaining_seconds = secondsa - hours * 3600 - minutes * 60
    return hours, minutes, remaining_seconds

print(secondsa(3, 4, 15))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\coleb\OneDrive\Coraline\2_11_2022_Notebook.ipynb Cell 7' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/coleb/OneDrive/Coraline/2_11_2022_Notebook.ipynb#ch0000006?line=4'>5</a>     remaining_seconds = secondsa - hours * 3600 - minutes * 60
#       <a href='vscode-notebook-cell:/c%3A/Users/coleb/OneDrive/Coraline/2_11_2022_Notebook.ipynb#ch0000006?line=5'>6</a>     return hours, minutes, remaining_seconds
# ----> <a href='vscode-notebook-cell:/c%3A/Users/coleb/OneDrive/Coraline/2_11_2022_Notebook.ipynb#ch0000006?line=7'>8</a> print(secondsa(3, 4, 15))
#
# NameError: name 'secondsa' is not defined

# %%
name = "Cole"
number = len(name) * 3
print("Hello, " + name + '. Your lucky number is ' + str(number))
# Out:
# Hello, Cole. Your lucky number is 12

# %%
name = "Cosmo"
number = len(name) * 3
print("Hello, " + str(name) + ". Your lucky number is " + str(number))
# Out:
# Hello, Cosmo. Your lucky number is 15

# %%
june_days = 30
print("June has " +str(june_days) + " days.")
july_days = 31
print("July has " +str(july_days) + " days.")
# Out:
# June has 30 days.
# July has 31 days.

# %%
def month_days(month, days)
  31d = [January, Mar, May, July, August, October, December]
  30d = [April, June, September, November]
  28d = [February]
  29dly = [February]
  return

# %%
sqlClient = SQLQuery(....)
# Out:
#   Input In [2]
#     sqlClient = SQLQuery(....)
#                              ^
# SyntaxError: invalid syntax

# %%
sqlmagic = ibmcloudsql.SQLBuilder()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\coleb\OneDrive\Coraline\2_11_2022_Notebook.ipynb Cell 13' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/coleb/OneDrive/Coraline/2_11_2022_Notebook.ipynb#ch0000012?line=0'>1</a> sqlmagic = ibmcloudsql.SQLBuilder()
#
# NameError: name 'ibmcloudsql' is not defined
