# %% [markdown]
# <a href="https://colab.research.google.com/github/Cbhami/Coraline/blob/master/Cole's_Resume.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Personal Information

# %% [markdown]
# Cole B. Hamilton
#
# Senior Data Analyst
#
# San Antonio, TX
#
# 910-824-1624
#
# cole.b.hamilton@gmail.com
#
# www.linkedin.com/in/hamiltoncole/

# %% [markdown]
# Self-driven, results-oriented professional with excellent writing skills who has extensive experience managing recruitment, training, and agile team building in United States Army. Flexible and enthusiastic professional used to a fast-paced environment where solving problems is crucial. Well-versed in the use of statistical analysis and data analysis to identify underperforming areas and manage courses to increase junior members. Proven record in data analysis cleaning, visualizing, automating, and presenting complex datasets for senior managers. Mastery of data analytics reporting through data programming languages, quantitative analysis, and dashboard creations. Responsible for data solutions, data security, and protected information data governance.

# %% [markdown]
# ## *Skills*
#
# ---

# %% [markdown]
# Master in Agile Project Management, Human Resources, Leadership, and Staff Development.
#
# Highly developed skills in data cleaning, data visualization, and dynamic report construction.
#
# Experienced in content design, virtual teaching, and development. Expert in MS Teams.
#
# Proficient in R, Python, M, and DAX programming languages.

# %% [markdown]
# ## *Professional Experience*
#
# ---

# %% [markdown]
# ### ***Senior Data Analyst - San Antonio, TX					July 2020 - Present***
#
# ---
#
#
#
# Senior Data Analyst for the largest of five brigades within the United States Army Recruiting Command. Responsible for architecting data analytics models, reports, and dashboards for the command team. Design and facilitate the use of Power Bi, r Studio, and Microsoft Excel analytical tools. Executed Power Query scripts and developed tools for a team of 2,400 Soldiers to utilize.
#
# Manages millions of rows of code using SQL and database connections to provide data analytics to senior Army leaders. Trained and developed a staff of operations analysts to transform the brigade headquarters in advanced Microsoft Excel and Power Bi report development.
#
# Established the 8-page Mission Report that was updated and published daily with code pulled from Open Database Connectivity through R, SQL, M, and DAX scripting languages. Focused on quantitative and statistical data analysis with a data focused technical expertise. Enabled senior leaders to make data driven decisions through technical writing and strategic business analysis. Collaborated with regional developers and data engineers to produce data road maps to develop successful business intelligence reports and products.

# %% [markdown]
# ## *Leadership and Training Management Experience*
#
#
# ---

# %% [markdown]
# ### ***District Recruiting Manager							May 2018 - July 2020***
#
# ---
#
#
#
# Served as the Senior Enlisted Advisor facilitating one of three companies covering all enlisted accessions and officer commissioning in Iowa. Advised the commander on briefings, public engagements, marketing opportunities, and onboarding processes for a team of 30 Soldiers. Upskilled over 30 senior army leaders in business solutions and business decision making through managing annual evaluations, awards and commendations, counseling, and mentoring.
#
# Generated business insights through data exploration and business intelligence methods. Developed campaign strategies and used technical skills to interpret data for the commander. Conducted management consulting for six other companies within the region while balancing simultaneous projects and meeting business demands.
#
# Conceptualized, analyzed data, and evaluated lifecycle-recruiting operations to support a company for combined annual enlistment objectives of over 210 hires, new Soldiers in a unit consisting of over 30 hiring counselors and subordinate office managers, station commanders among four different recruiting offices. Focused product marketing and strategic initiatives to achieve success.

# %% [markdown]
# ### ***Senior Noncommissioned Officer					October 2004 - May 2018***
#
# ---
#
#
#
# Senior manager in human resources with a focus in technical teams and process improvements in Army recruiting methods. Flexible in a rapidly changing environment with efficiencies in tactical planning and managing technical teams. User friendly leader with over 12 years of human resource and technical recruiting expertise. Proven ability to work in a team environment and rise as a leader amongst peers.
#
# Delivered service autonomously as an overseas recruiter assigned to Heidelberg MEPS covering three continents. Interacted with NATO, UN, and DOD component installations along with US Embassies across the world. Motivated a small geographically dispersed team to collaborate and problem solve to achieve business requirements.
#
# Performed as a Paratrooper and Engineer with the 82nd Airborne Division  Ft Bragg, NC. Served in both Operation Enduring and Operation Iraqi Freedom. Formed and managed teams with diverse people through effective communication, conflict management, and interpersonal skills. Displayed skills in leadership and people management while planning special projects.

# %% [markdown]
# ## *Education*

# %% [markdown]
# -
# Graduate Certificate in Data Science (Est May 2023)
#
# University of Louisville, KY
#
#
#
#
# -
# Doctor of Philosophy, Human Resource Management (GPA 3.77)
#
# Northcentral University, La Jolla, CA
#
# -
# Master of Arts, Leadership and Management (GPA 3.5)
#
# Liberty University, Lynchburg, VA
#
#
# -
# Master of Business Administration in Finance (GPA 3.82)
#
# Post University, Waterbury, CT

# %% [markdown]
# ## *Certifications*

# %% [markdown]
# SHRM-CP Society for Human Resource Management – Senior Certified Professional
#
# PMI-DASM Disciplined Agile Scrum Master
#
# Certified Agile Professional
#
# Lean Six Sigma Master Black Belt
#
# Cornell Data Science Certificate - R and R Studio
#
# USC Intermediate Data Analytics Certificate - Microsoft Excel and Power Bi
#
# Google Data Analytics Certifications - Google Sheets and R
#
# IBM Data Analyst Certificate - Python
#
# DA-100 Microsoft Power Bi Data Analyst Certification
#
# Excel Architect Certification

# %% [markdown]
# ###Certification Tracker Link

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Cbhami/Coraline/master/Certification%20Tracker%20Public.csv', header = [1])
df1 = df[1:37]
df1['FINISH DATE'] = pd.to_datetime(df['FINISH DATE']).dt.date
df1.sort_values(by='FINISH DATE', inplace = True, ascending=True)
df1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                           My Certifications                    Organization  \
# 12                                  SHRM-CP                            SHRM
# 13                         365 Fundamentals                      Microsoft
# 14                      Teams Administrator                      Microsoft
# 15                Lean Six Sigma Green Belt                            SSGI
# 16         Lean Six Sigma Master Black Belt                            SSGI
# 17             Power Platforms Fundamentals                      Microsoft
# 18              Microsoft Certified Trainer                      Microsoft
# 19           Excel Apprentice Certification                       eLearning
# 20                  Azure Data Fundamentals                      Microsoft
# 21          Microsoft Power Bi Data Analyst                      Microsoft
# 22            Excel Associate Certification                       eLearning
# 23                    Google Data Analytics                          Google
# 24                 Data Science Certificate              Cornell University
# 25                         IBM Data Analyst                             IBM
# 26                                 SHMR-SCP                            SHRM
# 27           Excel Specialist Certification                       eLearning
# 28                 Excel Core Certification                       eLearning
# 29            Excel Developer Certification                       eLearning
# 30            Excel Architect Certification                       eLearning
# 31                                 PMI-DASM                             PMI
# 32                          Lean Specialist                           AIGPE
# 33                              Lean Expert                           AIGPE
# 34             Agile Certified Professional                            SSGI
# 35  Intermediate Data Analytics Certificate    University of South Carolina
# 36                       Azure Fundamentals                      Microsoft
# 1                                   PMI-ACP                             PMI
# 2                                 PMI-DASSM                             PMI
# 3                                      SAFe  American Technology Consulting
# 4                                  PMI-CAPM                             PMI
# 5                                   PMI-PMP                             PMI
# 6                  Data Science Certificate        University of Louisville
# 7       IBM Data Analytics with Excel and R                             IBM
# 8          Google IT Automation with Python                          Google
# 9                Excel Master Certification                       eLearning
# 10                Google Project Management                          Google
# 11                         IBM Data Science                             IBM
#
#                Concentration                     Skill 1          Skill 2  \
# 12           Human Resources             Human Resources              NaN
# 13          Microsoft Office            Microsoft Office              NaN
# 14            Microsoft Teams            Microsoft Teams              NaN
# 15             Lean Six Sigma             Lean Six Sigma              NaN
# 16             Lean Six Sigma             Lean Six Sigma              NaN
# 17  Microsoft Power Platforms  Microsoft Power Platforms              NaN
# 18                   Training                   Training              NaN
# 19            Microsoft Excel            Microsoft Excel              NaN
# 20                      Azure   Microsoft Data Platforms              NaN
# 21              Data Analysis                   Power Bi              NaN
# 22            Microsoft Excel            Microsoft Excel              NaN
# 23              Data Analysis                          R    Google Sheets
# 24              Data Analysis                          R              NaN
# 25              Data Analysis                     Python              NaN
# 26           Human Resources             Human Resources              NaN
# 27            Microsoft Excel            Microsoft Excel              NaN
# 28            Microsoft Excel            Microsoft Excel              NaN
# 29            Microsoft Excel            Microsoft Excel              NaN
# 30            Microsoft Excel            Microsoft Excel              NaN
# 31                      Agile                      Agile              NaN
# 32             Lean Six Sigma             Lean Six Sigma              NaN
# 33             Lean Six Sigma             Lean Six Sigma              NaN
# 34                      Agile                      Agile              NaN
# 35              Data Analysis                   Power Bi  Microsoft Excel
# 36                      Azure   Microsoft Data Platforms              NaN
# 1                       Agile                      Agile              NaN
# 2                       Agile                      Agile              NaN
# 3                       Agile                      Agile              NaN
# 4          Project Management         Project Management              NaN
# 5          Project Management         Project Management              NaN
# 6               Data Analysis                     Python              NaN
# 7               Data Analysis                          R  Microsoft Excel
# 8               Data Analysis                     Python              NaN
# 9             Microsoft Excel            Microsoft Excel              NaN
# 10         Project Management         Project Management              NaN
# 11              Data Analysis                     Python  Microsoft Excel
#
#                                      Organization URL  \
# 12                                  https://shrm.org/
# 13            https://docs.microsoft.com/en-us/learn/
# 14            https://docs.microsoft.com/en-us/learn/
# 15         https://www.6sigmacertificationonline.com/
# 16         https://www.6sigmacertificationonline.com/
# 17            https://docs.microsoft.com/en-us/learn/
# 18            https://docs.microsoft.com/en-us/learn/
# 19                         https://elearning.iact.ie/
# 20            https://docs.microsoft.com/en-us/learn/
# 21            https://docs.microsoft.com/en-us/learn/
# 22                         https://elearning.iact.ie/
# 23                          https://www.coursera.org/
# 24                      https://ecornell.cornell.edu/
# 25                          https://www.coursera.org/
# 26                                  https://shrm.org/
# 27                         https://elearning.iact.ie/
# 28                         https://elearning.iact.ie/
# 29                         https://elearning.iact.ie/
# 30                         https://elearning.iact.ie/
# 31                               https://www.pmi.org/
# 32  https://ibmcsr.udemy.com/course/lean-managemen...
# 33  https://ibmcsr.udemy.com/course/lean-managemen...
# 34         https://www.6sigmacertificationonline.com/
# 35  https://armyeitaas.sharepoint-mil.us/teams/FCS...
# 36            https://docs.microsoft.com/en-us/learn/
# 1                                https://www.pmi.org/
# 2                                https://www.pmi.org/
# 3                       https://www.atc-training.net/
# 4                                https://www.pmi.org/
# 5                                https://www.pmi.org/
# 6                 https://engineering.louisville.edu/
# 7   https://www.coursera.org/programs/casy-on-dema...
# 8   https://www.coursera.org/learn/python-operatin...
# 9                          https://elearning.iact.ie/
# 10  https://www.coursera.org/learn/applying-projec...
# 11  https://www.coursera.org/learn/machine-learnin...
#
#                         Type  START DATE FINISH DATE FINISH Date Goal  ...  \
# 12             Certification    3/1/2021  2021-06-28              NaN  ...
# 13             Certification    8/1/2021  2021-08-21              NaN  ...
# 14             Certification   7/30/2021  2021-09-13              NaN  ...
# 15             Certification    8/1/2021  2021-10-03              NaN  ...
# 16             Certification    8/1/2021  2021-10-03              NaN  ...
# 17             Certification   9/27/2021  2021-10-04              NaN  ...
# 18             Certification   10/7/2021  2021-10-07              NaN  ...
# 19             Certification    8/1/2021  2021-10-17              NaN  ...
# 20             Certification  10/11/2021  2021-10-18              NaN  ...
# 21             Certification    9/9/2021  2021-10-24              NaN  ...
# 22             Certification    8/1/2021  2021-10-27              NaN  ...
# 23  Professional Certificate   10/1/2021  2021-12-29              NaN  ...
# 24  Professional Certificate   11/1/2021  2022-01-10              NaN  ...
# 25  Professional Certificate   10/1/2021  2022-01-16              NaN  ...
# 26             Certification   1/16/2022  2022-01-31              NaN  ...
# 27             Certification    8/1/2021  2022-02-06              NaN  ...
# 28             Certification    8/1/2021  2022-02-06              NaN  ...
# 29             Certification    8/1/2021  2022-02-06              NaN  ...
# 30             Certification    8/1/2021  2022-02-06              NaN  ...
# 31             Certification   1/10/2022  2022-02-19              NaN  ...
# 32             Certification   2/21/2022  2022-02-22              NaN  ...
# 33             Certification   2/22/2022  2022-02-23              NaN  ...
# 34             Certification    2/1/2022  2022-03-14              NaN  ...
# 35  Professional Certificate   3/14/2022  2022-03-25        3/25/2022  ...
# 36             Certification   3/26/2022  2022-03-27        3/27/2022  ...
# 1              Certification   12/1/2021         NaT              NaN  ...
# 2              Certification   2/26/2022         NaT         5/1/2022  ...
# 3              Certification   2/26/2022         NaT        4/15/2022  ...
# 4              Certification    1/1/2022         NaT        11/1/2022  ...
# 5              Certification   12/1/2021         NaT        12/1/2022  ...
# 6       Academic Certificate   1/10/2022         NaT         5/1/2023  ...
# 7   Professional Certificate  10/10/2022         NaT        12/1/2022  ...
# 8   Professional Certificate   12/1/2021         NaT         6/1/2022  ...
# 9              Certification    8/1/2021         NaT         8/1/2022  ...
# 10  Professional Certificate   11/1/2021         NaT         4/1/2022  ...
# 11  Professional Certificate   10/1/2022         NaT         7/1/2022  ...
#
#    Exam/Training Cost Exam Attempts  Total Costs    Funding Source  \
# 12         $4,000.00            1.0   $4,000.00   Proponent Funded
# 13            $99.00            1.0      $99.00                ESI
# 14           $160.00            3.0     $480.00                ESI
# 15           $199.00            1.0     $199.00        ArmyIgnited
# 16           $500.00            1.0     $500.00        ArmyIgnited
# 17            $99.00            1.0      $99.00                ESI
# 18           $800.00            1.0     $800.00                ESI
# 19              $-              1.0        $-                 Self
# 20            $99.00            1.0      $99.00                ESI
# 21           $160.00            3.0     $480.00                ESI
# 22              $-              1.0        $-                 Self
# 23           $300.00            1.0     $300.00            Vetjobs
# 24         $1,500.00            1.0   $1,500.00               Unit
# 25           $300.00            1.0     $300.00            Vetjobs
# 26           $300.00            1.0     $300.00        ArmyIgnited
# 27              $-              1.0        $-                 Self
# 28              $-              1.0        $-                 Self
# 29              $-              1.0        $-                 Self
# 30              $-              1.0        $-                 Self
# 31           $270.00            1.0     $270.00        ArmyIgnited
# 32           $100.00            1.0     $100.00            Vetjobs
# 33           $100.00            1.0     $100.00            Vetjobs
# 34           $270.00            1.0     $270.00        ArmyIgnited
# 35         $6,000.00            1.0   $6,000.00   Proponent Funded
# 36            $99.00            1.0      $99.00                ESI
# 1          $2,000.00            1.0   $2,000.00        ArmyIgnited
# 2            $270.00            1.0     $270.00        ArmyIgnited
# 3            $500.00            1.0     $500.00        ArmyIgnited
# 4            $300.00            1.0     $300.00        ArmyIgnited
# 5            $300.00            1.0     $300.00        ArmyIgnited
# 6            $750.00            2.0   $1,500.00        ArmyIgnited
# 7            $300.00            1.0     $300.00            Vetjobs
# 8            $300.00            1.0     $300.00            Vetjobs
# 9             $49.00            1.0      $49.00               Self
# 10           $300.00            1.0     $300.00            Vetjobs
# 11           $300.00            1.0     $300.00            Vetjobs
#
#     Additional Study Expenses   \
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29                         NaN
# 30                         NaN
# 31                         NaN
# 32                         NaN
# 33                         NaN
# 34                         NaN
# 35                       $-
# 36                         NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
#
#                                   Best Study Resource Personal Expenses   \
# 12  https://learnhrm.partnerrc.com/am/@@login?came...                NaN
# 13                                                NaN                NaN
# 14                                                NaN                NaN
# 15                                                NaN                NaN
# 16                                                NaN                NaN
# 17                                                NaN                NaN
# 18                                                NaN                NaN
# 19                                                NaN                NaN
# 20                                                NaN                NaN
# 21                                                NaN                NaN
# 22                                                NaN                NaN
# 23                                                NaN                NaN
# 24                                                NaN                NaN
# 25                                                NaN                NaN
# 26                                                NaN                NaN
# 27                                                NaN                NaN
# 28                                                NaN                NaN
# 29                                                NaN                NaN
# 30                                                NaN                NaN
# 31                                                NaN                NaN
# 32                                                NaN                NaN
# 33                                                NaN                NaN
# 34                                                NaN                NaN
# 35                                                NaN                NaN
# 36                                                NaN                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4                                                 NaN                NaN
# 5                                                 NaN                NaN
# 6                                                 NaN                NaN
# 7                                                 NaN                NaN
# 8                                                 NaN                NaN
# 9                                                 NaN                NaN
# 10                                                NaN                NaN
# 11                                                NaN                NaN
#
#                                   NOTES Additional Study Resource  \
# 12                                  NaN                       NaN
# 13                                  NaN                       NaN
# 14                                  NaN                       NaN
# 15                                  NaN                       NaN
# 16                                  NaN                       NaN
# 17                                  NaN                       NaN
# 18                                  NaN                       NaN
# 19                                  NaN                       NaN
# 20                                  NaN                       NaN
# 21                                  NaN                       NaN
# 22                                  NaN                       NaN
# 23                                  NaN                       NaN
# 24                                  NaN                       NaN
# 25                                  NaN                       NaN
# 26                                  NaN                       NaN
# 27                                  NaN                       NaN
# 28                                  NaN                       NaN
# 29                                  NaN                       NaN
# 30                                  NaN                       NaN
# 31                                  NaN                       NaN
# 32                                  NaN                       NaN
# 33                                  NaN                       NaN
# 34      Pending funding approval 2/1/22                       NaN
# 35       Moved to virtual due to budget                       NaN
# 36                                  NaN                       NaN
# 1                                   NaN                       NaN
# 2     ArmyIgnited Approval Pending 2/26                       NaN
# 3     ArmyIgnited Approval Pending 2/26                       NaN
# 4                                   NaN                       NaN
# 5   Funding approved. Ready to schedule                       NaN
# 6                                   NaN                       NaN
# 7                                   NaN                       NaN
# 8                                   NaN                       NaN
# 9                 Pending final project                       NaN
# 10                                  NaN                       NaN
# 11                                  NaN                       NaN
#
#                   Additional Study Resource2
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                                       NaN
# 30                                       NaN
# 31                                       NaN
# 32                                       NaN
# 33                                       NaN
# 34                                       NaN
# 35                                       NaN
# 36                                       NaN
# 1   https://www.onlinepmti.com/ACP/home#\n\n
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
#
# [36 rows x 24 columns]

# %%
df1 = df1.astype(str) #convert back to string format to remove date.time and just keep the date
Certlist = [] #create my empty list
Certdate = [] #create my empty list
for a in df1['My Certifications']:
  Certlist.append(a)
for b in df1['FINISH DATE']:
  Certdate.append(b)

Cert_dict = dict(zip(Certlist, Certdate)) #Here is my dictionary of certifications

Cert_dict.get('PMI-DASM')
# Out:
# '2022-02-19'
