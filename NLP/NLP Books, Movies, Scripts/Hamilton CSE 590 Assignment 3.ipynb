# %% [markdown]
# ### Data/Package Load

# %% [markdown]
# ### ***Part 1:**<br> Select and download three texts of your choosing that represent different media or writing formats (for example, you could choose i. a novel, movie script, and play script or ii. a short story, poem, and novel, etc.)
# **Make sure you briefly descibe your documents and explain the difference between them in a paragraph.**

# %%
#The first thing we need to do is import the packages needed for the entire assignment

import textblob as tb
import numpy as np
import pandas as pd
import nltk as nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from pathlib import Path
from textblob import TextBlob
from operator import itemgetter
from pathlib import Path
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\coleb\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Text 1: Great Gatsby book txt file
# Text 2: Monty Python and the Holy Grail movie script txt file
# Text 3: The Adventures of Sherlock Holmes short story txt file

# %%
txt1 = open("Monty Python and the Holy Grail.txt", "r", encoding='utf8') #I will assign txt 1 as my movie
txt2 = open('Great Gatsby.txt', 'r', encoding='utf8') #I will assign txt.read_text()  #Txt 2 will be my book
txt3 = open("The Adventures of Sherlock Holmes.txt", "r", encoding='utf8') #txt 3 will be my short stories

HolyGrailScript = txt1.read() #I need to read in my txt
GatsbyBook = txt2.read()
HolmesStory = txt3.read()

# %%
monty = TextBlob(HolyGrailScript) #I will pass my movie, book, and story through the TextBlob function
gatsby = TextBlob(GatsbyBook)
holmes = TextBlob(HolmesStory)
monty.word_counts #I will pass my movie, book, and story through the the word_counts dictionary
gatsby.word_counts #This will count the word frequencies
holmes.word_counts
# Out:
# defaultdict(int,
#             {'\ufeffproject': 1,
#              'gutenberg': 32,
#              's': 345,
#              'the': 5807,
#              'adventures': 11,
#              'of': 2777,
#              'sherlock': 102,
#              'holmes': 467,
#              'by': 367,
#              'arthur': 24,
#              'conan': 4,
#              'doyle': 4,
#              'this': 535,
#              'ebook': 10,
#              'is': 1153,
#              'for': 752,
#              'use': 44,
#              'anyone': 29,
#              'anywhere': 4,
#              'at': 783,
#              'no': 400,
#              'cost': 6,
#              'and': 3080,
#              'with': 877,
#              'almost': 20,
#              'restrictions': 2,
#              'whatsoever': 2,
#              'you': 1568,
#              'may': 212,
#              'copy': 14,
#              'it': 1749,
#              'give': 64,
#              'away': 109,
#              'or': 276,
#              're-use': 2,
#              'under': 48,
#              'terms': 24,
#              'project': 88,
#              'license': 17,
#              'included': 4,
#              'online': 4,
#              'www.gutenberg.net': 4,
#              'title': 3,
#              'author': 1,
#              'posting': 1,
#              'date': 11,
#              'april': 3,
#              '18': 1,
#              '2011': 1,
#              '1661': 1,
#              'first': 87,
#              'posted': 9,
#              'november': 1,
#              '29': 1,
#              '2002': 1,
#              'language': 2,
#              'english': 10,
#              'start': 16,
#              'produced': 5,
#              'an': 338,
#              'anonymous': 2,
#              'volunteer': 3,
#              'jose': 2,
#              'menendez': 2,
#              'sir': 79,
#              'i': 3035,
#              'a': 2698,
#              'scandal': 13,
#              'in': 1820,
#              'bohemia': 12,
#              'ii': 3,
#              'red-headed': 20,
#              'league': 17,
#              'iii': 3,
#              'case': 110,
#              'identity': 4,
#              'iv': 2,
#              'boscombe': 16,
#              'valley': 7,
#              'mystery': 22,
#              'v': 2,
#              'five': 36,
#              'orange': 11,
#              'pips': 12,
#              'vi': 2,
#              'man': 303,
#              'twisted': 10,
#              'lip': 12,
#              'vii': 2,
#              'adventure': 25,
#              'blue': 24,
#              'carbuncle': 7,
#              'viii': 2,
#              'speckled': 5,
#              'band': 15,
#              'ix': 2,
#              'engineer': 9,
#              'thumb': 16,
#              'x': 2,
#              'noble': 14,
#              'bachelor': 8,
#              'xi': 2,
#              'beryl': 4,
#              'coronet': 28,
#              'xii': 2,
#              'copper': 13,
#              'beeches': 12,
#              'to': 2764,
#              'she': 426,
#              'always': 58,
#              'woman': 68,
#              'have': 929,
#              'seldom': 6,
#              'heard': 113,
#              'him': 434,
#              'mention': 2,
#              'her': 430,
#              'any': 165,
#              'other': 161,
#              'name': 63,
#              'his': 1159,
#              'eyes': 87,
#              'eclipses': 1,
#              'predominates': 1,
#              'whole': 45,
#              'sex': 1,
#              'was': 1413,
#              'not': 712,
#              'that': 1766,
#              'he': 1485,
#              'felt': 32,
#              'emotion': 5,
#              'akin': 3,
#              'love': 18,
#              'irene': 17,
#              'adler': 16,
#              'all': 405,
#              'emotions': 1,
#              'one': 376,
#              'particularly': 7,
#              'were': 349,
#              'abhorrent': 1,
#              'cold': 21,
#              'precise': 3,
#              'but': 656,
#              'admirably': 4,
#              'balanced': 1,
#              'mind': 58,
#              'take': 79,
#              'most': 92,
#              'perfect': 7,
#              'reasoning': 11,
#              'observing': 4,
#              'machine': 16,
#              'world': 14,
#              'has': 286,
#              'seen': 72,
#              'as': 862,
#              'lover': 7,
#              'would': 333,
#              'placed': 19,
#              'himself': 73,
#              'false': 4,
#              'position': 22,
#              'never': 108,
#              'spoke': 27,
#              'softer': 1,
#              'passions': 1,
#              'save': 37,
#              'gibe': 1,
#              'sneer': 5,
#              'they': 202,
#              'admirable': 3,
#              'things': 29,
#              'observer': 4,
#              'excellent': 19,
#              'drawing': 6,
#              'veil': 8,
#              'from': 512,
#              'men': 39,
#              'motives': 3,
#              'actions': 4,
#              'trained': 4,
#              'reasoner': 6,
#              'admit': 2,
#              'such': 118,
#              'intrusions': 1,
#              'into': 275,
#              'own': 101,
#              'delicate': 7,
#              'finely': 1,
#              'adjusted': 2,
#              'temperament': 1,
#              'introduce': 4,
#              'distracting': 1,
#              'factor': 3,
#              'which': 778,
#              'might': 126,
#              'throw': 11,
#              'doubt': 64,
#              'upon': 467,
#              'mental': 1,
#              'results': 12,
#              'grit': 1,
#              'sensitive': 1,
#              'instrument': 2,
#              'crack': 3,
#              'high-power': 1,
#              'lenses': 1,
#              'be': 646,
#              'more': 175,
#              'disturbing': 1,
#              'than': 160,
#              'strong': 33,
#              'nature': 24,
#              'yet': 88,
#              'there': 516,
#              'late': 28,
#              'dubious': 1,
#              'questionable': 2,
#              'memory': 10,
#              'had': 833,
#              'little': 269,
#              'lately': 7,
#              'my': 1007,
#              'marriage': 26,
#              'drifted': 2,
#              'us': 184,
#              'each': 33,
#              'complete': 12,
#              'happiness': 3,
#              'home-centred': 1,
#              'interests': 4,
#              'rise': 5,
#              'up': 304,
#              'around': 3,
#              'who': 274,
#              'finds': 4,
#              'master': 11,
#              'establishment': 1,
#              'sufficient': 6,
#              'absorb': 1,
#              'attention': 24,
#              'while': 67,
#              'loathed': 1,
#              'every': 81,
#              'form': 13,
#              'society': 15,
#              'bohemian': 4,
#              'soul': 10,
#              'remained': 18,
#              'our': 212,
#              'lodgings': 8,
#              'baker': 42,
#              'street': 83,
#              'buried': 6,
#              'among': 35,
#              'old': 70,
#              'books': 9,
#              'alternating': 1,
#              'week': 27,
#              'between': 60,
#              'cocaine': 3,
#              'ambition': 1,
#              'drowsiness': 1,
#              'drug': 4,
#              'fierce': 6,
#              'energy': 7,
#              'keen': 11,
#              'still': 80,
#              'ever': 70,
#              'deeply': 12,
#              'attracted': 5,
#              'study': 10,
#              'crime': 32,
#              'occupied': 1,
#              'immense': 10,
#              'faculties': 2,
#              'extraordinary': 19,
#              'powers': 6,
#              'observation': 6,
#              'following': 15,
#              'out': 319,
#              'those': 67,
#              'clues': 3,
#              'clearing': 8,
#              'mysteries': 3,
#              'been': 393,
#              'abandoned': 3,
#              'hopeless': 2,
#              'official': 14,
#              'police': 43,
#              'time': 151,
#              'some': 245,
#              'vague': 10,
#              'account': 20,
#              'doings': 2,
#              'summons': 2,
#              'odessa': 1,
#              'trepoff': 1,
#              'murder': 7,
#              'singular': 33,
#              'tragedy': 6,
#              'atkinson': 1,
#              'brothers': 1,
#              'trincomalee': 1,
#              'finally': 19,
#              'mission': 7,
#              'accomplished': 2,
#              'so': 449,
#              'delicately': 1,
#              'successfully': 1,
#              'reigning': 3,
#              'family': 30,
#              'holland': 2,
#              'beyond': 11,
#              'these': 83,
#              'signs': 13,
#              'activity': 1,
#              'however': 108,
#              'merely': 10,
#              'shared': 2,
#              'readers': 1,
#              'daily': 3,
#              'press': 10,
#              'knew': 57,
#              'former': 3,
#              'friend': 78,
#              'companion': 34,
#              'night': 81,
#              'on': 391,
#              'twentieth': 2,
#              'march': 6,
#              '1888': 1,
#              'returning': 11,
#              'journey': 9,
#              'patient': 8,
#              'now': 234,
#              'returned': 36,
#              'civil': 3,
#              'practice': 12,
#              'when': 323,
#              'way': 116,
#              'led': 25,
#              'me': 635,
#              'through': 93,
#              'passed': 41,
#              'well-remembered': 1,
#              'door': 141,
#              'must': 171,
#              'associated': 12,
#              'wooing': 2,
#              'dark': 37,
#              'incidents': 5,
#              'scarlet': 3,
#              'seized': 10,
#              'desire': 6,
#              'see': 232,
#              'again': 69,
#              'know': 171,
#              'how': 145,
#              'employing': 2,
#              'rooms': 27,
#              'brilliantly': 2,
#              'lit': 13,
#              'even': 72,
#              'looked': 51,
#              'saw': 89,
#              'tall': 12,
#              'spare': 8,
#              'figure': 19,
#              'pass': 14,
#              'twice': 16,
#              'silhouette': 1,
#              'against': 53,
#              'blind': 4,
#              'pacing': 3,
#              'room': 134,
#              'swiftly': 14,
#              'eagerly': 4,
#              'head': 67,
#              'sunk': 9,
#              'chest': 6,
#              'hands': 73,
#              'clasped': 1,
#              'behind': 50,
#              'mood': 3,
#              'habit': 8,
#              'attitude': 2,
#              'manner': 28,
#              'told': 50,
#              'their': 97,
#              'story': 34,
#              'work': 87,
#              'risen': 4,
#              'drug-created': 1,
#              'dreams': 2,
#              'hot': 9,
#              'scent': 6,
#              'new': 33,
#              'problem': 21,
#              'rang': 4,
#              'bell': 14,
#              'shown': 20,
#              'chamber': 16,
#              'formerly': 4,
#              'part': 36,
#              'effusive': 1,
#              'glad': 18,
#              'think': 174,
#              'hardly': 50,
#              'word': 41,
#              'spoken': 12,
#              'kindly': 16,
#              'eye': 24,
#              'waved': 4,
#              'armchair': 15,
#              'threw': 29,
#              'across': 37,
#              'cigars': 5,
#              'indicated': 6,
#              'spirit': 1,
#              'gasogene': 1,
#              'corner': 32,
#              'then': 367,
#              'stood': 35,
#              'before': 165,
#              'fire': 44,
#              'over': 177,
#              'introspective': 3,
#              'fashion': 20,
#              'wedlock': 1,
#              'suits': 2,
#              'remarked': 64,
#              'watson': 81,
#              'put': 69,
#              'seven': 28,
#              'half': 39,
#              'pounds': 42,
#              'since': 39,
#              'answered': 56,
#              'indeed': 62,
#              'should': 213,
#              'thought': 77,
#              'just': 126,
#              'trifle': 4,
#              'fancy': 15,
#              'observe': 19,
#              'did': 166,
#              'tell': 98,
#              'intended': 1,
#              'go': 99,
#              'harness': 2,
#              'do': 330,
#              'deduce': 13,
#              'getting': 8,
#              'yourself': 42,
#              'very': 401,
#              'wet': 4,
#              'clumsy': 1,
#              'careless': 1,
#              'servant': 5,
#              'girl': 26,
#              'dear': 56,
#              'said': 486,
#              'too': 82,
#              'much': 121,
#              'certainly': 45,
#              'burned': 5,
#              'lived': 12,
#              'few': 77,
#              'centuries': 1,
#              'ago': 28,
#              'true': 29,
#              'country': 33,
#              'walk': 15,
#              'thursday': 2,
#              'came': 146,
#              'home': 46,
#              'dreadful': 17,
#              'mess': 1,
#              'changed': 5,
#              'clothes': 18,
#              'ca': 11,
#              "n't": 88,
#              'imagine': 29,
#              'mary': 22,
#              'jane': 1,
#              'incorrigible': 1,
#              'wife': 58,
#              'given': 33,
#              'notice': 11,
#              'fail': 6,
#              'chuckled': 7,
#              'rubbed': 3,
#              'long': 88,
#              'nervous': 9,
#              'together': 35,
#              'simplicity': 1,
#              'itself': 18,
#              'inside': 13,
#              'your': 405,
#              'left': 85,
#              'shoe': 1,
#              'where': 124,
#              'firelight': 1,
#              'strikes': 3,
#              'leather': 4,
#              'scored': 2,
#              'six': 24,
#              'parallel': 3,
#              'cuts': 2,
#              'obviously': 5,
#              'caused': 15,
#              'someone': 19,
#              'carelessly': 3,
#              'scraped': 2,
#              'round': 81,
#              'edges': 3,
#              'sole': 4,
#              'order': 21,
#              'remove': 6,
#              'crusted': 1,
#              'mud': 3,
#              'hence': 5,
#              'double': 12,
#              'deduction': 6,
#              'vile': 4,
#              'weather': 6,
#              'malignant': 1,
#              'boot-slitting': 1,
#              'specimen': 2,
#              'london': 41,
#              'slavey': 1,
#              'if': 280,
#              'gentleman': 45,
#              'walks': 5,
#              'smelling': 1,
#              'iodoform': 1,
#              'black': 49,
#              'mark': 8,
#              'nitrate': 1,
#              'silver': 3,
#              'right': 100,
#              'forefinger': 4,
#              'bulge': 1,
#              'side': 80,
#              'top-hat': 4,
#              'show': 16,
#              'secreted': 1,
#              'stethoscope': 1,
#              'dull': 7,
#              'pronounce': 2,
#              'active': 4,
#              'member': 5,
#              'medical': 9,
#              'profession': 10,
#              'could': 288,
#              'help': 50,
#              'laughing': 17,
#              'ease': 2,
#              'explained': 9,
#              'process': 5,
#              'hear': 33,
#              'reasons': 8,
#              'thing': 47,
#              'appears': 18,
#              'ridiculously': 1,
#              'simple': 18,
#              'easily': 11,
#              'myself': 77,
#              'though': 63,
#              'successive': 3,
#              'instance': 5,
#              'am': 185,
#              'baffled': 3,
#              'until': 75,
#              'explain': 16,
#              'believe': 35,
#              'are': 355,
#              'good': 107,
#              'yours': 18,
#              'quite': 107,
#              'lighting': 2,
#              'cigarette': 4,
#              'throwing': 12,
#              'down': 229,
#              'distinction': 1,
#              'clear': 44,
#              'example': 13,
#              'frequently': 10,
#              'steps': 25,
#              'lead': 10,
#              'hall': 19,
#              'often': 13,
#              'well': 186,
#              'hundreds': 3,
#              'times': 18,
#              'many': 43,
#              'observed': 22,
#              'point': 43,
#              'seventeen': 1,
#              'because': 24,
#              'both': 49,
#              'by-the-way': 1,
#              'interested': 12,
#              'problems': 8,
#              'enough': 58,
#              'chronicle': 5,
#              'two': 143,
#              'trifling': 4,
#              'experiences': 2,
#              'sheet': 12,
#              'thick': 13,
#              'pink-tinted': 1,
#              'note-paper': 3,
#              'lying': 14,
#              'open': 63,
#              'table': 43,
#              'last': 95,
#              'post': 9,
#              'read': 39,
#              'aloud': 2,
#              'note': 31,
#              'undated': 1,
#              'without': 81,
#              'either': 34,
#              'signature': 5,
#              'address': 26,
#              'will': 269,
#              'call': 43,
#              'to-night': 25,
#              'quarter': 9,
#              'eight': 13,
#              "o'clock": 33,
#              'desires': 2,
#              'consult': 8,
#              'matter': 125,
#              'deepest': 5,
#              'moment': 36,
#              'recent': 6,
#              'services': 4,
#              'royal': 4,
#              'houses': 12,
#              'europe': 6,
#              'safely': 4,
#              'trusted': 2,
#              'matters': 20,
#              'importance': 16,
#              'can': 233,
#              'exaggerated': 2,
#              'we': 539,
#              'quarters': 5,
#              'received': 19,
#              'hour': 35,
#              'amiss': 2,
#              'visitor': 27,
#              'wear': 9,
#              'mask': 5,
#              'what': 391,
#              'means': 22,
#              'data': 11,
#              'capital': 8,
#              'mistake': 5,
#              'theorize': 1,
#              'insensibly': 1,
#              'begins': 1,
#              'twist': 4,
#              'facts': 35,
#              'suit': 10,
#              'theories': 7,
#              'instead': 8,
#              'carefully': 10,
#              'examined': 16,
#              'writing': 15,
#              'paper': 40,
#              'written': 23,
#              'wrote': 14,
#              'presumably': 3,
#              'endeavouring': 6,
#              'imitate': 1,
#              'processes': 1,
#              'bought': 6,
#              'crown': 6,
#              'packet': 2,
#              'peculiarly': 1,
#              'stiff': 2,
#              'peculiar': 20,
#              'hold': 9,
#              'light': 73,
#              'large': 41,
#              'e': 3,
#              'small': 81,
#              'g': 3,
#              'p': 2,
#              't': 2,
#              'woven': 3,
#              'texture': 1,
#              'make': 76,
#              'asked': 88,
#              'maker': 1,
#              'monogram': 2,
#              'rather': 64,
#              'stands': 6,
#              'gesellschaft': 1,
#              'german': 14,
#              'company': 18,
#              'customary': 1,
#              'contraction': 3,
#              'like': 94,
#              'co': 1,
#              'course': 60,
#              'papier': 1,
#              'eg': 1,
#              'let': 70,
#              'glance': 17,
#              'continental': 1,
#              'gazetteer': 1,
#              'took': 87,
#              'heavy': 29,
#              'brown': 16,
#              'volume': 5,
#              'shelves': 2,
#              'eglow': 1,
#              'eglonitz': 1,
#              'here': 139,
#              'egria': 1,
#              'german-speaking': 1,
#              'far': 54,
#              'carlsbad': 1,
#              'remarkable': 21,
#              'being': 45,
#              'scene': 14,
#              'death': 31,
#              'wallenstein': 1,
#              'its': 92,
#              'numerous': 2,
#              'glass-factories': 1,
#              'paper-mills': 1,
#              'ha': 22,
#              'boy': 17,
#              'sparkled': 2,
#              'sent': 21,
#              'great': 60,
#              'triumphant': 1,
#              'cloud': 4,
#              'made': 108,
#              'precisely': 14,
#              'construction': 1,
#              'sentence': 6,
#              'frenchman': 1,
#              'russian': 1,
#              'uncourteous': 1,
#              'verbs': 1,
#              'only': 163,
#              'remains': 7,
#              'therefore': 15,
#              'discover': 4,
#              'wanted': 11,
#              'writes': 1,
#              'prefers': 1,
#              'wearing': 3,
#              'showing': 7,
#              'face': 128,
#              'comes': 15,
#              'mistaken': 8,
#              'resolve': 2,
#              'doubts': 5,
#              'sharp': 15,
#              'sound': 31,
#              'horses': 4,
#              'hoofs': 2,
#              'grating': 2,
#              'wheels': 7,
#              'curb': 1,
#              'followed': 25,
#              'pull': 2,
#              'whistled': 2,
#              'pair': 12,
#              'yes': 125,
#              'continued': 14,
#              'glancing': 23,
#              'window': 70,
#              'nice': 7,
#              'brougham': 4,
#              'beauties': 1,
#              'hundred': 18,
#              'fifty': 9,
#              'guineas': 3,
#              'apiece': 4,
#              'money': 47,
#              'nothing': 108,
#              'else': 32,
#              'better': 49,
#              'bit': 6,
#              'doctor': 39,
#              'stay': 8,
#              'lost': 28,
#              'boswell': 1,
#              'promises': 4,
#              'interesting': 21,
#              'pity': 9,
#              'miss': 88,
#              'client': 31,
#              'want': 28,
#              'sit': 17,
#              'best': 31,
#              'slow': 6,
#              'step': 22,
#              'stairs': 14,
#              'passage': 22,
#              'paused': 3,
#              'immediately': 7,
#              'outside': 27,
#              'loud': 3,
#              'authoritative': 1,
#              'tap': 3,
#              'come': 162,
#              'entered': 33,
#              'less': 38,
#              'feet': 28,
#              'inches': 2,
#              'height': 5,
#              'limbs': 7,
#              'hercules': 1,
#              'dress': 25,
#              'rich': 11,
#              'richness': 1,
#              'england': 20,
#              'bad': 14,
#              'taste': 3,
#              'bands': 2,
#              'astrakhan': 1,
#              'slashed': 1,
#              'sleeves': 5,
#              'fronts': 1,
#              'double-breasted': 1,
#              'coat': 19,
#              'deep': 23,
#              'cloak': 7,
#              'thrown': 10,
#              'shoulders': 16,
#              'lined': 4,
#              'flame-coloured': 2,
#              'silk': 5,
#              'secured': 3,
#              'neck': 9,
#              'brooch': 1,
#              'consisted': 2,
#              'single': 18,
#              'flaming': 2,
#              'boots': 16,
#              'extended': 4,
#              'halfway': 2,
#              'calves': 1,
#              'trimmed': 1,
#              'tops': 1,
#              'fur': 2,
#              'completed': 4,
#              'impression': 16,
#              'barbaric': 1,
#              'opulence': 1,
#              'suggested': 9,
#              'appearance': 16,
#              'carried': 22,
#              'broad-brimmed': 3,
#              'hat': 44,
#              'hand': 113,
#              'wore': 8,
#              'upper': 9,
#              'extending': 2,
#              'past': 23,
#              'cheekbones': 1,
#              'vizard': 1,
#              'apparently': 5,
#              'raised': 11,
#              'lower': 7,
#              'appeared': 27,
#              'character': 20,
#              'hanging': 7,
#              'straight': 8,
#              'chin': 12,
#              'suggestive': 9,
#              'resolution': 3,
#              'pushed': 14,
#              'length': 4,
#              'obstinacy': 1,
#              'harsh': 1,
#              'voice': 20,
#              'strongly': 5,
#              'marked': 12,
#              'accent': 2,
#              'uncertain': 4,
#              'pray': 42,
#              'seat': 11,
#              'colleague': 4,
#              'dr': 31,
#              'occasionally': 10,
#              'cases': 24,
#              'whom': 40,
#              'honour': 12,
#              'count': 4,
#              'von': 4,
#              'kramm': 2,
#              'nobleman': 2,
#              'understand': 49,
#              'discretion': 3,
#              'trust': 16,
#              'extreme': 9,
#              'prefer': 7,
#              'communicate': 5,
#              'alone': 27,
#              'rose': 24,
#              'caught': 20,
#              'wrist': 9,
#              'back': 139,
#              'chair': 56,
#              'none': 34,
#              'say': 94,
#              'anything': 53,
#              'shrugged': 8,
#              'broad': 13,
#              'begin': 6,
#              'binding': 1,
#              'absolute': 15,
#              'secrecy': 7,
#              'years': 66,
#              'end': 57,
#              'present': 27,
#              'weight': 7,
#              'influence': 11,
#              'european': 1,
#              'history': 3,
#              'promise': 14,
#              'excuse': 15,
#              'strange': 46,
#              'august': 1,
#              'person': 26,
#              'employs': 1,
#              'wishes': 5,
#              'agent': 9,
#              'unknown': 5,
#              'confess': 16,
#              'once': 86,
#              'called': 26,
#              'exactly': 8,
#              'aware': 10,
#              'dryly': 1,
#              'circumstances': 9,
#              'delicacy': 5,
#              'precaution': 5,
#              'taken': 28,
#              'quench': 1,
#              'grow': 2,
#              'seriously': 5,
#              'compromise': 1,
#              'families': 5,
#              'speak': 20,
#              'plainly': 8,
#              'implicates': 1,
#              'house': 113,
#              'ormstein': 2,
#              'hereditary': 4,
#              'kings': 1,
#              'also': 54,
#              'murmured': 6,
#              'settling': 2,
#              'closing': 6,
#              'glanced': 22,
#              'apparent': 1,
#              'surprise': 16,
#              'languid': 2,
#              'lounging': 5,
#              'depicted': 1,
#              'incisive': 3,
#              'energetic': 4,
#              'slowly': 19,
#              'reopened': 1,
#              'impatiently': 3,
#              'gigantic': 4,
#              'majesty': 18,
#              'condescend': 2,
#              'state': 18,
#              'able': 31,
#              'advise': 7,
#              'sprang': 23,
#              'paced': 7,
#              'uncontrollable': 3,
#              'agitation': 5,
#              'gesture': 5,
#              'desperation': 1,
#              'tore': 5,
#              'hurled': 3,
#              'ground': 22,
#              'cried': 69,
#              'king': 26,
#              'why': 76,
#              'attempt': 10,
#              'conceal': 5,
#              'addressing': 2,
#              ...})

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words('english') #We're looking specifically for English stop words
#print(stopwords)

# %%
items1 = monty.word_counts.items()    #Here we assign the word count to the item 1 for txt 1, (Monty Python)
items2 = gatsby.word_counts.items() #Repeat the same for the other items
items3 = holmes.word_counts.items()
#print(items1) 
print(len(items1)) #This prints the length of the txt files before the stopwords are removed
#print(items2)
print(len(items2))
#print(items3)
print(len(items3))
# Out:
# 3558
# 6638
# 8525

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words('english') #We're looking specifically for English stop words 
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
items1 = [item for item in items1 if item[0] not in stopwords] #This will pull my stopwords out from items1
items2 = [item for item in items2 if item[0] not in stopwords] #This will pull my stopwords out from items2
items3 = [item for item in items3 if item[0] not in stopwords] #This will pull my stopwords out from items3
print(len(items1)) #This prints the length of the txt files after the stopwords are removed
print(len(items2))
print(len(items3))
# Out:
# 3428
# 6492
# 8386

# %% [markdown]
# ### Answer to word count question:
#
# Monty Python = 3,428
#
# Gatsby = 6,492
#
# Sherlock Holmes = 8,386
#
# There was a significant difference in the word counts between the three items. I would have assumed Monty Python and the Holy Grail would have had a higher word count than it did given it is a movie script. Another item to note was the difference between the original word count and the new word count when the stopwords were introduced.
# The before vs the after:
# 3,558 vs 3,428
# 6,637 vs 6,492
# 8,525 vs 8,386
#
# The stopwords removal removed approximately the same number of words from each item. This seems accurate due to the stopwords including common types of punctuation - something that would not necessarily be unique to one work over the other. The largest number of stopwords removed was from Great Gatsby at 145. The smallest number was from Monty Python at 130. Sherlock Holmes had 139 words removed.

# %%
print(str("The difference in word count for Monty Python is " + str(3558 - 3428)))
print(str("The difference in word count for Great Gatsby is " + str(6637 - 6492)))
print(str("The difference in word count for Sherlock Holmes is " + str(8525 - 8386)))
# Out:
# The difference in word count for Monty Python is 130
# The difference in word count for Great Gatsby is 145
# The difference in word count for Sherlock Holmes is 139

# %% [markdown]
# ## **Part 2:**<br>
# (a) Compute word counts for each of your documents after excluding English stop words (and optionally, performing lemmatization).<br>
#
# (b) Create and display a bar plot for each document that include word counts for the 25 most frequent words (after the above processing).<br>
#
# (c) Create and display a word cloud for each document (using a mask image of your choice) that includes only the 100 most frequent words.  Note that you'll likely want to use the approach outlined in Session 25 that utilizes the `fitwords` method, since you will want data consistent with those for part (b).<br>
#
# (d) Do you see any notable difference between the documents wrt (b) and/or (c) above?  Try to explain why or why not, and whether you would expect such a difference.<br>

# %%
sorted_monty = sorted(items1, key=itemgetter(1), reverse=True) #Sorting my items with itemgetter
sorted_gatsby = sorted(items2, key=itemgetter(1), reverse=True) #Sorting my items with itemgetter
sorted_holmes = sorted(items3, key=itemgetter(1), reverse=True) #Sorting my items with itemgetter

stopwords1 = ['“', '”', '’', '...', '.', ',', '-', '‘'] #Establishing additional stopwords to pull punctuation out of Great Gatsby specifically. I will run it through all of them though.

sorted_holmes2 = [pair for pair in sorted_holmes if pair[0] not in stopwords1] #Run the secondary stopwords removal
sorted_monty2 = [pair for pair in sorted_monty if pair[0] not in stopwords1]
sorted_gatsby2 = [pair for pair in sorted_gatsby if pair[0] not in stopwords1]
#print (sorted_romeo2)

# %%
top25a = sorted_monty2[:25] #Count the top 25 from each item
top25b = sorted_gatsby2[0:25] 
top25c = sorted_holmes2[:25]
df_monty = pd.DataFrame(top25a, columns=['word', 'count'])  #Add the top 25 items to a pandas DataFrame
df_gatsby = pd.DataFrame(top25b, columns=['word', 'count'])
df_holmes = pd.DataFrame(top25c, columns=['word', 'count'])

# %%
df_gatsby.sort_values(by=['count'], ascending=False) #sorting by descending value to verify the dataframe is working
df_gatsby.head()
# Out:
#      word  count
# 0  gatsby    260
# 1    said    233
# 2     tom    189
# 3   daisy    183
# 4     one    148

# %%
df_monty.plot.bar(x='word', y='count',color = 'blue', legend=False)
plt.title('Monty Python and the Holy Grail')
plt.gcf().tight_layout()

# %%
df_holmes.plot.bar(x='word', y='count', color = 'orange', legend=False)
plt.title('The Adventures of Sherlock Holmes')
plt.gcf().tight_layout()

# %%
df_gatsby.plot.bar(x='word', y='count', color = 'green', legend=False)
plt.title('Great Gatsby')
plt.gcf().tight_layout()

# %%
from PIL import Image #import the components for wordcloud
import numpy as np
from wordcloud import WordCloud

# %%
import imageio #import the imageio package
mask_image1 = imageio.imread('Python.png') #set the images for my wordclouds
mask_image2 = imageio.imread('sherlock.png')
mask_image3 = imageio.imread('Shield.png')

# %%
wordcloud1 = WordCloud(width=1000, height=1000, #These lines set the dimensions for the wordclouds. Specifically ensuring the max words is equal to 100
    colormap='prism', max_words = 100, mask=mask_image2, background_color='white')
wordcloud2 = WordCloud(width=1000, height=1000, 
    colormap='prism', max_words = 100, mask=mask_image1, background_color='white')
wordcloud3 = WordCloud(width=1000, height=1000, 
    colormap='prism', max_words = 100, mask=mask_image3, background_color='white')

# %%
from pathlib import Path
Sherlock_text = Path('The Adventures of Sherlock Holmes.txt').read_text(encoding='utf-8') #Reading the text in for the wordcloud image per txt file
Holmes_wordcloud = wordcloud1.generate(Sherlock_text)

Gatsby_text = Path('Great Gatsby.txt').read_text(encoding='utf-8')
Gatsby_wordcloud = wordcloud2.generate(Gatsby_text)

Monty_text = Path('Monty Python and the Holy Grail.txt').read_text(encoding='utf-8')
Monty_wordcloud = wordcloud3.generate(Monty_text)

from wordcloud import WordCloud   
Holmes_wordcloud = wordcloud1.to_file('Holmes.png')
Gatsby_wordcloud = wordcloud2.to_file('Gatsby.png')
Monty_wordcloud = wordcloud3.to_file('Monty.png')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
plt.axis('off')
plt.imshow(Monty_wordcloud)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.axis('off')
plt.imshow(Holmes_wordcloud)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.axis('off')
plt.imshow(Gatsby_wordcloud)

# %% [markdown]
# ## Answer 2
#
# The word cloud and bar plots were aligned to one another accurately. The names and words that populated in the bar chart were emphasized in the wordcloud. The wordcloud program increased the size and used quality placement of the most recurring words in the text. I wouldn't say there were notable differences between the two.

# %% [markdown]
# ## **Part 3:**<br>
# (a) Use **Textatistic** to compute the _average_ of the Flesch–Kincaid, Gunning Fog, SMOG, and Dale–Chall scores for each document.
#
# (b) Are there noticeable differences among your documents's readability scores, and do you suspect any difference is present (or _should be_ present)?

# %%
#First read in the text for textatistic
from pathlib import Path
textatistic_Holmes = Path('The Adventures of Sherlock Holmes.txt').read_text(encoding='utf-8')
textatistic_Monty = Path('Monty Python and the Holy Grail.txt').read_text(encoding='utf-8')
textatistic_Gatsby = Path('Great Gatsby.txt').read_text(encoding='utf-8')

# %%
from textatistic import Textatistic
readability_Holmes = Textatistic(textatistic_Holmes) #determine the readability for each by running the texatistic function
readability_Monty = Textatistic(textatistic_Monty)
readability_Gatsby = Textatistic(textatistic_Gatsby)

# %%
# %precision 3
readability_Monty.dict() #determine the readability
# Out:
# {'char_count': 98779,
#  'word_count': 20976,
#  'sent_count': 3901,
#  'sybl_count': 25656,
#  'notdalechall_count': 4573,
#  'polysyblword_count': 746,
#  'flesch_score': 97.902,
#  'fleschkincaid_score': 0.940,
#  'gunningfog_score': 3.573,
#  'smog_score': 5.627,
#  'dalechall_score': 7.346}

# %%
readability_Holmes.dict() #determine the readability
# Out:
# {'char_count': 471485,
#  'word_count': 108509,
#  'sent_count': 7354,
#  'sybl_count': 133425,
#  'notdalechall_count': 14506,
#  'polysyblword_count': 4733,
#  'flesch_score': 87.833,
#  'fleschkincaid_score': 4.674,
#  'gunningfog_score': 7.647,
#  'smog_score': 7.712,
#  'dalechall_score': 6.479}

# %%
readability_Gatsby.dict() #determine the readability of Gatsby
# Out:
# {'char_count': 236194,
#  'word_count': 51955,
#  'sent_count': 3732,
#  'sybl_count': 65335,
#  'notdalechall_count': 10966,
#  'polysyblword_count': 2535,
#  'flesch_score': 86.318,
#  'fleschkincaid_score': 4.678,
#  'gunningfog_score': 7.520,
#  'smog_score': 7.837,
#  'dalechall_score': 7.660}

# %% [markdown]
# ## **Part 4:**<br>
# (a) Use spaCy to compute the pairwise similarity between your documents (i.e. doc. 1 to doc. 2, doc. 1 to doc. 3, doc. 2 to doc. 3).<br>
#
# (b) Do any of these similarity scores seem higher or lower than you would expect?  Explain your response.

# %%
import spacy #import the large spaCY package
nlp_lg = spacy.load('en_core_web_lg')  
nlp_lg.max_length = 1500000

# %%
#Create the docs for spaCY to read
from pathlib import Path
document1 = nlp_lg(Path('Great Gatsby.txt').read_text(encoding='utf-8'))
document2 = nlp_lg(Path('Monty Python and the Holy Grail.txt').read_text())
document3 = nlp_lg(Path('The Adventures of Sherlock Holmes.txt').read_text())

# %%
docsim=document1.similarity(document2)
print(f'G&G to MP similarity is {docsim:.3}.') #This generates my spaCY similarity score for GG -> MP
# Out:
# G&G to MP similarity is 0.985.

# %%
docsim=document1.similarity(document3)
print(f'G&G to SH similarity is {docsim:.3}.') #This gives us the similarity score between GG -> SH
# Out:
# G&G to SH similarity is 0.995.

# %%
docsim=document2.similarity(document3)
print(f'MP to SH similarity is {docsim:.3}.') #The similarity score of MP -> SH
# Out:
# MP to SH similarity is 0.984.

# %% [markdown]
# (b) Do any of these similarity scores seem higher or lower than you would expect?  Explain your response.
#
# ## Answer 4
# Yes. I would have assumed that based on the years the files were written (Monty Python, Great Gatsby, and Sherlock Holmes), there would have been a larger deviation in similarity scores. The furthest similarity score was 0.016 (Monty Python vs. Sherlock Holmes). I would not have assumed the Great Gatsby would have had a similarity score of 99.5% to the adventures of Sherlock Holmes. That was an extremely close similarity score.
#
# I installed the large spaCY profile just to confirm the findings and ensure I wasn't missing data by using the medium profile. The results were nearly the same.

# %% [markdown]
# ## **Part 5:**<br>
# (a) Use spaCy to find the named entities in your documents.<br>
#
# (b) Produce a bar plot for each document that includes the count for the 20 most common named entities (by name).<br>
#
# (c) Produce a second bar plot per document based on the counts of every named entity type (PERSON, ORG, etc.)<br>
#
# (d) Do you notice any meaningful differences (or similarities) among the documents wrt to these plots?  If so, explain what they are.

# %%
#spaCY load
#use encore web lg

document = nlp_lg(Path('Great Gatsby.txt').read_text(encoding = 'utf-8') + 
    Path('Monty Python and the Holy Grail.txt').read_text(encoding = 'utf-8') +
    Path('The Adventures of Sherlock Holmes.txt').read_text(encoding = 'utf-8'))

# %% [markdown]
# ### Great Gatsby

# %%
document1 = nlp_lg(Path('Great Gatsby.txt').read_text(encoding = 'utf-8'))
for entity in document1.ents: #run through the document.ents (adding entity and label)
    print(f'{entity.text}:{entity.label_}')
# Out:
# Gutenberg eBook:WORK_OF_ART
# The Great Gatsby:WORK_OF_ART
# F. Scott Fitzgerald:PERSON
# eBook:EVENT
# the United States:GPE
# the Project Gutenberg License:ORG
# eBook:EVENT
# the United States:GPE
# eBook:PRODUCT
# The Great Gatsby:WORK_OF_ART
# F. Scott Fitzgerald:PERSON
# January 17, 2021:DATE
# 64317:MONEY
# January 24 2021:DATE
# English:LANGUAGE
# Alex Cabal:ORG
# The Great Gatsby:WORK_OF_ART
# F. Scott Fitzgerald
#
#
#                            Table:PERSON
# Thomas Parke:PERSON
# d’Invilliers
#
#
#                                   I:ORG
# at least:CARDINAL
# East:LOC
# Gatsby:PERSON
# Gatsby:PERSON
# one:CARDINAL
# ten
# thousand miles:QUANTITY
# Gatsby:PERSON
# three:CARDINAL
# Carraways:PERSON
# fifty-one:CARDINAL
# today:DATE
# New Haven:GPE
# 1915:DATE
# just a quarter of
# a century:DATE
# Teutonic:NORP
# the Great War:EVENT
# the Middle West:LOC
# East:LOC
# one:CARDINAL
# a year:DATE
# East:LOC
# the spring of twenty-two:DATE
# eighty a
# month:DATE
# the last minute:TIME
# Washington:GPE
# a
# few days:DATE
# Dodge:ORG
# Finnish:NORP
# Finnish:NORP
# one morning:TIME
# West Egg:LOC
# the summer:DATE
# one:CARDINAL
# a dozen:CARDINAL
# Midas:ORG
# Morgan:PERSON
# Maecenas:PERSON
# one year:DATE
# Yale News:ORG
# one:CARDINAL
# North America:LOC
# New York:GPE
# two:CARDINAL
# Twenty miles:QUANTITY
# Long Island:LOC
# Columbus:GPE
# West Egg:LOC
# two:CARDINAL
# only fifty yards:QUANTITY
# two:CARDINAL
# twelve or fifteen thousand a season:CARDINAL
# one:CARDINAL
# Hôtel de Ville:LOC
# Normandy:GPE
# one:CARDINAL
# more than forty acres:QUANTITY
# Gatsby:PERSON
# Gatsby:PERSON
# eighty dollars:MONEY
# a
# month:DATE
# East Egg:LOC
# the Tom
# Buchanans:ORG
# Daisy:PERSON
# second:ORDINAL
# Tom
# :PERSON
# two days:DATE
# Chicago:GPE
# one:CARDINAL
# New Haven:GPE
# one:CARDINAL
# twenty-one:CARDINAL
# Chicago:GPE
# East:LOC
# Lake
# Forest:ORG
# a year:DATE
# France:GPE
# Daisy:PERSON
# Daisy:PERSON
# Tom:PERSON
# two:CARDINAL
# Georgian Colonial mansion:GPE
# a quarter:CARDINAL
# French:NORP
# afternoon:TIME
# Tom Buchanan:PERSON
# New Haven:GPE
# years:DATE
# thirty:CARDINAL
# Two:CARDINAL
# New Haven:GPE
# a few minutes:TIME
# one:CARDINAL
# vista:ORG
# Italian:NORP
# French:NORP
# one:CARDINAL
# two:CARDINAL
# a few moments:TIME
# Tom Buchanan:PERSON
# two:CARDINAL
# two:CARDINAL
# Daisy:PERSON
# Baker:PERSON
# Daisy:PERSON
# Baker:PERSON
# the next hour:TIME
# Chicago:GPE
# East:LOC
# dozen:CARDINAL
# night:TIME
# Tom:PERSON
# Tomorrow:DATE
# three years old:DATE
# Tom Buchanan:PERSON
# Nick:PERSON
# East:LOC
# East:LOC
# Daisy:PERSON
# Baker:PERSON
# Daisy:PERSON
# New York:GPE
# all afternoon:TIME
# Baker:PERSON
# four:CARDINAL
# Baker:PERSON
# West Egg:GPE
# Gatsby:PERSON
# Gatsby:PERSON
# Daisy:PERSON
# Gatsby:PERSON
# Tom Buchanan:PERSON
# two:CARDINAL
# four:CARDINAL
# Daisy:PERSON
# two weeks:DATE
# the longest day:DATE
# the year:DATE
# the longest day:DATE
# the year:DATE
# the longest day:DATE
# the year:DATE
# Baker:PERSON
# Daisy:PERSON
# Tom:PERSON
# Tom:PERSON
# Daisy:PERSON
# Baker:PERSON
# Tom:PERSON
# Daisy:PERSON
# second:ORDINAL
# Can’t you talk about:WORK_OF_ART
# Tom:PERSON
# the Coloured Empires:ORG
# Goddard:PERSON
# Tom’s:WORK_OF_ART
# Daisy:PERSON
# Tom:PERSON
# Daisy:PERSON
# California:GPE
# Baker:PERSON
# Tom
# :PERSON
# Daisy:PERSON
# Daisy:PERSON
# tonight:TIME
# New York:GPE
# two hundred:CARDINAL
# morning till night:TIME
# Baker:PERSON
# a moment:TIME
# dusk:TIME
# Tom:PERSON
# Tom:PERSON
# Daisy:PERSON
# Nick:PERSON
# Baker:PERSON
# Baker:PERSON
# Baker:PERSON
# Gatsby:PERSON
# Baker:PERSON
# Tom:PERSON
# New York:GPE
# Baker:PERSON
# Tom:PERSON
# Daisy:PERSON
# Daisy:PERSON
# Baker:PERSON
# a minute:TIME
# Cunard:ORG
# White Star Line:FAC
# Tom:PERSON
# Daisy:PERSON
# Tom:PERSON
# the last five minutes
# :TIME
# Daisy:PERSON
# Tom:PERSON
# Baker:PERSON
# fifth:ORDINAL
# Tom:PERSON
# Miss
# Baker:PERSON
# several feet:QUANTITY
# Daisy:PERSON
# Daisy:PERSON
# Nick:PERSON
# Nick,
# :ORG
# Nick:PERSON
# less than an hour:TIME
# Tom:PERSON
# Tom:PERSON
# Tom:PERSON
# Tom:PERSON
# Baker:PERSON
# Saturday Evening Post:WORK_OF_ART
# Ten o’clock:DATE
# Jordan:PERSON
# tomorrow:DATE
# Daisy:PERSON
# Westchester:GPE
# Jordan Baker:PERSON
# Asheville:GPE
# Hot Springs:GPE
# Palm Beach:GPE
# forgotten long ago:DATE
# night:TIME
# Carraway:PERSON
# Daisy:PERSON
# Nick:PERSON
# night:TIME
# Baker:PERSON
# Tom:PERSON
# Daisy:PERSON
# about a thousand years old:DATE
# Nick’s:ORG
# Nick:PERSON
# this summer:DATE
# Daisy:PERSON
# Tom:PERSON
# New York:GPE
# Louisville:GPE
# Nick:PERSON
# Tom:PERSON
# Nordic:LOC
# first:ORDINAL
# Nick:PERSON
# a few minutes
# later:TIME
# Daisy:PERSON
# Tom:PERSON
# Daisy:PERSON
# three:CARDINAL
# one:CARDINAL
# East:LOC
# Daisy:PERSON
# Tom:PERSON
# New York:GPE
# West Egg:FAC
# fifty feet:QUANTITY
# Gatsby:PERSON
# Baker:PERSON
# Gatsby:PERSON
# West Egg:FAC
# New York:GPE
# a quarter:CARDINAL
# J. Eckleburg:PERSON
# one:CARDINAL
# Queens:GPE
# days:DATE
# as long as half an
# hour:DATE
# at least a minute:TIME
# first:ORDINAL
# Tom Buchanan’s:PERSON
# New York:GPE
# Tom:PERSON
# one
# afternoon:TIME
# Sunday afternoon:TIME
# a hundred yards:QUANTITY
# One:CARDINAL
# three:CARDINAL
# third:ORDINAL
# George B. Wilson:PERSON
# Tom:PERSON
# Ford:ORG
# Wilson:PERSON
# Tom:PERSON
# Wilson:PERSON
# Next week:DATE
# Tom:PERSON
# Wilson:PERSON
# Tom:PERSON
# the middle thirties:DATE
# Tom:PERSON
# Wilson:PERSON
# Tom:PERSON
# Tom:PERSON
# George Wilson:PERSON
# two:CARDINAL
# a few days:DATE
# the Fourth of July:DATE
# Italian:NORP
# Tom:PERSON
# Wilson:ORG
# New York:GPE
# Tom Buchanan:PERSON
# New York:GPE
# Wilson:PERSON
# Tom
# :PERSON
# Tom:PERSON
# New York:GPE
# Town Tattle:PRODUCT
# four:CARDINAL
# one:CARDINAL
# John
# :PERSON
# D. Rockefeller:PERSON
# a dozen:CARDINAL
# Wilson:PERSON
# one:CARDINAL
# Tom.:PERSON
# Wilson:PERSON
# ten
# dollars:MONEY
# Airedale:ORG
# Airedale:NORP
# Wilson:PERSON
# Tom:PERSON
# ten:CARDINAL
# Fifth Avenue:FAC
# Sunday:DATE
# afternoon:TIME
# Tom:PERSON
# Myrtle:GPE
# Catherine:PERSON
# the West Hundreds:LOC
# 158th Street:FAC
# one:CARDINAL
# Wilson:PERSON
# Versailles:GPE
# Town Tattle:PRODUCT
# Simon Called Peter:PERSON
# Broadway:FAC
# Wilson:PERSON
# first:ORDINAL
# one:CARDINAL
# afternoon:TIME
# Tom:PERSON
# second:ORDINAL
# that
# :TIME
# afternoon:TIME
# Tom:PERSON
# Wilson:PERSON
# Simon Called:PERSON
# Tom:PERSON
# Myrtle:PERSON
# first:ORDINAL
# Wilson:PERSON
# first:ORDINAL
# Catherine:PERSON
# about thirty:CARDINAL
# McKee:PERSON
# Wilson:PERSON
# a hundred and twenty-seven:CARDINAL
# Wilson:PERSON
# last week:DATE
# McKee:PERSON
# Eberhardt:PERSON
# McKee:PERSON
# Wilson:PERSON
# Chester:GPE
# Wilson:PERSON
# McKee:PERSON
# one:CARDINAL
# McKee:PERSON
# Tom Buchanan:PERSON
# You McKees:WORK_OF_ART
# Myrtle:GPE
# Myrtle:PERSON
# dozen:CARDINAL
# Long Island:GPE
# McKee:PERSON
# Tom:PERSON
# Two:CARDINAL
# Two:CARDINAL
# Tom.:PERSON
# Two:CARDINAL
# One:CARDINAL
# Catherine:PERSON
# Long Island:GPE
# West Egg:LOC
# about a month ago:DATE
# Gatsby:PERSON
# Kaiser Wilhelm’s:PERSON
# McKee:PERSON
# Catherine:PERSON
# Chester:GPE
# McKee:PERSON
# Tom:PERSON
# Long Island:GPE
# Myrtle:PERSON
# Tom:PERSON
# Wilson:PERSON
# Myrtle:GPE
# a moment as:TIME
# George B. Wilson:PERSON
# the Gasoline Pump:ORG
# Catherine:PERSON
# Myrtle:GPE
# Tom:PERSON
# Wilson:PERSON
# Myrtle:GPE
# Catherine:PERSON
# Catholic:NORP
# Daisy:PERSON
# Catholic:NORP
# Catherine:PERSON
# Europe:LOC
# Europe:LOC
# Monte Carlo:ORG
# Just last year:DATE
# Monte Carlo:ORG
# Marseilles:GPE
# twelve hundred dollars:MONEY
# two days:DATE
# Mediterranean:LOC
# McKee
# :PERSON
# years:DATE
# Chester:GPE
# Myrtle Wilson:PERSON
# Myrtle:GPE
# Myrtle:GPE
# Catherine:PERSON
# Catherine:PERSON
# Myrtle:PERSON
# first:ORDINAL
# all afternoon:TIME
# Catherine:PERSON
# eleven years:DATE
# Tom:PERSON
# second:ORDINAL
# one:CARDINAL
# Catherine:PERSON
# Tom rang:PERSON
# first:ORDINAL
# Tom:PERSON
# two:CARDINAL
# New York:GPE
# the night:TIME
# McKee:PERSON
# nine o’clock:TIME
# ten:CARDINAL
# McKee:PERSON
# a few feet:QUANTITY
# Tom Buchanan:PERSON
# Wilson:PERSON
# Wilson
# :PERSON
# Daisy:PERSON
# Daisy!:WORK_OF_ART
# Daisy:PERSON
# Wilson:PERSON
# Daisy:PERSON
# Tom Buchanan:PERSON
# McKee:PERSON
# Catherine:PERSON
# Town Tattle:PRODUCT
# Versailles:GPE
# McKee:PERSON
# some day:DATE
# McKee:PERSON
# Beauty and the Beast:WORK_OF_ART
# Pennsylvania Station:ORG
# the morning:TIME
# four:CARDINAL
# the summer nights:DATE
# afternoon:TIME
# two:CARDINAL
# weekends:DATE
# Rolls-Royce:ORG
# midnight:TIME
# Mondays eight:DATE
# all day:DATE
# the night:TIME
# Friday five:DATE
# New York:GPE
# Monday:DATE
# two hundred:CARDINAL
# two hundred:CARDINAL
# several
# hundred feet:MONEY
# Christmas:DATE
# Gatsby:PERSON
# seven o’clock:DATE
# five:CARDINAL
# New York:GPE
# five:CARDINAL
# one:CARDINAL
# Frisco:ORG
# Gilda
# Gray’s:ORG
# Follies:ORG
# first:ORDINAL
# Gatsby:PERSON
# one:CARDINAL
# Long Island:GPE
# Gatsby:PERSON
# Gatsby:PERSON
# Gatsby:PERSON
# Saturday:DATE
# morning:TIME
# Gatsby:PERSON
# that night:TIME
# Jay
# Gatsby:PERSON
# a little after
# :PERCENT
# seven:CARDINAL
# Englishmen:NORP
# Americans:NORP
# a few:CARDINAL
# two or
# three:DATE
# Jordan Baker:PERSON
# a minute:TIME
# two:CARDINAL
# the finals the week
# before:DATE
# one:CARDINAL
# about a month ago:DATE
# Jordan:PERSON
# Jordan:PERSON
# two:CARDINAL
# three:CARDINAL
# Mumble:PERSON
# Jordan:PERSON
# one:CARDINAL
# Lucille:PERSON
# Lucille:PERSON
# Lucille:PERSON
# a week:DATE
# Croirier’s:WORK_OF_ART
# Jordan:PERSON
# tonight:TIME
# Two
# hundred:CARDINAL
# Gatsby:PERSON
# two:CARDINAL
# Jordan:PERSON
# three:CARDINAL
# Mumbles:PERSON
# Lucille:PERSON
# It’s:WORK_OF_ART
# German:NORP
# One:CARDINAL
# Germany:GPE
# first:ORDINAL
# American:NORP
# Lucille:PERSON
# Gatsby:PERSON
# first:ORDINAL
# another one after midnight:TIME
# Jordan:PERSON
# three:CARDINAL
# Jordan:PERSON
# Jordan:PERSON
# East Egg:ORG
# West Egg:LOC
# Jordan:PERSON
# half-hour:TIME
# first:ORDINAL
# Gatsby:PERSON
# Gothic:LOC
# English:LANGUAGE
# Jordan:PERSON
# Volume One:PRODUCT
# Belasco:ORG
# one:CARDINAL
# Jordan:PERSON
# Roosevelt:PERSON
# Claud
# :PERSON
# Roosevelt:PERSON
# last night:TIME
# about a week:DATE
# an hour:TIME
# midnight:TIME
# Italian:NORP
# Jordan Baker:PERSON
# two:CARDINAL
# June nineteen-eighteen:DATE
# France:GPE
# Jordan:GPE
# Gatsby:PERSON
# I’m Gatsby:PRODUCT
# one:CARDINAL
# four or five:CARDINAL
# two:CARDINAL
# Gatsby:PERSON
# Chicago:GPE
# Jordan:GPE
# Gatsby:PERSON
# his middle years:DATE
# Gatsby:PERSON
# Oxford:ORG
# Gatsby:PERSON
# Louisiana:GPE
# East Side:LOC
# New York:GPE
# Long Island:LOC
# Jordan:PERSON
# Gatsby:PERSON
# Vladmir Tostoff:PERSON
# Carnegie Hall:ORG
# as ‘Vladmir Tostoff’s
# Jazz History of the World!’ :WORK_OF_ART
# Tostoff:PERSON
# Gatsby:PERSON
# one:CARDINAL
# every day:DATE
# the “Jazz History of the World:ORG
# Gatsby:PERSON
# French:NORP
# Gatsby:PERSON
# Gatsby’s:ORG
# one:CARDINAL
# Gatsby:PERSON
# Baker:PERSON
# Gatsby:PERSON
# evening:TIME
# first:ORDINAL
# mornings:TIME
# Jordan:PERSON
# two:CARDINAL
# One:CARDINAL
# Jordan:PERSON
# East Egg:ORG
# One:CARDINAL
# two:CARDINAL
# first:ORDINAL
# tonight:TIME
# one:CARDINAL
# half an hour ago:TIME
# Jordan Baker:PERSON
# Gatsby:PERSON
# Jordan:GPE
# about an hour:TIME
# Sigourney Howard:PERSON
# first:ORDINAL
# Gatsby:PERSON
# tomorrow:DATE
# morning:TIME
# nine
# o’clock:PERCENT
# Philadelphia:GPE
# a minute:TIME
# night:TIME
# night:TIME
# night:TIME
# night:TIME
# Fifty feet:QUANTITY
# one:CARDINAL
# Gatsby:PERSON
# two minutes:TIME
# half a dozen:CARDINAL
# first:ORDINAL
# Gatsby:PERSON
# Owl Eyes:PERSON
# night:TIME
# Wha:PERSON
# Half a dozen:CARDINAL
# first:ORDINAL
# At least a dozen:CARDINAL
# a
# moon:MONEY
# Gatsby:PERSON
# three nights:DATE
# several weeks:DATE
# summer:DATE
# the early morning:TIME
# New York:GPE
# the Probity Trust:ORG
# first:ORDINAL
# Jersey City:GPE
# July:DATE
# Yale Club:ORG
# a conscientious hour:TIME
# Madison Avenue:FAC
# Murray Hill Hotel:FAC
# 33rd Street:FAC
# the Pennsylvania Station:FAC
# New York:GPE
# night:TIME
# Fifth Avenue:FAC
# a few
# minutes:TIME
# night:TIME
# eight o’clock:TIME
# Forties:WORK_OF_ART
# five:CARDINAL
# Jordan Baker:PERSON
# midsummer:DATE
# first:ORDINAL
# one day:DATE
# Warwick:GPE
# Daisy’s:ORG
# first:ORDINAL
# a
# row:DATE
# Jordan Baker:PERSON
# one:CARDINAL
# two:CARDINAL
# first:ORDINAL
# Love:WORK_OF_ART
# Nick:PERSON
# at least one:CARDINAL
# Sunday:DATE
# morning:TIME
# Gatsby:PERSON
# One:CARDINAL
# Von Hindenburg:PERSON
# second:ORDINAL
# Gatsby:PERSON
# that summer:DATE
# July 5th, 1922:DATE
# Gatsby:PERSON
# East Egg:LOC
# Bunsen:PERSON
# Yale:ORG
# Webster Civet:PERSON
# last summer:DATE
# Maine:GPE
# Hornbeams:PERSON
# the Willie
# Voltaires:ORG
# Blackbuck:PERSON
# Ismays:GPE
# Chrysties:PERSON
# Hubert Auerbach:PERSON
# Chrystie:PERSON
# Edgar Beaver:PERSON
# Clarence Endive:PERSON
# East Egg:LOC
# white knickerbockers:ORG
# Etty:PERSON
# Island:LOC
# R. P. Schraeders:PERSON
# Georgia:GPE
# Ripley Snells:PERSON
# Snell:ORG
# three days:DATE
# Ulysses Swett’s:PERSON
# Dancies:PERSON
# S. B. Whitebait:PERSON
# Maurice
# A. Flink:PERSON
# Hammerheads:LOC
# West Egg:LOC
# Poles:NORP
# Mulreadys:PERSON
# Cecil Roebuck:PERSON
# Cecil Schoen:PERSON
# Gulick the State:ORG
# Newton Orchid:PERSON
# Films Par Excellence:ORG
# Eckhaust:ORG
# Clyde Cohen:PERSON
# Don
# S. Schwartz:ORG
# Arthur McCarty:PERSON
# one:CARDINAL
# Catlips:PERSON
# Bembergs:WORK_OF_ART
# G.
# :PERSON
# Earl Muldoon:PERSON
# Muldoon:PERSON
# Da Fontano:PERSON
# Ed Legros:PERSON
# James B.
# :PERSON
# Rot-Gut:WORK_OF_ART
# the De Jongs:ORG
# Ernest Lilly:PERSON
# Associated Traction:ORG
# next day:DATE
# Klipspringer:PERSON
# Gus Waize:PERSON
# Horace:PERSON
# Lester Myer:PERSON
# George
# Duckweed:PERSON
# Francis Bull:PERSON
# New York:GPE
# Chromes:PRODUCT
# Dennickers:WORK_OF_ART
# Russel Betty:PERSON
# Corrigans:NORP
# Kellehers:GPE
# Scullys:PERSON
# S. W. Belcher:PERSON
# the
# Smirkes:ORG
# Quinns:PERSON
# Henry L. Palmetto:PERSON
# Times Square:FAC
# Benny McClenahan:PERSON
# four:CARDINAL
# Jaqueline:PERSON
# Consuela:PERSON
# Gloria
# :PERSON
# Judy:PERSON
# June:DATE
# months:DATE
# American:ORG
# Faustina:PERSON
# Baedeker:GPE
# Brewer:PERSON
# Albrucksburger:PERSON
# Haag:PERSON
# Ardita Fitz-Peters:PERSON
# P. Jewett:PERSON
# the American Legion:ORG
# Claudia Hip:PERSON
# Duke:ORG
# Gatsby:PERSON
# the summer:DATE
# nine o’clock:TIME
# one morning:TIME
# July:DATE
# Gatsby:PERSON
# three:CARDINAL
# first:ORDINAL
# two:CARDINAL
# morning:TIME
# today:DATE
# ’d:CARDINAL
# American:NORP
# hatboxes:FAC
# a dozen:CARDINAL
# perhaps half a dozen:CARDINAL
# the past month:DATE
# first:ORDINAL
# roadhouse:ORG
# West Egg:GPE
# Gatsby:PERSON
# Middle West:LOC
# America:GPE
# Oxford:ORG
# many
# years:DATE
# Jordan Baker:PERSON
# Oxford:ORG
# the Middle West:LOC
# San Francisco:GPE
# Europe:MONEY
# Paris:GPE
# Venice:GPE
# Rome:GPE
# the Bois de Boulogne:ORG
# first:ORDINAL
# the Argonne Forest I:ORG
# half mile:QUANTITY
# two days:DATE
# two nights:DATE
# a hundred and thirty
# :CARDINAL
# sixteen:CARDINAL
# last
# :DATE
# three:CARDINAL
# German:NORP
# Allied:ORG
# Montenegro:GPE
# Montenegro:GPE
# Adriatic Sea:LOC
# Montenegro:GPE
# Montenegro:GPE
# Montenegrin:PERSON
# Montenegro:GPE
# a dozen:CARDINAL
# Montenegro:GPE
# Orderi di
# :PERSON
# Danilo:PERSON
# Montenegro:GPE
# Nicolas Rex:PERSON
# Jay Gatsby:PERSON
# Valour Extraordinary:PRODUCT
# Oxford:ORG
# days:DATE
# Trinity Quad:ORG
# the Earl of
# :PERSON
# Doncaster:GPE
# half a dozen:CARDINAL
# Gatsby:PERSON
# the Grand Canal:FAC
# today:DATE
# this afternoon:TIME
# this afternoon:TIME
# Miss
# Baker:PERSON
# Baker:PERSON
# Baker:PERSON
# Jordan:PERSON
# Jay Gatsby:PERSON
# Port Roosevelt:GPE
# nineteen-hundreds:DATE
# Wilson:PERSON
# half:CARDINAL
# Astoria:GPE
# only half:CARDINAL
# Gatsby:PERSON
# Gatsby:PERSON
# Oxford:ORG
# a
# Christmas:DATE
# every year:DATE
# the Queensboro Bridge:FAC
# first:ORDINAL
# first:ORDINAL
# two:CARDINAL
# Europe:LOC
# Gatsby:PERSON
# Blackwell’s Island:ORG
# three:CARDINAL
# two bucks:MONEY
# Gatsby:PERSON
# noon:TIME
# Forty-second:TIME
# Gatsby
# :PERSON
# Carraway:PERSON
# Wolfshiem:PERSON
# Jew:PERSON
# two:CARDINAL
# half:CARDINAL
# one:CARDINAL
# Wolfshiem:PERSON
# Gatsby:PERSON
# Katspaugh:GPE
# a penny:MONEY
# Gatsby:PERSON
# Wolfshiem:PERSON
# Highballs:WORK_OF_ART
# Wolfshiem:PERSON
# Gatsby:PERSON
# Wolfshiem:PERSON
# Wolfshiem:PERSON
# Metropole:GPE
# Metropole:GPE
# Wolfshiem:PERSON
# Rosy Rosenthal:PERSON
# six:CARDINAL
# Rosy:PERSON
# evening:TIME
# almost morning:TIME
# Rosy:PERSON
# Rosy:PERSON
# four o’clock in the morning:TIME
# Wolfshiem:PERSON
# three:CARDINAL
# Four:CARDINAL
# Five:CARDINAL
# Becker:PERSON
# two:CARDINAL
# Gatsby:PERSON
# Wolfshiem:PERSON
# Wolfshiem:PERSON
# Wolfshiem:PERSON
# Metropole:GPE
# one:CARDINAL
# Gatsby:PERSON
# Baker:PERSON
# Baker:PERSON
# Wolfshiem:PERSON
# Wolfshiem:PERSON
# Oggsford:ORG
# Oggsford College:ORG
# England:GPE
# Oggsford College:ORG
# one:CARDINAL
# Gatsby:PERSON
# Several years:DATE
# an hour:TIME
# Gatsby:PERSON
# Wolfshiem:PERSON
# two:CARDINAL
# Meyer:ORG
# Gatsby:PERSON
# Wolfshiem:PERSON
# fifty years old:DATE
# Gatsby:PERSON
# one:CARDINAL
# his sentimental days:DATE
# New York:GPE
# Broadway:FAC
# Meyer Wolfshiem:WORK_OF_ART
# Gatsby:PERSON
# 1919:DATE
# Fixed the World’s Series:WORK_OF_ART
# 1919:DATE
# the end of:DATE
# one:CARDINAL
# fifty million:CARDINAL
# a minute:TIME
# Tom Buchanan:PERSON
# a minute:TIME
# Tom:PERSON
# half a dozen:CARDINAL
# Daisy:PERSON
# Gatsby:PERSON
# Buchanan:PERSON
# Gatsby:PERSON
# Tom:PERSON
# Gatsby:PERSON
# Gatsby:PERSON
# One October day:DATE
# nineteen-seventeen:DATE
# Jordan Baker:PERSON
# afternoon:TIME
# the Plaza Hotel:FAC
# one:CARDINAL
# half:CARDINAL
# half:CARDINAL
# England:GPE
# Daisy Fay’s:PERSON
# just eighteen,:DATE
# two years:DATE
# Louisville:GPE
# all day long:DATE
# Camp
# :ORG
# Taylor:PERSON
# night:TIME
# an hour:TIME
# that morning:TIME
# five feet:QUANTITY
# Jordan:GPE
# the Red
# Cross:ORG
# that day:DATE
# Daisy:PERSON
# Jay Gatsby:PERSON
# four years:DATE
# Long Island:GPE
# nineteen-seventeen:DATE
# the next year:DATE
# a few beaux
# :MONEY
# Daisy:PERSON
# New York:GPE
# several weeks:DATE
# the next autumn:DATE
# armistice:ORG
# February:DATE
# New Orleans:GPE
# June:DATE
# Tom Buchanan:PERSON
# Chicago:GPE
# Louisville:GPE
# hundred:CARDINAL
# four:CARDINAL
# the Muhlbach Hotel:FAC
# the day:DATE
# three hundred and fifty thousand
# dollars:CARDINAL
# June:DATE
# night:TIME
# Sauterne:ORG
# Daisy:PERSON
# Next day:DATE
# five o’clock:PERCENT
# Tom Buchanan:PERSON
# a
# three months:DATE
# the South Seas:LOC
# Santa Barbara:GPE
# a
# minute:TIME
# Where’s Tom:WORK_OF_ART
# the
# hour:TIME
# August:DATE
# A week:DATE
# Santa Barbara Tom:GPE
# Ventura:GPE
# one night:TIME
# next April:DATE
# France:GPE
# one:CARDINAL
# Cannes:GPE
# Deauville:GPE
# Chicago:GPE
# Daisy:PERSON
# Chicago:GPE
# Daisy
# :PERSON
# about six weeks ago:DATE
# Gatsby:PERSON
# first:ORDINAL
# years:DATE
# Gatsby:PERSON
# West Egg:GPE
# Gatsby:PERSON
# half:CARDINAL
# Gatsby:PERSON
# Jordan Baker:PERSON
# the Plaza
# :LOC
# half an hour:TIME
# Central Park:LOC
# the West Fifties:GPE
# I’m the Sheik of Araby:WORK_OF_ART
# Gatsby:PERSON
# Daisy:PERSON
# June:DATE
# night:TIME
# Jordan:GPE
# Daisy:PERSON
# some afternoon:TIME
# five years:DATE
# some afternoon:TIME
# half:CARDINAL
# some
# night:TIME
# Jordan:GPE
# first:ORDINAL
# New York:GPE
# Tom’s:PERSON
# Tom:PERSON
# Chicago:GPE
# years:DATE
# Daisy:PERSON
# Jordan:GPE
# Daisy:PERSON
# Gatsby:PERSON
# Daisy:PERSON
# Jordan:PERSON
# Gatsby:PERSON
# Gatsby:PERSON
# Fifty-Ninth:MONEY
# Gatsby:PERSON
# Tom Buchanan:PERSON
# West Egg:FAC
# Two o’clock:TIME
# Gatsby:PERSON
# first:ORDINAL
# Gatsby:PERSON
# Coney Island:GPE
# all summer:DATE
# Baker:PERSON
# Daisy:PERSON
# tomorrow:DATE
# about the day after tomorrow:DATE
# a few days:DATE
# Wolfshiem:ORG
# ’d:CARDINAL
# Gatsby:PERSON
# Coney Island:LOC
# Daisy:PERSON
# next morning:TIME
# Tom:PERSON
# Tom:PERSON
# eleven o’clock:TIME
# Gatsby:PERSON
# Finn:PERSON
# West Egg:GPE
# two o’clock:TIME
# Gatsby’s:ORG
# An hour:TIME
# Gatsby:PERSON
# One:CARDINAL
# about four:CARDINAL
# The
# Journal:ORG
# Finn:PERSON
# twelve:CARDINAL
# Gatsby:PERSON
# Clay’s Economics:ORG
# Finnish:NORP
# all day:DATE
# just two minutes:TIME
# Daisy:PERSON
# Castle Rackrent:ORG
# an hour:TIME
# an hour:TIME
# Ferdie:PERSON
# Ferdie:PERSON
# Gatsby:PERSON
# half a minute:TIME
# Daisy:PERSON
# Gatsby:PERSON
# Daisy:PERSON
# Gatsby:PERSON
# thousand:CARDINAL
# many years:DATE
# Daisy:PERSON
# Five years next November:DATE
# Gatsby:PERSON
# another minute:TIME
# Finn:PERSON
# Gatsby:PERSON
# Daisy:PERSON
# first:ORDINAL
# Gatsby:PERSON
# Daisy’s:WORK_OF_ART
# Daisy:PERSON
# Gatsby:PERSON
# half an hour:TIME
# Gatsby:PERSON
# Gatsby:PERSON
# Kant:PERSON
# half an hour:TIME
# a decade before:DATE
# five years:DATE
# Americans:NORP
# half an hour:TIME
# Gatsby:PERSON
# Daisy:PERSON
# Gatsby:PERSON
# years:DATE
# Daisy:PERSON
# Jay:PERSON
# Daisy:PERSON
# Daisy:PERSON
# Gatsby:PERSON
# just three years:DATE
# night:TIME
# Daisy:PERSON
# two:CARDINAL
# Daisy
# :PERSON
# Marie Antoinette:PERSON
# Gatsby:PERSON
# the Merton College
# Library:WORK_OF_ART
# Klipspringer:PERSON
# that morning:TIME
# Gatsby:PERSON
# Chartreuse:ORG
# Daisy:PERSON
# Daisy:PERSON
# Gatsby:PERSON
# two:CARDINAL
# third:ORDINAL
# a minute:TIME
# two:CARDINAL
# dozen:CARDINAL
# England:GPE
# the beginning of each season, spring and:DATE
# one:CARDINAL
# one:CARDINAL
# indian:NORP
# Daisy:PERSON
# midsummer:DATE
# Gatsby:PERSON
# Gatsby:PERSON
# all night:TIME
# Daisy:PERSON
# Daisy:PERSON
# half:CARDINAL
# Dan Cody:PERSON
# years ago:DATE
# Gatsby:PERSON
# Gatsby:PERSON
# about eighteen:DATE
# Daisy:PERSON
# Gatsby:PERSON
# Gatsby:PERSON
# Detroit:GPE
# Daisy:PERSON
# Gatsby:PERSON
# Klipspringer:PERSON
# Ewing:PERSON
# a few minutes:TIME
# Daisy:PERSON
# Klipspringer:PERSON
# Klipspringer:PERSON
# Gatsby:PERSON
# Ewing:PERSON
# Gatsby:PERSON
# Gatsby:PERSON
# Daisy:PERSON
# Klipspringer:ORG
# The Love Nest:WORK_OF_ART
# Gatsby:PERSON
# Gatsby:PERSON
# the morning:TIME
# the evening:TIME
# West Egg:LOC
# New
# York:GPE
# the hour:TIME
# One:CARDINAL
# Gatsby:PERSON
# five years:DATE
# Daisy:PERSON
# Daisy:PERSON
# Gatsby:PERSON
# New York:GPE
# one
# morning:TIME
# Gatsby:PERSON
# Gatsby:PERSON
# five minutes:TIME
# Gatsby:PERSON
# Gatsby:PERSON
# hundreds:CARDINAL
# all
# :DATE
# summer:DATE
# Canada:GPE
# Long Island:LOC
# James Gatz:PERSON
# North Dakota:GPE
# James Gatz:PERSON
# the age of seventeen:DATE
# Dan Cody’s:PERSON
# Lake Superior:LOC
# James Gatz:PERSON
# that afternoon:TIME
# green jersey:GPE
# Jay
# Gatsby:PERSON
# Tuolomee:ORG
# Cody:PERSON
# half an
# hour:PERCENT
# Jay Gatsby:PERSON
# West Egg:GPE
# Long Island:GPE
# Platonic:ORG
# Jay Gatsby:PERSON
# seventeen-year-old:DATE
# over a year:DATE
# half:CARDINAL
# half:CARDINAL
# the bracing
# days:DATE
# night:TIME
# some months before:DATE
# Lutheran College:ORG
# St. Olaf’s:ORG
# Minnesota:GPE
# two weeks:DATE
# the
# day:DATE
# Dan Cody’s:PERSON
# Cody:PERSON
# fifty years old:DATE
# Nevada:GPE
# Yukon:ORG
# seventy-five:CARDINAL
# Montana:GPE
# Ella Kaye:PERSON
# 1902:DATE
# five years:DATE
# James Gatz’s:PERSON
# Girl Bay:LOC
# Gatz:PERSON
# Cody:PERSON
# Cody:PERSON
# one:CARDINAL
# A few days later:DATE
# Duluth:ORG
# six:CARDINAL
# Tuolomee:ORG
# the West Indies:GPE
# Barbary Coast:GPE
# Gatsby:PERSON
# Cody:PERSON
# Dan Cody:PERSON
# Dan Cody:PERSON
# Gatsby:PERSON
# five
# years:DATE
# three:CARDINAL
# Continent:LOC
# Ella Kaye:PERSON
# one night:TIME
# Boston:GPE
# a week later:DATE
# Dan Cody:PERSON
# Gatsby:PERSON
# one:CARDINAL
# American:NORP
# Eastern:NORP
# Cody:PERSON
# Gatsby:PERSON
# Cody:PERSON
# twenty-five
# thousand dollars:MONEY
# Ella Kaye:PERSON
# Jay Gatsby:PERSON
# first:ORDINAL
# Gatsby:PERSON
# several
# weeks:DATE
# New York:GPE
# Jordan:PERSON
# one Sunday:DATE
# afternoon:TIME
# two minutes:TIME
# Tom
# Buchanan:PERSON
# three:CARDINAL
# Tom:PERSON
# Sloane:PERSON
# Gatsby:PERSON
# just a minute:TIME
# Tom:PERSON
# Sloane:PERSON
# Gatsby:PERSON
# Tom:PERSON
# Buchanan:PERSON
# Tom:PERSON
# About two weeks ago:DATE
# Nick:PERSON
# Gatsby:PERSON
# Tom:PERSON
# Nick:PERSON
# Sloane:PERSON
# two:CARDINAL
# Gatsby:PERSON
# Sloane:PERSON
# Gatsby:PERSON
# Tom:PERSON
# New York:GPE
# Sloane:PERSON
# Gatsby:PERSON
# Sloane:PERSON
# Gatsby:PERSON
# Sloane:PERSON
# Gatsby:PERSON
# just a minute:TIME
# Sloane:PERSON
# Tom:PERSON
# Daisy:PERSON
# these days:DATE
# Sloane:PERSON
# Sloane:PERSON
# Tom:PERSON
# Tom:PERSON
# August:DATE
# Gatsby:PERSON
# Tom:PERSON
# Daisy:PERSON
# Saturday:DATE
# night:TIME
# Gatsby:PERSON
# Gatsby:PERSON
# summer:DATE
# West Egg:LOC
# second:ORDINAL
# Daisy:PERSON
# hundreds:CARDINAL
# Daisy:PERSON
# Nick:PERSON
# Gatsby:PERSON
# Tom:PERSON
# Gatsby:PERSON
# Tom
# :PERSON
# Daisy:PERSON
# Daisy:PERSON
# Buchanan:PERSON
# Buchanan:PERSON
# the polo player:WORK_OF_ART
# Tom:PERSON
# Gatsby:PERSON
# Tom:PERSON
# evening:TIME
# Daisy:PERSON
# Gatsby:PERSON
# Tom:PERSON
# Daisy:PERSON
# Gatsby:PERSON
# half an hour:TIME
# Tom:PERSON
# Daisy:PERSON
# the half-hour:TIME
# Gatsby:PERSON
# Gatsby:PERSON
# only two
# weeks before:DATE
# Baedeker:PERSON
# Wha’:WORK_OF_ART
# Daisy:PERSON
# tomorrow:DATE
# Baedeker:PERSON
# five:CARDINAL
# Doc Civet:PERSON
# Miss
# Baedeker:PERSON
# New Jersey:GPE
# Civet:PERSON
# Daisy:PERSON
# Star:WORK_OF_ART
# moonlight between:WORK_OF_ART
# one:CARDINAL
# Daisy:PERSON
# West Egg:GPE
# Broadway:FAC
# Long Island:GPE
# ten square feet
# :QUANTITY
# Gatsby:PERSON
# Tom:PERSON
# Not Gatsby:WORK_OF_ART
# Daisy:PERSON
# Tom:PERSON
# Daisy:PERSON
# Daisy:PERSON
# Tom:PERSON
# Nick:PERSON
# Daisy:PERSON
# Three:CARDINAL
# that year:DATE
# Gatsby:PERSON
# hours:TIME
# one:CARDINAL
# Gatsby:PERSON
# five years:DATE
# Gatsby:PERSON
# Daisy:PERSON
# Tom:PERSON
# four years:DATE
# One:CARDINAL
# Louisville:GPE
# five
# years ago:DATE
# hours:TIME
# Daisy:PERSON
# One autumn night:TIME
# five years before:DATE
# a cool night:TIME
# two:CARDINAL
# the year:DATE
# Gatsby:PERSON
# Daisy:PERSON
# Gatsby:PERSON
# Saturday:DATE
# night:TIME
# as obscurely as:CARDINAL
# Trimalchio:ORG
# just a minute:TIME
# Gatsby:PERSON
# Carraway:PERSON
# Carraway:ORG
# Carraway:PERSON
# Finn:PERSON
# Gatsby:PERSON
# a week ago:DATE
# half a dozen:CARDINAL
# West Egg:LOC
# Next day:DATE
# Gatsby:PERSON
# Daisy:PERSON
# Wolfshiem:ORG
# Daisy:PERSON
# tomorrow:DATE
# Baker:PERSON
# Half an hour:TIME
# Daisy
# :PERSON
# Gatsby:PERSON
# The next day:DATE
# the summer:DATE
# the National Biscuit Company:ORG
# noon:TIME
# Buchanans:NORP
# Gatsby:PERSON
# The master’s:WORK_OF_ART
# this
# :TIME
# noon:TIME
# Madame:WORK_OF_ART
# Daisy:PERSON
# Jordan:PERSON
# Jordan:PERSON
# Thomas Buchanan:PERSON
# Gatsby:PERSON
# Daisy:PERSON
# Jordan:PERSON
# Tom:PERSON
# Daisy:PERSON
# Tom:PERSON
# Gatsby:PERSON
# Nick:PERSON
# Daisy:PERSON
# Gatsby:PERSON
# Jordan:GPE
# Daisy:PERSON
# Nick:PERSON
# Daisy:PERSON
# Bles-sed:WORK_OF_ART
# The bles-sed:WORK_OF_ART
# Gatsby:PERSON
# Daisy:PERSON
# Aunt Jordan’s:WORK_OF_ART
# Daisy:PERSON
# Gatsby:PERSON
# Where’s Daddy:WORK_OF_ART
# Daisy:PERSON
# Daisy:PERSON
# Pammy:PERSON
# Goodbye:WORK_OF_ART
# Tom:PERSON
# four:CARDINAL
# Gatsby:PERSON
# every year:DATE
# Tom
# :PERSON
# a minute:TIME
# every year:DATE
# Gatsby:PERSON
# one:CARDINAL
# Gatsby:PERSON
# Tom:PERSON
# about an hour:TIME
# this afternoon:TIME
# Daisy:PERSON
# the
# day:DATE
# the next thirty years:DATE
# Jordan:PERSON
# the fall:DATE
# Daisy:PERSON
# Tom:PERSON
# to
# Gatsby:PERSON
# first:ORDINAL
# Daisy:PERSON
# Gatsby:PERSON
# Tom Buchanan:PERSON
# Gatsby:PERSON
# Daisy:PERSON
# Tom:PERSON
# Gatsby:PERSON
# one:CARDINAL
# Daisy:PERSON
# first:ORDINAL
# Jordan:GPE
# three:CARDINAL
# Gatsby:PERSON
# Tom:PERSON
# Gatsby:PERSON
# About a quarter:CARDINAL
# Tom:PERSON
# Daisy:PERSON
# Tom:PERSON
# Gatsby:PERSON
# Tom:PERSON
# Daisy:PERSON
# Jordan:GPE
# Gatsby:PERSON
# Tom.:PERSON
# Gatsby:PERSON
# Tom:PERSON
# Daisy:PERSON
# Tom
# :PERSON
# Gatsby:PERSON
# Come on, Daisy:WORK_OF_ART
# Tom:PERSON
# Gatsby:PERSON
# Nick:PERSON
# Jordan:GPE
# Gatsby:PERSON
# Jordan
# :PERSON
# Tom:PERSON
# Gatsby:PERSON
# Tom:PERSON
# Tom.:PERSON
# Jordan:PERSON
# second:ORDINAL
# ’d:CARDINAL
# Jordan:PERSON
# Gatsby:PERSON
# Gatsby:PERSON
# Oxford:ORG
# Jordan:PERSON
# Oxford:ORG
# Oxford:ORG
# Oxford:ORG
# New Mexico:GPE
# Tom:PERSON
# Tom:PERSON
# Jordan:PERSON
# Daisy:PERSON
# Gatsby:PERSON
# Tom:PERSON
# Jordan:PERSON
# Tom:PERSON
# Wilson:ORG
# Tom:PERSON
# Wilson:PERSON
# Tom:PERSON
# Wilson:PERSON
# Tom:PERSON
# last week:DATE
# Wilson:PERSON
# Wilson:PERSON
# Tom:PERSON
# ten years:DATE
# Tom:PERSON
# the last two days:DATE
# Wilson:PERSON
# twenty:CARDINAL
# Tom:PERSON
# Myrtle:GPE
# Tom:PERSON
# less than an hour:TIME
# Wilson:PERSON
# Tom:PERSON
# tomorrow:DATE
# afternoon:TIME
# afternoon:TIME
# one:CARDINAL
# Myrtle Wilson:PERSON
# one:CARDINAL
# Myrtle
# Wilson’s:ORG
# Tom:PERSON
# Jordan Baker:PERSON
# Tom:PERSON
# an hour ago:TIME
# Daisy:PERSON
# Wilson:PERSON
# Astoria:GPE
# fifty miles:QUANTITY
# hour:TIME
# Fiftieth Street:FAC
# Jordan:PERSON
# New York:GPE
# summer afternoons:TIME
# Tom:PERSON
# Daisy
# :PERSON
# two:CARDINAL
# Tom:PERSON
# Central Park:LOC
# the Plaza Hotel:FAC
# Daisy:PERSON
# five:CARDINAL
# four
# o’clock:DATE
# Jordan:PERSON
# Daisy:PERSON
# Tom:PERSON
# ten:CARDINAL
# Gatsby:PERSON
# one:CARDINAL
# Jordan:PERSON
# me”—but:PERSON
# Gatsby:PERSON
# Tom:PERSON
# ’d:CARDINAL
# Tom:PERSON
# Daisy:PERSON
# a minute:TIME
# Tom:PERSON
# Mendelssohn’s:PERSON
# March:DATE
# Jordan:PERSON
# the middle of June:DATE
# Daisy:PERSON
# Louisville:GPE
# June:DATE
# Tom:PERSON
# Biloxi:GPE
# Biloxi:GPE
# Biloxi:GPE
# Biloxi:GPE
# Tennessee:GPE
# Jordan:PERSON
# two:CARDINAL
# three weeks:DATE
# Daddy
# :PERSON
# The day:DATE
# a Bill Biloxi:PERSON
# Memphis:GPE
# today:DATE
# Daisy:PERSON
# ’d:CARDINAL
# Biloxi:GPE
# Jordan:PERSON
# Tom:PERSON
# Biloxi:GPE
# Daisy’s:ORG
# Louisville:GPE
# Asa
# Bird:ORG
# the last minute:TIME
# Jordan:PERSON
# Yale:ORG
# Tom:PERSON
# Biloxi:GPE
# First:ORDINAL
# Gatsby:PERSON
# Tom eyed:PERSON
# Gatsby:PERSON
# Oxford:ORG
# Oxford:ORG
# Tom:PERSON
# Biloxi:GPE
# New Haven:GPE
# Gatsby:PERSON
# nineteen-nineteen:DATE
# five months:DATE
# Oxford:ORG
# Tom:PERSON
# Gatsby:PERSON
# England:GPE
# France:GPE
# one:CARDINAL
# Tom:PERSON
# a minute:TIME
# Tom:PERSON
# Gatsby:PERSON
# one:CARDINAL
# Gatsby:PERSON
# Gatsby:PERSON
# Daisy:PERSON
# one:CARDINAL
# Tom:PERSON
# Nobody:PERSON
# Jordan:PERSON
# Gatsby:PERSON
# Daisy
# :PERSON
# Tom:PERSON
# Gatsby:PERSON
# Gatsby:PERSON
# Tom:PERSON
# Gatsby:PERSON
# Jordan:PERSON
# Tom:PERSON
# Gatsby:PERSON
# Daisy:PERSON
# Tom:PERSON
# Gatsby:PERSON
# five
# years:DATE
# Tom:PERSON
# Daisy:PERSON
# five years:DATE
# Gatsby:PERSON
# Tom:PERSON
# five
# years ago:DATE
# Daisy:PERSON
# a mile:QUANTITY
# Daisy
# :PERSON
# Gatsby:PERSON
# Daisy:PERSON
# Daisy:PERSON
# Chicago:GPE
# Gatsby:PERSON
# Daisy:PERSON
# Jordan:GPE
# Kapiolani:GPE
# Tom:PERSON
# the Punch Bowl:FAC
# Daisy:PERSON
# Gatsby:PERSON
# Jay:PERSON
# Gatsby:PERSON
# Gatsby:PERSON
# Tom:PERSON
# Daisy:PERSON
# Gatsby:PERSON
# Daisy:PERSON
# Tom:PERSON
# Tom.:PERSON
# Gatsby:PERSON
# Tom:PERSON
# Daisy’s:WORK_OF_ART
# Tom:PERSON
# Gatsby:PERSON
# Daisy:PERSON
# Tom:PERSON
# Meyer Wolfshiem:PERSON
# tomorrow:DATE
# Gatsby:PERSON
# Wolfshiem:ORG
# Chicago:GPE
# one:CARDINAL
# first:ORDINAL
# Gatsby:PERSON
# Walter
# Chase:PERSON
# New Jersey:GPE
# Walter:PERSON
# Tom:PERSON
# Gatsby:PERSON
# Walter:PERSON
# Gatsby:PERSON
# Tom:PERSON
# Walter:PERSON
# Daisy:PERSON
# Gatsby:PERSON
# Jordan:GPE
# Gatsby:PERSON
# Daisy:PERSON
# afternoon:TIME
# Tom:PERSON
# two:CARDINAL
# Daisy:PERSON
# Tom:PERSON
# Gatsby:PERSON
# Tom:PERSON
# Tom:PERSON
# Jordan:PERSON
# Nick:PERSON
# Nick:PERSON
# today:DATE
# thirty:DATE
# a
# new decade:DATE
# seven o’clock:TIME
# Long Island:GPE
# Tom:PERSON
# Jordan:GPE
# Thirty:CARDINAL
# a decade:DATE
# Jordan:PERSON
# Daisy:PERSON
# thirty:CARDINAL
# Greek:NORP
# Michaelis:PERSON
# George Wilson:PERSON
# Michaelis:PERSON
# Wilson:PERSON
# Wilson:PERSON
# the day after tomorrow:DATE
# Michaelis:PERSON
# four years:DATE
# Wilson:PERSON
# Michaelis:PERSON
# Wilson
# :PERSON
# certain days:DATE
# Michaelis:PERSON
# a little after seven:DATE
# Wilson:PERSON
# Mavro Michaelis:PERSON
# first:ORDINAL
# New York:GPE
# a hundred yards:QUANTITY
# Myrtle Wilson:PERSON
# Michaelis:PERSON
# first:ORDINAL
# a little at:MONEY
# three or four:CARDINAL
# Tom:PERSON
# Tom:PERSON
# a minute:TIME
# Jordan:PERSON
# Myrtle Wilson’s:PERSON
# the hot night:TIME
# Tom:PERSON
# first:ORDINAL
# Wilson:PERSON
# Wilson:PERSON
# Tom:PERSON
# Tom:PERSON
# Tom:PERSON
# Tom:PERSON
# two:CARDINAL
# Michaelis:PERSON
# one:CARDINAL
# One:CARDINAL
# one:CARDINAL
# thirty or forty miles
# :QUANTITY
# forty:DATE
# fifty:CARDINAL
# Wilson:ORG
# Tom:PERSON
# Wilson:PERSON
# Wilson:ORG
# Tom:PERSON
# Tom:PERSON
# Tom:PERSON
# a minute
# ago:TIME
# New York:GPE
# this afternoon:TIME
# all afternoon:TIME
# Tom:PERSON
# Tom:PERSON
# New York:GPE
# Wilson:PERSON
# Tom:PERSON
# two:CARDINAL
# Tom:PERSON
# half an hour ago:TIME
# Tom:PERSON
# Buchanans:NORP
# Tom:PERSON
# second:ORDINAL
# two:CARDINAL
# Daisy:PERSON
# West Egg:GPE
# Nick:PERSON
# tonight:TIME
# Jordan:PERSON
# Jordan:PERSON
# Nick:PERSON
# Jordan
# :PERSON
# one day:DATE
# Jordan:PERSON
# a few minutes:TIME
# house:ORG
# twenty yards:QUANTITY
# Gatsby:PERSON
# between two:CARDINAL
# Wolfshiem:WORK_OF_ART
# a minute:TIME
# Daisy:PERSON
# Daisy:PERSON
# West Egg:LOC
# Wilson:PERSON
# Was Daisy:WORK_OF_ART
# New York:GPE
# a minute:TIME
# Daisy:PERSON
# second:ORDINAL
# tomorrow:DATE
# this afternoon:TIME
# All night:TIME
# Tom:PERSON
# Daisy
# :PERSON
# two:CARDINAL
# three:CARDINAL
# Daisy:PERSON
# June night:TIME
# three months before:DATE
# Daisy:PERSON
# Tom:PERSON
# two:CARDINAL
# Gatsby:PERSON
# Daisy:PERSON
# all night:TIME
# half:CARDINAL
# Gatsby:PERSON
# morning:TIME
# about four o’clock
# :PERCENT
# a minute:TIME
# many days:DATE
# two:CARDINAL
# French:NORP
# Atlantic City:GPE
# Montreal:GPE
# Daisy:PERSON
# this night:TIME
# Dan Cody:PERSON
# Jay Gatsby:PERSON
# Tom:PERSON
# Daisy:PERSON
# first:ORDINAL
# first:ORDINAL
# Camp Taylor:PERSON
# Daisy:PERSON
# year:DATE
# Daisy:PERSON
# Jay Gatsby:PERSON
# Daisy:PERSON
# October:DATE
# night:TIME
# millions:CARDINAL
# Daisy:PERSON
# Daisy:PERSON
# Gatsby:PERSON
# two days later:DATE
# Gatsby:PERSON
# Gatsby:PERSON
# Daisy:PERSON
# every minute:TIME
# the last afternoon:TIME
# Daisy:PERSON
# the next day:DATE
# their month:DATE
# one:CARDINAL
# Argonne:ORG
# the
# armistice:LAW
# Oxford:ORG
# Daisy:PERSON
# Daisy:PERSON
# the year:DATE
# All night:TIME
# Beale Street Blues:WORK_OF_ART
# a hundred:CARDINAL
# Daisy:PERSON
# the
# season:DATE
# half a dozen:CARDINAL
# half a dozen:CARDINAL
# evening:TIME
# the middle of spring:DATE
# Tom
# Buchanan:PERSON
# Daisy:PERSON
# Gatsby:PERSON
# Oxford:ORG
# Long Island:LOC
# lovely day:DATE
# Gatsby:PERSON
# this afternoon:TIME
# a minute:TIME
# first:ORDINAL
# France:GPE
# Tom:PERSON
# Daisy:PERSON
# Louisville:GPE
# a week:DATE
# November:DATE
# Daisy:PERSON
# day:DATE
# a minute:TIME
# nine o’clock:TIME
# the last one of
# :DATE
# Gatsby:PERSON
# today:DATE
# Gatsby:PERSON
# today:DATE
# Gatsby:PERSON
# all summer:DATE
# Twelve minutes:TIME
# Gatsby:PERSON
# about noon:TIME
# First:ORDINAL
# three months before:DATE
# Goodbye:WORK_OF_ART
# Gatsby:PERSON
# Just before noon:TIME
# Jordan Baker:PERSON
# this hour:TIME
# this morning:TIME
# Daisy:PERSON
# Hempstead:GPE
# Southampton:GPE
# this afternoon:TIME
# Daisy:PERSON
# last night:TIME
# Southampton:GPE
# this
# :TIME
# afternoon:TIME
# this afternoon:TIME
# this afternoon:TIME
# Gatsby:PERSON
# a few minutes later:TIME
# four:CARDINAL
# Detroit:GPE
# three-fifty:CARDINAL
# just noon:TIME
# Myrtle Wilson’s:PERSON
# Catherine:PERSON
# long after midnight:TIME
# George Wilson:PERSON
# Michaelis
# :PERSON
# first:ORDINAL
# four:CARDINAL
# five:CARDINAL
# two:CARDINAL
# three:CARDINAL
# Michaelis:PERSON
# fifteen minutes:TIME
# Wilson:PERSON
# Wilson:ORG
# a couple of months ago:DATE
# Michaelis:PERSON
# George:PERSON
# a minute:TIME
# Twelve years:DATE
# George:PERSON
# Michaelis:PERSON
# a few hours before:TIME
# morning:TIME
# Wilson:ORG
# George:PERSON
# George:PERSON
# George:PERSON
# half:CARDINAL
# half:CARDINAL
# Michaelis:PERSON
# Wilson:PERSON
# yesterday:DATE
# afternoon:TIME
# Michaelis:PERSON
# Wilson:PERSON
# dozen:CARDINAL
# Wilson:PERSON
# Myrtle:GPE
# Wilson:PERSON
# George:PERSON
# morning:TIME
# George:PERSON
# Wilson:PERSON
# Michaelis:PERSON
# Wilson:PERSON
# Wilson:PERSON
# Michaelis:PERSON
# George:PERSON
# Wilson:PERSON
# a little later:DATE
# About five o’clock:TIME
# Michaelis:PERSON
# night:TIME
# Wilson:PERSON
# Michaelis:PERSON
# Wilson
# :PERSON
# six o’clock:DATE
# Michaelis:PERSON
# the night before:TIME
# three:CARDINAL
# Wilson:PERSON
# Michaelis:PERSON
# four hours later:TIME
# Wilson:ORG
# Port Roosevelt:PERSON
# Gad’s Hill:ORG
# Gad’s Hill:ORG
# noon:TIME
# three hours:TIME
# Michaelis:GPE
# half-past two:DATE
# West Egg:GPE
# Gatsby:PERSON
# Gatsby:PERSON
# two o’clock Gatsby:TIME
# the summer:DATE
# Gatsby:PERSON
# four o’clock:TIME
# Gatsby:PERSON
# Wolfshiem:ORG
# Gatsby:PERSON
# first:ORDINAL
# four:CARDINAL
# one:CARDINAL
# Gatsby:PERSON
# Wilson:ORG
# two years:DATE
# that day:DATE
# the next day:DATE
# Gatsby:PERSON
# madman:WORK_OF_ART
# Wilson:ORG
# that afternoon:TIME
# next morning:TIME
# Michaelis:PERSON
# Wilson:ORG
# Catherine:PERSON
# Gatsby:PERSON
# Wilson:PERSON
# Gatsby:PERSON
# West Egg:GPE
# first:ORDINAL
# hour upon hour:TIME
# Daisy:PERSON
# Tom:PERSON
# early that afternoon:TIME
# Gatsby:PERSON
# Meyer Wolfshiem’s:PERSON
# Broadway:FAC
# five:DATE
# three:CARDINAL
# Gatsby:PERSON
# Dan Cody:PERSON
# New York:GPE
# Wolfshiem:ORG
# Daisy:PERSON
# noon:TIME
# Wolfshiem:PERSON
# Wolfshiem:ORG
# Gatsby
# :PERSON
# Carraway:PERSON
# Edgar:PERSON
# Meyer Wolfshiem:PERSON
# that afternoon:TIME
# Long Distance:ORG
# Chicago:GPE
# Daisy:PERSON
# Slagle:PERSON
# Young Parke’s:WORK_OF_ART
# New
# York:GPE
# just five minutes:TIME
# Gatsby:PERSON
# Gatsby:PERSON
# the third day:DATE
# Henry C. Gatz:PERSON
# Minnesota:GPE
# Gatsby:PERSON
# September day:DATE
# Chicago:GPE
# Chicago:GPE
# Carraway:ORG
# Jimmy:PRODUCT
# Gatz:PERSON
# Gatsby:PERSON
# Gatz:PERSON
# Gatz:PERSON
# Jimmy:PRODUCT
# East:LOC
# East:LOC
# James J.
# Hill:PERSON
# Carraway:PERSON
# Klipspringer:PERSON
# Gatsby:PERSON
# tomorrow:DATE
# Three o’clock:TIME
# a minute:TIME
# Greenwich:GPE
# tomorrow:DATE
# Gatsby:PERSON
# Gatsby:PERSON
# Gatsby:PERSON
# New York:GPE
# Meyer
# Wolfshiem:ORG
# The
# Swastika Holding Company:WORK_OF_ART
# first:ORDINAL
# Jewess
# :ORG
# Wolfshiem:PERSON
# Chicago:GPE
# first:ORDINAL
# The Rosary:WORK_OF_ART
# Carraway:PERSON
# Chicago:GPE
# Wolfshiem’s:ORG
# Stella:WORK_OF_ART
# Chicago:GPE
# Chicago:GPE
# Gatsby:PERSON
# Meyer Wolfshiem:PERSON
# first:ORDINAL
# First:ORDINAL
# Winebrenner:PERSON
# Forty-third:DATE
# a couple of days:DATE
# more than four dollars:MONEY
# half an hour:TIME
# Oggsford:ORG
# the American Legion:ORG
# Albany:GPE
# two:CARDINAL
# World’s Series:EVENT
# 1919:DATE
# this afternoon:TIME
# West
# Egg:ORG
# Gatz:PERSON
# Jimmy:WORK_OF_ART
# Jimmy:WORK_OF_ART
# two years ago:DATE
# another
# minute:TIME
# lingeringly:ORG
# Hopalong
# Cassidy:PRODUCT
# the date September:DATE
# 12, 1906:DATE
# 6:00      a.m.:TIME
# 6:15-6:30:TIME
# 7:15-8:15:CARDINAL
# 8:30-4:30 p.m.:TIME
# 4:30-5:00:TIME
# 5:00-6:00:TIME
# 7:00-9:00:TIME
# Shafters:WORK_OF_ART
# one:CARDINAL
# week:DATE
# 5.00:MONEY
# 3.00:MONEY
# Jimmy:WORK_OF_ART
# Lutheran:GPE
# Gatsby:PERSON
# half an hour:TIME
# five o’clock:TIME
# three:CARDINAL
# Gatz:PERSON
# five:CARDINAL
# West Egg:GPE
# Gatsby:PERSON
# Gatsby:PERSON
# one night:TIME
# three months
# before:DATE
# Gatsby:PERSON
# Gatsby:PERSON
# that
# Daisy:PERSON
# hundreds:CARDINAL
# One:CARDINAL
# Christmas:DATE
# Chicago:GPE
# Union Station:ORG
# six o’clock of a
# December:TIME
# evening:TIME
# Chicago:GPE
# Chicago:GPE
# Milwaukee:GPE
# St. Paul:GPE
# Christmas:DATE
# Wisconsin:GPE
# one strange hour:TIME
# Middle West:LOC
# Swede:NORP
# those long winters:DATE
# Carraway:PERSON
# decades:DATE
# West:LOC
# Tom:PERSON
# Gatsby:PERSON
# Daisy:PERSON
# Jordan:PERSON
# Westerners:NORP
# Eastern:ORG
# East:LOC
# Ohio:GPE
# West Egg:GPE
# El Greco:GPE
# a hundred:CARDINAL
# four:CARDINAL
# a white evening:TIME
# no one:CARDINAL
# Gatsby:PERSON
# East:LOC
# one:CARDINAL
# Jordan Baker:PERSON
# just a minute:TIME
# Jordan:PERSON
# five years:DATE
# half:CARDINAL
# One afternoon:TIME
# October:DATE
# Tom Buchanan:PERSON
# Fifth Avenue:FAC
# Nick:PERSON
# Nick:PERSON
# Tom:PERSON
# Wilson:PERSON
# afternoon:TIME
# every minute:TIME
# Daisy’s:ORG
# Tom:PERSON
# Daisy:PERSON
# Gatsby:PERSON
# One:CARDINAL
# a minute:TIME
# Daisy:PERSON
# Gatsby:PERSON
# East Egg:FAC
# Saturday:DATE
# nights:TIME
# New York:GPE
# One night:TIME
# the last night:TIME
# Dutch:NORP
# Gatsby:PERSON
# Gatsby:PERSON
# first:ORDINAL
# the end of
# Daisy’s:DATE
# under the night:TIME
# Gatsby:PERSON
# tomorrow:DATE
# one fine morning:TIME
# U.S.:GPE
# United States:GPE
# Foundation:ORG
# the
# United States:DATE
# Gutenberg:PERSON
# Gutenberg:PERSON
# eBook:EVENT
# Gutenberg eBooks:PERSON
# the United States:GPE
# U.S.:GPE
# Project
# Gutenberg:WORK_OF_ART
# Gutenberg-tm License:ORG
# 1:CARDINAL
# Gutenberg-tm:ORG
# Gutenberg-tm:PERSON
# Gutenberg-tm electronic:ORG
# 1.E.8:CARDINAL
# Gutenberg:WORK_OF_ART
# a few:CARDINAL
# Literary Archive Foundation:ORG
# the
# Foundation:WORK_OF_ART
# PGLAF:ORG
# Gutenberg-tm:PERSON
# the United
# States:GPE
# United States:GPE
# the United States:GPE
# Gutenberg:PERSON
# Gutenberg-tm:PERSON
# Gutenberg-tm:ORG
# Gutenberg-tm License:ORG
# the United States:GPE
# Foundation:ORG
# the United States:GPE
# Gutenberg:PERSON
# Gutenberg-tm License:ORG
# Project Gutenberg:WORK_OF_ART
# Gutenberg:WORK_OF_ART
# eBook:EVENT
# the United States:GPE
# the Project Gutenberg License:ORG
# www.gutenberg.org:ORG
# the
#   United States:GPE
# eBook:PRODUCT
# 1.E.2:CARDINAL
# U.S.:GPE
# the United States:GPE
# Project
# Gutenberg:WORK_OF_ART
# 1.E.8:CARDINAL
# 1.E.4:CARDINAL
# Gutenberg-tm
# License:ORG
# paragraph 1.E.1:DATE
# Gutenberg-tm License:ORG
# 1.E.6:CARDINAL
# Gutenberg-tm web:ORG
# www.gutenberg.org:ORG
# Gutenberg-tm License:ORG
# 1.E.1:CARDINAL
# 1.E.8:CARDINAL
# 1.E.8:CARDINAL
# Gutenberg-tm:PERSON
# 20%:PERCENT
# Literary Archive Foundation:ORG
# 60 days:DATE
# Literary Archive Foundation:ORG
# 30 days:DATE
# Gutenberg-tm
#   License:PERSON
# Gutenberg-tm
#   :PERSON
# 1.F.3:CARDINAL
# 90 days:DATE
# Gutenberg-tm:PERSON
# Literary Archive Foundation:ORG
# Section 3:LAW
# 1.F.:CARDINAL
# 1.F.1:CARDINAL
# Gutenberg:PERSON
# U.S.:GPE
# Gutenberg-tm:ORG
# 1.F.2:CARDINAL
# 1.F.3:CARDINAL
# Gutenberg Literary Archive Foundation:ORG
# 90 days:DATE
# second:ORDINAL
# second:ORDINAL
# 1.F.3:CARDINAL
# EXPRESS:ORG
# 1.F.5:CARDINAL
# 1.F.6:ORG
# Foundation:ORG
# Foundation:ORG
# Gutenberg-tm:PERSON
# the Mission of Project:ORG
# Gutenberg-tm:PERSON
# Gutenberg-tm:ORG
# hundreds:CARDINAL
# Gutenberg-tm's:PERSON
# 2001:DATE
# Gutenberg Literary Archive Foundation:ORG
# Gutenberg Literary:PERSON
# Foundation:ORG
# 3:CARDINAL
# Gutenberg Literary:PERSON
# Literary Archive Foundation:ORG
# 501(c)(3:CARDINAL
# Mississippi:GPE
# the Internal
# Revenue Service:ORG
# Foundation:ORG
# EIN:ORG
# 64-6221541:DATE
# Gutenberg Literary:PERSON
# U.S.:GPE
# Foundation:ORG
# 809:CARDINAL
# North 1500:LOC
# Salt Lake City:GPE
# 801:CARDINAL
# 596-1887:DATE
# Foundation:ORG
# www.gutenberg.org/contact
#
# Section 4:LAW
# Literary Archive Foundation:ORG
# Gutenberg-tm:ORG
# $1 to $5,000:MONEY
# IRS:ORG
# Foundation:ORG
# 50:CARDINAL
# the United
# States:GPE
# the United States:GPE
# U.S.:GPE
# Gutenberg-tm:PERSON
# Michael S. Hart:PERSON
# forty years:DATE
# Gutenberg-tm eBooks:ORG
# U.S.:GPE
# www.gutenberg.org:ORG
# Gutenberg-tm:PERSON
# Gutenberg Literary:PERSON
# eBooks:ORG
# eBooks:ORG

# %%
from collections import Counter
from matplotlib import figure
from matplotlib import pyplot as plt

# %%
my_dict1 = pd.DataFrame.from_dict(document1.ents) 
my_dict1 #Here I have an issue with the dictionary not translating over one for one to a pd dataframe
# Out:
#                      0         1           2     3     4     5     6     7   \
# 0             Gutenberg     eBook        None  None  None  None  None  None
# 1                   The     Great      Gatsby  None  None  None  None  None
# 2                    F.     Scott  Fitzgerald  None  None  None  None  None
# 3                 eBook      None        None  None  None  None  None  None
# 4                   the    United      States  None  None  None  None  None
# ...                 ...       ...         ...   ...   ...   ...   ...   ...
# 2531  www.gutenberg.org      None        None  None  None  None  None  None
# 2532          Gutenberg         -          tm  None  None  None  None  None
# 2533          Gutenberg  Literary        None  None  None  None  None  None
# 2534             eBooks      None        None  None  None  None  None  None
# 2535             eBooks      None        None  None  None  None  None  None
#
#         8     9     10    11    12    13
# 0     None  None  None  None  None  None
# 1     None  None  None  None  None  None
# 2     None  None  None  None  None  None
# 3     None  None  None  None  None  None
# 4     None  None  None  None  None  None
# ...    ...   ...   ...   ...   ...   ...
# 2531  None  None  None  None  None  None
# 2532  None  None  None  None  None  None
# 2533  None  None  None  None  None  None
# 2534  None  None  None  None  None  None
# 2535  None  None  None  None  None  None
#
# [2536 rows x 14 columns]

# %%
def new_dictionary(document): #This function will split the document into an organized list
    ent_text = [] #Creating an empty list to add my words to
    for entity in document1.ents:
        ent_text.append(entity.text)

    dict_ent_name = Counter(ent_text)

    return dict_ent_name

def new_dataframe(document):
    df_ent = new_dictionary(document)
    df_doc = pd.DataFrame(data = {'name' :df_ent.keys(), 'count' : df_ent.values()})
    return df_doc

my_new_dict_1 = new_dictionary(document1)
new_doc1 = new_dataframe(my_new_dict_1)
new_doc1.head(5)
sorted_Gatsby_1 = new_doc1.sort_values(by = 'count', ascending = False)
sorted_Gatsby_1_20 = sorted_Gatsby_1[:20]

# %%
def new_dictionary11(document): #Just as I did for the ent text, I will repeat for the ent_label
    ent_label11 = []
    for entity in document1.ents:
        ent_label11.append(entity.label_)

    dict_ent_name11 = Counter(ent_label11)

    return dict_ent_name11

def new_dataframe11(document):
    df_ent11 = new_dictionary11(document)
    df_doc11 = pd.DataFrame(data = {'name' :df_ent11.keys(), 'count' : df_ent11.values()})
    return df_doc11

my_new_dict_11 = new_dictionary11(document1)
new_doc11 = new_dataframe11(my_new_dict_11)
sorted_Gatsby_11 = new_doc11.sort_values(by = 'count', ascending = False)
sorted_Gatsby_11.head(20)
# Out:
#            name  count
# 1        PERSON   1073
# 6          DATE    266
# 9      CARDINAL    260
# 13         TIME    235
# 3           GPE    234
# 4           ORG    170
# 14      ORDINAL     63
# 0   WORK_OF_ART     59
# 10          LOC     55
# 12         NORP     32
# 15          FAC     26
# 7         MONEY     17
# 11     QUANTITY     17
# 5       PRODUCT     12
# 2         EVENT      6
# 16      PERCENT      6
# 17          LAW      3
# 8      LANGUAGE      2

# %%
plt.bar(sorted_Gatsby_1_20['name'], sorted_Gatsby_1_20['count'], color ='green')
fig = plt.gcf()
fig.set_size_inches(13.5, 10.5)
plt.xticks(rotation = 45)
plt.title('20 Most Common Named Entities')
plt.xlabel('Names')
plt.ylabel('Count')
xs = sorted_Gatsby_1_20['name']
ys = sorted_Gatsby_1_20['count']
for x,y in zip(xs,ys):

    label = "{:.2f}".format(y)      #I used an example I found online to assist with labeling the data points. Although not necessary, it helps with the smaller data points towards the bottom and gives context to the bars

    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') 
plt.show()

# %%
plt.bar(sorted_Gatsby_11['name'], sorted_Gatsby_11['count'], color='green')
fig = plt.gcf()
fig.set_size_inches(10.5, 10.5)
plt.xticks(rotation = 45)
plt.rcParams["figure.figsize"] = (40,3)
plt.title('Count of Entities')
plt.xlabel('Names')
plt.ylabel('Count')
xs = sorted_Gatsby_11['name']
ys = sorted_Gatsby_11['count']
for x,y in zip(xs,ys):

    label = "{:.2f}".format(y)

    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') 
plt.show()

# %% [markdown]
# ### Monty Python

# %%
document2 = nlp_lg(Path('Monty Python and the Holy Grail.txt').read_text(encoding = 'utf-8'))
for entity in document2.ents: #run through the document.ents (adding entity and label)
    print(f'{entity.text}:{entity.label_}')
# Out:
# Monty Python:PERSON
# 1975:DATE
# Graham Chapman &:ORG
# John Cleese & Eric Idle:PERSON
# Terry Gilliam:PERSON
# Michael Palin:PERSON
# 20.3.74:ORG
# MONTY PYTHON AND THE HOLY GRAIL:WORK_OF_ART
# Reel 1:LAW
# 1A:CARDINAL
# 1:CARDINAL
# first:ORDINAL
# 391.00:CARDINAL
# first:ORDINAL
# Scene 4
#
# 	 Sc				Spot
# 	 No:ORG
# 1:CARDINAL
# 00.01   :CARDINAL
# BLACK B.G.
#
# 					PYTHON:PRODUCT
# MONTY):ORG
# MICHAEL WHITE
# 			:PERSON
# THE HOLY GRAIL:WORK_OF_ART
# GRAHAM CHAPMAN
# 			:PERSON
# JOHN CLEESE
# 			ERIC:PERSON
# TERRY GILLIAM
# 			:PERSON
# TERRY JONES
# 			:PERSON
# MICHAEL PALIN:PERSON
# nik Akten Di
# :PERSON
# CAROL CLEVELAND:WORK_OF_ART
# NEIL INNES:PERSON
# JOHN YOUNG:PERSON
# RITA DAVES:PERSON
# STEWART
# 			SALLY KINGHORN
# :PERSON
# ELSPETH CAMERON
# 			MITSUKO FORSTATER:ORG
# SALLY JOHNSON
# 			SANDY:PERSON
# JONI FLNN:PERSON
# ALISON WALKER
# 			LORAINE WARD		  ANNA LANSKI
# 			SALLY COOMBE		  VIVIENNE MACDONALD
# 			YVONNE DICK		DAPHNE DARLING
# 			FIONA:ORG
# GORDON		  GLORIA GRAHAM
# 			JUDY LAMS:PERSON
# TRACY:PERSON
# SYLVIA TAYLOR:PERSON
# JOYCE POLLNER
# 			MARY ALLEN
# :PERSON
# HOWARD ATHERTON
# 				:PERSON
# JOHN WELLARD
# 			Camera:PERSON
# ROGER PRATT
# 				Camera Grip:PERSON
# Chargehand Electrician:PERSON
# ANDREW RICHIE:PERSON
# Rosturm:PERSON
# HOUSTON:GPE
# Wi n0t trei:PERSON
# Sweden:GPE
# GARTH MARSHALL
# 				Sound Mixer	HUGH:PERSON
# GODFREY KIRBY:PERSON
# PHILIP CHUBB
# 			Sound Assistant:ORG
# ROBERT DOYLE
# 			Dubbing:PERSON
# JOHN FOSTER:PERSON
# JOHN MISTER:PERSON
# NICK GASTER:PERSON
# ALEXANDER CAMPBELL ASKEW:PERSON
# BRIAN PEACHEY:PERSON
# DANIELLE KOCHAVI
# 			:PERSON
# Continuity:ORG
# EYLES
# 				Accountant:ORG
# BRIAN BROCKWELL
# 		:PERSON
# CHRISTINE WATT
# 			:PERSON
# Property Buyer:ORG
# ROY CANNON:PERSON
# CHARLIE TORBETT:PERSON
# MIKE KENNEDY
# 					:PERSON
# Art:PERSON
# PHILIP COWLAM:ORG
# NOBBY CLARK:PERSON
# BOB DEVINE
# 					:PERSON
# GRAHAM BULLOCK
# 				Stagehand:PERSON
# JIM N. SAVERY
# 					:PERSON
# mani:PERSON
# Charlie Knode:PERSON
# Brian McNully:PERSON
# John Gledhill:PERSON
# Peter
# 		Thompson:PERSON
# Sue Cable:ORG
# Valerie Charlton:PERSON
# Drew Mara:PERSON
# Sue Smith:PERSON
# Charlie Coulter:PERSON
# Iain Monaghan:PERSON
# Steve
# 		Bennell:PERSON
# Bernard Belenger:PERSON
# Alpini McAlpine:PERSON
# Hugh
# 		Boyle:ORG
# Dave Taylor:PERSON
# Garry Cooper:PERSON
# Peter Saunders:PERSON
# Sheppard:PERSON
# Vaughn Millard:PERSON
# Mamish MacInnes:PERSON
# Terry Mosaic:PERSON
# Bawn O'Beirne Ranelagh:PERSON
# Scotland:GPE
# Doune Castle:FAC
# Castle Stalker:ORG
# Killin:ORG
# Glen Coe:PERSON
# Arnhall Castle:PERSON
# Braklim:PERSON
# Sherroffmiur:PERSON
# Monty) Pictures Ltd.:ORG
# 20:CARDINAL
# Fitzroy Square:FAC
# London:GPE
# Twickenham Film Studios:ORG
# England:GPE
# 1974:DATE
# National Film Trustee Company Lt:ORG
# the Forestry Commission:ORG
# Keir:PERSON
# Cawdor Estates:PERSON
# Stirling
#   University:ORG
# Doune:PERSON
# RICHARD M. NIXON
#
# 				Including:PERSON
# NEIL INNIS
#
# 					Additional music
# 						:PERSON
# HAZEL PETHING
# :PERSON
# Karving:GPE
# t00thbrush:GPE
# Svenge:ORG
# Oslo:GPE
# Norwegian:NORP
# Oslo:GPE
# Fillings of Passion:WORK_OF_ART
# The Huge M0lars:WORK_OF_ART
# Horst
# 			Nordfink:ORG
# Mynd:PERSON
# DOYLE:ORG
# GERRY HARRISON
# 			:PERSON
# JOHN HORTON
# 			Choreography:PERSON
# Director &
# 		  Period:ORG
# JOHN WALKER
# 			:PERSON
# PAM LUKE
# 				Photography:PERSON
# LUCINDA COWELL:PERSON
# KATE HEPBURN:PERSON
# TERRY BEDFORD:PERSON
# M00se Costumes	SIGGI CHURCHILL:WORK_OF_ART
# ROY SMITH:PERSON
# HORST PROT III
# 	 :PERSON
# Taylor:PERSON
# HENGST DOUGLAS-HOME
# 	 :PERSON
# JURGEN WIGG
# :PERSON
# JOHN HACKNEY:PERSON
# IRKESTORM-SLATER WALKER
#
# 	 Large:ORG
# third:ORDINAL
# Latin:LANGUAGE
# French:NORP
# VIC ROTTER
# 			Antler:ORG
# LIV THATCHER:ORG
# the last
# 		  minute:TIME
# YELLOW B.G
# 						:ORG
# JOHN GOLDSTONE & ":PERSON
# RALPH:PERSON
# MARK FORSTARTER
#
# 			:WORK_OF_ART
# EARL J. LLAMA
# 						MIKE Q. LLAMA III
# 			SY:PERSON
# Z. LLAMA IX
# :PERSON
# 6:CARDINAL
# VENEZUELAN:NORP
# RED LLAMAS
# 					:PRODUCT
# 142:CARDINAL
# MEXICAN:NORP
# 14:CARDINAL
# NORTH CHILEAN:NORP
# LLAMA:ORG
# LLAMA-FRESH:LAW
# FARMS LTD:ORG
# PARAGUAY:GPE
# TERRY GILLIAM:PERSON
# TERRY JONES
# :PERSON
# 1:CARDINAL
# England AD 787:WORK_OF_ART
# a few more seconds:TIME
# ARTHUR:PERSON
# two half coconuts
# :CARDINAL
# ARTHUR:PERSON
# ARTHUR:PERSON
# Bodium:PERSON
# Arthur:PERSON
# Uther Pendragon:PERSON
# Camelot:ORG
# Britons:NORP
# Saxons:NORP
# England:GPE
# Patsy:PERSON
# Camelot:ORG
# two:CARDINAL
# martin:PERSON
# winter:DATE
# about eight:CARDINAL
# five ounces:QUANTITY
# five-ounce:QUANTITY
# one pound:QUANTITY
# Arthur:PERSON
# the Court of Camelot:ORG
# Velocity:PRODUCT
# four hundred and ninety three:CARDINAL
# SECOND:ORDINAL
# African:NORP
# African:NORP
# European:NORP
# Knights:ORG
# Camelot:ORG
# African:NORP
# ARTHUR:PERSON
# PATSY:ORG
# SECOND:ORDINAL
# two:CARDINAL
# 2:CARDINAL
# Terry Gilliam's:PERSON
# Brueghel:PERSON
# Wailings:ORG
# a couple of
# :MONEY
# one:CARDINAL
# four:CARDINAL
# Two:CARDINAL
# one:CARDINAL
# a few minutes:TIME
# Robinson:PERSON
# nine:CARDINAL
# today:DATE
# Thursday:DATE
# Thursday:DATE
# ARTHUR:PERSON
# PATSY:PERSON
# 3:CARDINAL
# EXTERIOR - DAY:DATE
# ARTHUR:PERSON
# PATSY:PERSON
# ARTHUR:PERSON
# PATSY:PERSON
# thirty-seven:CARDINAL
# thirty-seven:CARDINAL
# Dennis"
#
# 			ARTHUR:PERSON
# Dennis:PERSON
# Arthur:PERSON
# Britons:NORP
# Britons:ORG
# Britons:ORG
# Britons:NORP
# DENNIS:PERSON
# the week:DATE
# two-thirds:CARDINAL
# The Lady of the Lake:WORK_OF_ART
# Excalibur:ORG
# Arthur:PERSON
# Excalibur:ORG
# Frank:PERSON
# Supreme:ORG
# supreme:ORG
# PEASANTS:ORG
# DENNIS:PERSON
# patsy:PERSON
# about ...:CARDINAL
# 4:CARDINAL
# ARTHUR:PERSON
# PATSY:PERSON
# the GREEN KNIGHT's:ORG
# ARTHUR:PERSON
# PATSY:PERSON
# The GREEN KNIGHT:WORK_OF_ART
# parry:PERSON
# the GREEN KNIGHT's:PRODUCT
# ARTHUR:PERSON
# PATSY:PERSON
# The GREEN KNIGHT:WORK_OF_ART
# ARTHUR:PERSON
# the BLACK KNIGHT:FAC
# first:ORDINAL
# second:ORDINAL
# the GREEN KNIGHT:PRODUCT
# ARTHUR:PERSON
# PATSY:PERSON
# Four:CARDINAL
# ARTHUR:PERSON
# PATSY:ORG
# the GREEN KNIGHT:PRODUCT
# ARTHUR:PERSON
# PATSY:PERSON
# knight:PERSON
# the Black Knight:PRODUCT
# Arthur:PERSON
# Britons:NORP
# ARTHUR:PERSON
# Camelot:LOC
# knights ...
#
# 			BLACK KNIGHT:ORG
# knight:PERSON
# Britons:NORP
# ARTHUR:PERSON
# about fifteen seconds:TIME
# ARTHUR:ORG
# ARTHUR:PERSON
# KNIGHT:ORG
# ten seconds:TIME
# ARTHUR:PERSON
# ARTHUR
# 	Victory:WORK_OF_ART
# ARTHUR:PERSON
# ARTHUR:PERSON
# knight:PERSON
# KNIGHT:ORG
# ARTHUR:ORG
# KNIGHT:ORG
# ARTHUR:PERSON
# KNIGHT:ORG
# The Black Knight:WORK_OF_ART
# ARTHUR:PERSON
# Patsy:PERSON
# ARTHUR:PERSON
# PATSY:PERSON
# 5:CARDINAL
# EXTERIOR - DAY:DATE
# Latin:NORP
# house:ORG
# BEDEVERE:PERSON
# VILLAGER:ORG
# Witch:ORG
# BEDEVERE:ORG
# VILLAGER:ORG
# VILLAGER:ORG
# SECOND:ORDINAL
# VILLAGER:ORG
# BEDEVERE:ORG
# SECOND:ORDINAL
# VILLAGER:ORG
# ARTHUR:PERSON
# PATSY:PERSON
# Bedevere:PERSON
# Wood:ORG
# SECOND:ORDINAL
# VILLAGER:ORG
# VILLAGER:ORG
# Tie:GPE
# ARTHUR:ORG
# BEDEVERE:ORG
# VILLAGER:ORG
# Bedevere:PERSON
# a few yards:QUANTITY
# BEDEVERE:ORG
# ARTHUR:PERSON
# Two:CARDINAL
# ARTHUR:PERSON
# BEDEVERE:ORG
# Arthur:PERSON
# Britons:NORP
# ARTHUR:PERSON
# PATSY:ORG
# knight:PERSON
# Camelot:ORG
# the Round Table:FAC
# ARTHUR:ORG
# Liege:ORG
# Bedevere:PERSON
# Knight:PERSON
# 6:CARDINAL
# Arthur:PERSON
# The Round Table:WORK_OF_ART
# ARTHUR:ORG
# Knights:ORG
# 1:CARDINAL
# ARTHUR:PERSON
# PATSY:ORG
# BEDEVERE:ORG
# 2:CARDINAL
# GAWAIN:PERSON
# ARTHUR:ORG
# 3:CARDINAL
# GAWAIN:PERSON
# HECTOR:PERSON
# ARTHUR:PERSON
# 4:CARDINAL
# ROBIN:PERSON
# ARTHUR:PERSON
# ROBIN:PERSON
# ARTHUR & CO:ORG
# 5:CARDINAL
# hen-house:ORG
# 6:CARDINAL
# 7:CARDINAL
# LAUNCELOT:PERSON
# ARTHUR:ORG
# Eilean Donan:GPE
# six:CARDINAL
# 8:CARDINAL
# ARTHUR:PERSON
# PATSY:PERSON
# BEDEVERE:ORG
# PAGE:ORG
# GAWAIN:PERSON
# PAGE:ORG
# HECTOR:PERSON
# PAGE:PERSON
# GALAHAD:ORG
# PAGE:ORG
# ROBIN:PERSON
# six:CARDINAL
# LAUNCELOT:ORG
# PAGE:ORG
# 6:CARDINAL
# THE BOOK OF THE FILM
#
# 			VOICE OVER:WORK_OF_ART
# Bedevere:PERSON
# first:ORDINAL
# Arthur:PERSON
# Robin:PERSON
# the Dragon of Agnor:FAC
# Chicken of Bristol:ORG
# Page:PERSON
# the Battle of Badon Hill:FAC
# the centuries:DATE
# 7:CARDINAL
# KNIGHTS:ORG
# BEDEVERE:ORG
# ARTHUR
# :ORG
# Earth:LOC
# Bedevere:PERSON
# Camelot:ORG
# ARTHUR:PERSON
# PAGE:ORG
# Knights:ORG
# Camelot:ORG
# 8:CARDINAL
# KNIGHTS:ORG
# Camelot:ORG
# knights of:ORG
# the Round Table:WORK_OF_ART
# Camelot:ORG
# two:CARDINAL
# KNIGHTS':ORG
# Clark Gable:PERSON
# Camelot:LOC
# ARTHUR:PERSON
# BEDEVERE:ORG
# second:ORDINAL
# Camelot:LOC
# KNIGHTS:ORG
# PAGES:ORG
# ARTHUR:PERSON
# KNIGHTS
# fall:ORG
# Arthur:PERSON
# Arthur:PERSON
# Britons:NORP
# one:CARDINAL
# ARTHUR:PERSON
# Arthur:PERSON
# Knights of the Round:ORG
# Arthur:PERSON
# the Sacred Cup:EVENT
# KNIGHTS:ORG
# Arthur:PERSON
# Grail:ORG
# Arthur:PERSON
# KNIGHTS:ORG
# ARTHUR:ORG
# LAUNCELOT:ORG
# ARTHUR:PERSON
# Camelot:ORG
# The Quest For The Holy Grail:WORK_OF_ART
# 9:CARDINAL
# one:CARDINAL
# two:CARDINAL
# ARTHUR:ORG
# two:CARDINAL
# ARTHUR:PERSON
# King Arthur:PERSON
# Round:ORG
# Guy de Loimbard:PERSON
# this night:TIME
# one:CARDINAL
# BATTLEMENTS:ORG
# English:NORP
# French:LANGUAGE
# England:GPE
# Grail:WORK_OF_ART
# English:LANGUAGE
# Arthur-king:PERSON
# second:ORDINAL
# Fetchez la vache:ORG
# Fetchez la vache:ORG
# ARTHUR:ORG
# GALAHAD:ORG
# Knights!:ORG
# ARTHUR:PERSON
# Knights:ORG
# KNIGHTS:ORG
# KNIGHTS:ORG
# LAUNCELOT:ORG
# LAUNCELOT:ORG
# FRENCH:NORP
# English:NORP
# FRENCH:NORP
# night:TIME
# English:NORP
# FRENCH:NORP
# FRENCH:NORP
# FRENCH:NORP
# twenty-foot:QUANTITY
# ENGLISH:LANGUAGE
# TAUNTER:PERSON
# ARTHUR:ORG
# French:LANGUAGE
# ARTHUR:ORG
# Launcelot:ORG
# Galahad:ORG
# nightfall:TIME
# French:NORP
# Launcelot:PERSON
# Galahad:ORG
# LAUNCELOT:ORG
# ARTHUR:PERSON
# ARTHUR:PERSON
# GAWAIN:PERSON
# GAWAIN:PERSON
# 10:CARDINAL
# - DAY:DATE
# French:NORP
# Arthur:PERSON
# Arthur:PERSON
# Grail:ORG
# KNIGHT:ORG
# FRANK:PERSON
# The Tale of Sir:WORK_OF_ART
# Robin:PERSON
# The Tale Of Sir:WORK_OF_ART
# Robin:PERSON
# 11:CARDINAL
# KNIGHT:ORG
# half:CARDINAL
# thirteenth-century:DATE
# one:CARDINAL
# one:CARDINAL
# first:ORDINAL
# Robin:PERSON
# Camelot:LOC
# Robin:PERSON
# Robin:PERSON
# Robin:PERSON
# Rob:PERSON
# CAMELOT:ORG
# 43:CARDINAL
# I
# 	 CAMELOT:ORG
# 43:CARDINAL
# I
# 	 CAMELOT:ORG
# 43:CARDINAL
# 12:CARDINAL
# three:CARDINAL
# KNIGHTS:ORG
# one:CARDINAL
# three:CARDINAL
# KNIGHTS:ORG
# one:CARDINAL
# ROBIN:PERSON
# Morning:TIME
# ONE:CARDINAL
# ROBIN:PERSON
# THREE:CARDINAL
# THREE:CARDINAL
# HEADS:ORG
# Robin:PERSON
# Robin:PERSON
# THREE:CARDINAL
# HEADS:ORG
# knight:PERSON
# THREE:CARDINAL
# HEADS:ORG
# THREE:CARDINAL
# HEADS:ORG
# THREE:CARDINAL
# SECOND:ORDINAL
# SECOND:ORDINAL
# SECOND:ORDINAL
# FIRST:ORDINAL
# SECOND:ORDINAL
# One:CARDINAL
# SECOND:ORDINAL
# Oo:ORG
# SECOND:ORDINAL
# this week:DATE
# SECOND:ORDINAL
# ROBIN:PERSON
# Knight:PERSON
# one:CARDINAL
# Knight:ORG
# ROBIN:PERSON
# Dagger:WORK_OF_ART
# Mace:PERSON
# six:CARDINAL
# ROBIN:PERSON
# FIRST:ORDINAL
# one:CARDINAL
# SECOND:ORDINAL
# THIRD:ORDINAL
# FIRST:ORDINAL
# SECOND:ORDINAL
# HEADS:ORG
# PAN:ORG
# three:CARDINAL
# SECOND:ORDINAL
# Ooh:ORG
# first:ORDINAL
# SECOND:ORDINAL
# 3:CARDINAL
# 13:CARDINAL
# ROBIN:PERSON
# ROBIN:PERSON
# Robin:PERSON
# Robin:PERSON
# Robin:PERSON
# Robin:PERSON
# The Tale Of Sir Galahad:WORK_OF_ART
# 14:CARDINAL
# King Arthur:ORG
# Galahad:PERSON
# the Round Table:ORG
# the Holy Grail:PRODUCT
# GALAHAD:ORG
# 15:CARDINAL
# knight:PERSON
# O Zoot:PERSON
# Zoot:PERSON
# GALAHAD:ORG
# Galahad:PERSON
# Chaste:PERSON
# Zoot:PERSON
# Zoot:PERSON
# Galahad:PERSON
# ZOOT:PERSON
# WINSTON:PERSON
# GALAHAD:ORG
# Winston:PERSON
# Piglet:PERSON
# ZOOT:PERSON
# one:CARDINAL
# Zoot:PERSON
# Zoot:PERSON
# Dingo:ORG
# Zoot:PERSON
# Zoot:PERSON
# Zoot:PERSON
# beacon:GPE
# first:ORDINAL
# Grail:ORG
# Zoot:PERSON
# Castle Anthrax:FAC
# one:CARDINAL
# tonight:TIME
# LAUNCELOT:PERSON
# CONCORD:ORG
# GAWAIN:ORG
# Galahad:PERSON
# Galahad:PERSON
# Galahad:PERSON
# only a hundred:CARDINAL
# LAUNCELOT:ORG
# CONCORDE:PRODUCT
# nick:PERSON
# Galahad:PERSON
# LAUNCELOT:ORG
# Grail:ORG
# LAUNCELOT:ORG
# GAWAIN:ORG
# CONCORDE:PRODUCT
# LAUNCELOT:ORG
# Launcelot:PERSON
# the Holy Grail:PRODUCT
# Bedevere:ORG
# Arthur:PERSON
# night:TIME
# 16:CARDINAL
# ARTHUR:PERSON
# BEDEVERE:ORG
# woodman:PERSON
# Enchanter:PERSON
# Grail:ORG
# Grail:ORG
# The Bridge of Death:WORK_OF_ART
# Grail:ORG
# ARTHUR:PERSON
# BEDEVERE:ORG
# PATSY:ORG
# ARTHUR:PERSON
# SIX:CARDINAL
# DARKNESS:ORG
# Peng:PERSON
# John:PERSON
# Mike:PERSON
# ARTHUR:PERSON
# PATSY:PERSON
# Salopian:NORP
# - Ed:PERSON
# KNIGHT:ORG
# KNIGHT:ORG
# Peng:PERSON
# KNIGHT:ORG
# the TALL KNIGHT:PRODUCT
# Enchanter:PERSON
# KNIGHT:ORG
# Peng:PERSON
# Nee:PERSON
# Wum:GPE
# KNIGHT:ORG
# KNIGHT:ORG
# KNIGHT:ORG
# ARTHUR:PERSON
# BEDEVERE:ORG
# KNIGHTS:ORG
# Peng:PERSON
# 17:CARDINAL
# EXTERIOR - DAY:DATE
# two:CARDINAL
# PATROLMEN:ORG
# One:CARDINAL
# The Tale of Sir Launcelot:WORK_OF_ART
# 18:CARDINAL
# INTERIOR - PRINCE'S ROOM IN CASTLE - DAY:ORG
# One day:DATE
# twenty minutes:TIME
# Britain:GPE
# Alice ...:PERSON
# Herbert:PERSON
# Princess Lucky:PERSON
# TWO:CARDINAL
# One:CARDINAL
# one:CARDINAL
# 15:CARDINAL
# LAUNCELOT:ORG
# CONCORDE:PRODUCT
# Concorde:PRODUCT
# CONCORDE:PRODUCT
# LAUNCELOT:ORG
# LAUNCELOT:ORG
# Concorde:PRODUCT
# Swamp Castle:FAC
# LAUNCELOT:ORG
# Concorde:PRODUCT
# Concorde:PRODUCT
# Concorde:PRODUCT
# LAUNCELOT:ORG
# Concorde:PRODUCT
# LAUNCELOT:ORG
# 20:CARDINAL
# Two:CARDINAL
# H & L:ORG
# TWO:CARDINAL
# LAUNCELOT:ORG
# TWO:CARDINAL
# One:CARDINAL
# SENTRY:ORG
# LAUNCELOT:ORG
# LAUNCELOT:ORG
# SENTRY:ORG
# 21:CARDINAL
# EXTERIOR - DAY:DATE
# LAUNCELOT:ORG
# Errol Flynn:PERSON
# Errol Flynn:PERSON
# 22:CARDINAL
# INTERIOR - DAY:DATE
# last minute:TIME
# boar:ORG
# ATTENDANTS:ORG
# LAUNCELOT:ORG
# COOK:ORG
# LAUNCELOT:ORG
# 23:CARDINAL
# INTERIOR - DAY:DATE
# LAUNCELOT:PERSON
# LAUNCELOT:ORG
# Hiccoughs:ORG
# LAUNCELOT:ORG
# Launcelot:PERSON
# the Court of Camelot:ORG
# first:ORDINAL
# LAUNCELOT:PERSON
# half:CARDINAL
# Launcelot:PERSON
# fifty pounds:MONEY
# Launcelot:PERSON
# eight:CARDINAL
# half:CARDINAL
# Launcelot:PERSON
# LAUNCELOT:ORG
# Camelot:LOC
# Camelot:ORG
# Camelot:LOC
# Camelot:LOC
# Launcelot:PERSON
# Camelot:ORG
# LAUNCELOT:ORG
# 24:CARDINAL
# INTERIOR - DAY:DATE
# LAUNCELOT:PERSON
# One:CARDINAL
# LAUNCELOT:PERSON
# one:CARDINAL
# LAUNCELOT:ORG
# LAUNCELOT:ORG
# LAUNCELOT:ORG
# today:DATE
# two:CARDINAL
# one:CARDINAL
# Herbert:PERSON
# BACK:ORG
# BACK:ORG
# Princess:ORG
# Launcelot:PERSON
# Camelot:ORG
# CONCORDE:PRODUCT
# the Tall Tower:FAC
# the last minute:TIME
# CONCORDE:PRODUCT
# LAUNCELOT:ORG
# CONCORDE:PRODUCT
# today:DATE
# LAUNCELOT:PERSON
# 25:CARDINAL
# ARTHUR:PERSON
# BEDEVERE:ORG
# two:CARDINAL
# CRONE:ORG
# ARTHUR
# 	 :ORG
# ARTHUR:PERSON
# ARTHUR:PERSON
# BEDEVERE:ORG
# only one:CARDINAL
# Knights:ORG
# as much as:MONEY
# Knights:ORG
# Peng:PERSON
# Nee-wum:PERSON
# ni:GPE
# Roger the Shrubber:PERSON
# ROGER:PERSON
# 26:CARDINAL
# ARTHUR
# 	 Oh:ORG
# Knights of Ni:ORG
# one:CARDINAL
# KNIGHT:ORG
# ONE:CARDINAL
# KNIGHT:ORG
# ONE:CARDINAL
# KNIGHT:ORG
# KNIGHT:ORG
# Neeeow:PERSON
# ONE:CARDINAL
# Peng:PERSON
# ONE:CARDINAL
# KNIGHT:ORG
# Peng:PERSON
# ARTHUR:ORG
# Knights:ORG
# Neeeow:PERSON
# Neeeow:PERSON
# Knights of N:ORG
# Knights of Ni:ORG
# Firstly:ORDINAL
# KNIGHTS:ORG
# half:CARDINAL
# two:CARDINAL
# KNIGHTS:ORG
# Knights of Ni:ORG
# KNIGHTS:ORG
# KNIGHTS:ORG
# KNIGHT:ORG
# Knights of Ni:ORG
# KNIGHT:ORG
# KNIGHT:ORG
# KNIGHTS:ORG
# ROBIN:PERSON
# Robin:PERSON
# KNIGHT:ORG
# Robin:PERSON
# KNIGHT:ORG
# ROBIN:PERSON
# ROBIN:PERSON
# ROBIN:PERSON
# Robin:PERSON
# ROBIN
#  My:PERSON
# KNIGHT
#  Now:ORG
# Robin:PERSON
# ROBIN:WORK_OF_ART
# KNIGHTS
# 	Stop:ORG
# The TALL KNIGHT:WORK_OF_ART
# KNIGHTS:ORG
# AAAArghh:PRODUCT
# KNIGHTS:ORG
# Aaaaarghhh:ORG
# ARTHUR:PERSON
# BEDEVERE:ORG
# ROBIN:PERSON
# 27:CARDINAL
# GLADE - DAY:DATE
# KNIGHT:ORG
# ONE:CARDINAL
# KNIGHTS:ORG
# KNIGHT:ORG
# KNIGHTS:ORG
# KNIGHT:ORG
# Nicky-Nicky:PERSON
# 28:CARDINAL
# EXTERIOR - DAY:DATE
# ry Song:PERSON
# ten feet:QUANTITY
# BRIAN:PERSON
# a few years back:DATE
# Two:CARDINAL
# kingdom:GPE
# 29:CARDINAL
# EXTERIOR - DAY:DATE
# the KNIGHTS OF NI:ORG
# Two:CARDINAL
# one:CARDINAL
# PATSY:ORG
# BEDEVERE:ORG
# 30:CARDINAL
# EXTERIOR - DAY:DATE
# KING BRIAN's Court:ORG
# FIRST:ORDINAL
# FIRST:ORDINAL
# SECOND:ORDINAL
# Majesty:ORG
# kingdom:GPE
# SECOND:ORDINAL
# a minute:TIME
# Five:CARDINAL
# SECOND:ORDINAL
# ARTHUR:ORG
# BEDEVERE:ORG
# GALAHAD:ORG
# LANCELOT:PERSON
# Garwin:PERSON
# Hecrot:ORG
# Camelot:ORG
# betty gable:PERSON
# Arthur:PERSON
# SECOND:ORDINAL
# Brian:PERSON
# LANCELOT:PERSON
# King Brian:PERSON
# SECOND:ORDINAL
# KNIGHTS:ORG
# LANCELOT:PERSON
# KNIGHTS.:ORG
# Brian:PERSON
# KNIGHTS:ORG
# SECOND:ORDINAL
# Brian:PERSON
# one:CARDINAL
# SECOND:ORDINAL
# LAUNCELOT:ORG
# the Shalott Choral Society:ORG
# SECOND:ORDINAL
# SECOND:ORDINAL
# Brian:PERSON
# SECOND:ORDINAL
# LANCELOT:PERSON
# Brian:PERSON
# KNIGHTS:ORG
# ARTHUR:PERSON
# KNIGHTS:ORG
# Brian:PERSON
# SECOND:ORDINAL
# KNIGHTS:ORG
# KNIGHTS:ORG
# harmony
#    :ORG
# ARTHUR:PERSON
# KNIGHTS:ORG
# BRIAN:PERSON
# two:CARDINAL
# Two:CARDINAL
# Three:CARDINAL
# ARTHUR:PERSON
# twenty:CARDINAL
# two:CARDINAL
# ARTHUR & CO:ORG
# Brian:PERSON
# ARTHUR OF CAMELOT ADDRESSES THEE OH MIGHTY KING BRIAN:ORG
# BRIAN
# 		:PERSON
# 9 feet:QUANTITY
# BRIAN:PERSON
# One:CARDINAL
# Two:CARDINAL
# Three:CARDINAL
# Four:CARDINAL
# ARCHERS:ORG
# GAWAIN:PERSON
# one:CARDINAL
# FIRST:ORDINAL
# ARTHUR:PERSON
# BRIAN:PERSON
# ACOUSTICS:ORG
# KING BRIAN:PERSON
# HARMONY:ORG
# NEXT:ORG
# three:CARDINAL
# one:CARDINAL
# KING'S:ORG
# ONE:CARDINAL
# Two:CARDINAL
# KING'S:ORG
# TWO:CARDINAL
# KNIGHTS:ORG
# Three:CARDINAL
# THREE:CARDINAL
# robin:PERSON
# ROBIN:PERSON
# ROBIN:PERSON
# a few feet:QUANTITY
# ROBIN'S:PERSON
# ROBIN:PERSON
# Robin:PERSON
# ARTHUR:PERSON
# PAGES:ORG
# 28:CARDINAL
# ARTHUR:PERSON
# LAUNCELOT:ORG
# GALAHAD:ORG
# Arthur:PERSON
# Bedevere:PERSON
# Robin:PERSON
# twenty-four:CARDINAL
# Galahad:PERSON
# 29:CARDINAL
# Nador:GPE
# Robin:PERSON
# KNIGHTS:ORG
# Winter ...:DATE
# Winter:DATE
# Spring:DATE
# Spring:DATE
# Autumn and Autumn:EVENT
# Summer:DATE
# one day:DATE
# 30:CARDINAL
# KNIGHTS:ORG
# ARTHUR:PERSON
# BEDEVERE:ORG
# Tim:PERSON
# Greetings Tim the Enchanter:PERSON
# KNIGHTS:ORG
# ONE:CARDINAL
# TWO:CARDINAL
# KNIGHTS:ORG
# KNIGHTS
# 	Sssssh:ORG
# aaa:ORG
# Grail:ORG
# KNIGHTS:ORG
# TIM:PERSON
# KNIGHTS:ORG
# Caerbannog:ORG
# KNIGHTS:ORG
# KNIGHTS:ORG
# fifty:CARDINAL
# 31:CARDINAL
# EXTERIOR - DAY:DATE
# KNIGHTS:ORG
# ARTHUR:PERSON
# a few seconds:TIME
# ARTHUR:ORG
# TIM:PERSON
# TIM:PERSON
# the Cave of Caerbannog:ORG
# KNIGHTS:ORG
# KNIGHTS:ORG
# a few yards:QUANTITY
# scots git:PERSON
# One:CARDINAL
# TIM:PERSON
# about twenty feet:QUANTITY
# BORS:ORG
# KNIGHTS:ORG
# twenty
# :CARDINAL
# Peckinpahish:PERSON
# four:CARDINAL
# KNIGHTS:ORG
# KNIGHTS:ORG
# LAUNCELOT:ORG
# Gawain:PERSON
# Bors:ORG
# Five:CARDINAL
# Three:CARDINAL
# Three:CARDINAL
# ROBIN:PERSON
# the Holy Hand Grenade:ORG
# The Holy Hand Grenade of Antioch:WORK_OF_ART
# Maynard:PERSON
# KNIGHTS:ORG
# golden reliquary:ORG
# KNIGHTS:ORG
# ARTHUR:PERSON
# the Book of Armaments:WORK_OF_ART
# Two:CARDINAL
# MONK:ORG
# St.  Attila:ORG
# First:ORDINAL
# the Holy Pin:GPE
# three:CARDINAL
# Three:CARDINAL
# three:CARDINAL
# Four:CARDINAL
# two:CARDINAL
# three:CARDINAL
# three:CARDINAL
# third:ORDINAL
# One:CARDINAL
# two:CARDINAL
# three ...
# 	  :DATE
# five:CARDINAL
# Three:CARDINAL
# Three:CARDINAL
# ARTHUR:PERSON
# KNIGHTS:ORG
# KNIGHTS:ORG
# Huzzah:GPE
# 32:CARDINAL
# KNIGHTS:ORG
# KNIGHTS:ORG
# MAYNARD:PERSON
# Maynard:PERSON
# MAYNARD:PERSON
# Aramaic:NORP
# Joseph:PERSON
# Aramathea:GPE
# MAYNARD:PERSON
# Joseph of
# 	:PERSON
# Holy Grail
# 	 :ORG
# MAYNARD
# 	 :PERSON
# Aaaaarrrrrrggghhh:ORG
# MAYNARD:PERSON
# MAYNARD:PERSON
# MAYNARD:PERSON
# MAYNARD:PERSON
# Camargue:ORG
# France:GPE
# Cornwall:GPE
# Saint Ives:PERSON
# Herefordshire:GPE
# The Legendary Black Beast of Aaaaarrrrrrggghhh!:WORK_OF_ART
# ARTHUR:PERSON
# Alf:PERSON
# Aaaaarrrrrrggghhh:PERSON
# Aaaaarrrrrrggghhh:ORG
# KNIGHTS:ORG
# Black Beast:EVENT
# Arthur
# 	 :ORG
# Aaaaagh:WORK_OF_ART
# The Quest for Holy Grail:WORK_OF_ART
# day:DATE
# 33:CARDINAL
# EXTERIOR - DAY:DATE
# KNIGHTS:ORG
# Glencoe:GPE
# half:CARDINAL
# a few seconds:TIME
# ARTHUR
# 	 The Bridge of Death:WORK_OF_ART
# Aaaaarrrrrrggghhh:ORG
# 5 miles:QUANTITY
# twenty-four:CARDINAL
# KNIGHTS:ORG
# more and more:CARDINAL
# Aaaaarrrrrrggghhh:ORG
# 4 miles:QUANTITY
# 82 miles:QUANTITY
# BEDEVERE:ORG
# ROBIN:PERSON
# ARTHUR:PERSON
# the Bridge of Death:FAC
# three:CARDINAL
# three:CARDINAL
# the Gorge of Eternal Peril:LOC
# 34:CARDINAL
# EXTERIOR - DAY:DATE
# LAUNCELOT:ORG
# BEDEVERE:ORG
# the Keeper of the Bridge:ORG
# Robin:PERSON
# Launcelot:PERSON
# Launcelot:PERSON
# Bridge:ORG
# ARTHUR:PERSON
# three:CARDINAL
# Launcelot:PERSON
# Arthur:PERSON
# LAUNCELOT:ORG
# 24:CARDINAL
# Bridge:ORG
# five:CARDINAL
# Three:CARDINAL
# ARTHUR:PERSON
# Three:CARDINAL
# five:CARDINAL
# Three:CARDINAL
# ARTHUR:PERSON
# Three:CARDINAL
# the Gorge of Eternal Peril:LOC
# Robin:PERSON
# Robin:PERSON
# five:CARDINAL
# Three:CARDINAL
# Three:CARDINAL
# Launcelot:PERSON
# LAUNCELOT:ORG
# KNIGHTS:ORG
# ARTHUR:PERSON
# ROBIN:PERSON
# the Bridge of Death:FAC
# three:CARDINAL
# Bridgekeeper:ORG
# LAUNCELOT:ORG
# Launcelot:PERSON
# LAUNCELOT:ORG
# ARTHUR:PERSON
# ROBIN:PERSON
# ROBIN:PERSON
# the Bridge of Death:FAC
# three:CARDINAL
# Bridgekeeper:ORG
# Robin:PERSON
# Camelot:ORG
# Grail!:ORG
# Assyria:GPE
# ROBIN:WORK_OF_ART
# 35:CARDINAL
# EXTERIOR - DAY:DATE
# LAUNCELOT:PERSON
# Gawain:PERSON
# Camelot:ORG
# OOV:ORG
# the Holy Grail:PRODUCT
# OOV:ORG
# Aaaaarrrrrrggghhh:PERSON
# LAUNCELOT:ORG
# LAUNCELOT:ORG
# LAUNCELOT:ORG
# 36:CARDINAL
# ARTHUR:ORG
# GALAHAD:ORG
# BEDEVERE:ORG
# ARTHUR:ORG
# ARTHUR:PERSON
# BEDEVERE:ORG
# Arthur:PERSON
# Britons:NORP
# the Holy Grail:PRODUCT
# African:NORP
# European:NORP
# Aaaaarrrrrrggghhh:PERSON
# BRIDGEKEEPER:ORG
# Sea:LOC
# twenty-eight:CARDINAL
# ARTHUR:ORG
# BEDEVERE:ORG
# 37:CARDINAL
# 38:CARDINAL
# EXTERIOR - DAY:DATE
# this day:DATE
# Monsieur Arthur:PERSON
# KNIGHTS:ORG
# French:NORP
# second:ORDINAL
# English:LANGUAGE
# Begorrah:WORK_OF_ART
# ARTHUR:PERSON
# the Knights of Camelot:ORG
# KNIGHTS:ORG
# ARTHUR:PERSON
# KNIGHTS:ORG
# English:LANGUAGE
# one:CARDINAL
# mac:ORG
# French:NORP
# ARTHUR:PERSON
# BEDEVERE:ORG
# ARTHUR:PERSON
# English:LANGUAGE
# French:NORP
# ARTHUR:ORG
# ARTHUR:ORG
# KNIGHTS:ORG
# French:NORP
# KNIGHTS:ORG
# ARTHUR:ORG
# BEDEVERE:ORG
# A. King Esquire:PERSON
# BRIDGEKEEPER/SOOTHSAYER:ORG
# Twenty-eight:DATE
# two:CARDINAL
# two:CARDINAL
# BRIDGEKEEPER:ORG
# ARTHUR:PERSON
# French:NORP
# English:LANGUAGE
# BEDEVERE:ORG
# PIKEMEN:ORG
# ARTHUR:PERSON
# ARMY:ORG
# ARTHUR:PERSON
# French:NORP
# Grail:ORG
# ARTHUR:PERSON
# ARMY:ORG
# ARMY:ORG
# ARMY:ORG
# TWO:CARDINAL
# Black Marias:PERSON
# ARMY:ORG
# ARTHUR:PERSON
# BEDEVERE:ORG
# ARMY:ORG
# ARMY:ORG
# KNIGHTS:ORG
# some fifteen seconds:TIME
# Four:CARDINAL
# five minute:TIME
# i.e it
#   :PERSON
# GRAHAM CHAPMAN:PERSON
# HICCOUGHING GUARD:ORG
# THREE:CARDINAL
# KNIGHT
# :PRODUCT
# JOHN CLEESE:PERSON
# SECOND:ORDINAL
# BLACK KNIGHT:PERSON
# NEWT:PERSON
# LAUNCELOT:PERSON
# TERRY GILLIAM:PERSON
# PATSY:PERSON
# ARTHUR'S:ORG
# KNIGHT SOOTHSAYER:WORK_OF_ART
# BRIDGEKEEPER:ORG
# GAWAIN
# 			:PERSON
# FIRST:ORDINAL
# ERIC:PERSON
# BINT:PERSON
# ROBIN:PERSON
# LAUNCELOT:PERSON
# TRUSTY STEED:PRODUCT
# ROGER THE SHRUBBER (:PERSON
# MAYNARD
#
# :PERSON
# NEIL INNES:PERSON
# FIRST:ORDINAL
# ROBIN'S:PERSON
# FAVORITE MINSTREL:WORK_OF_ART
# TERRY JONES:PERSON
# DENNIS'S MOTHER:PERSON
# BEDEVERE:PERSON
# THREE:CARDINAL
# KNIGHT:ORG
# PRINCE HERBERT:PERSON
# MICHAEL PALIN:PERSON
# DENNIS:PERSON
# THREE:CARDINAL
# GALAHAD:PERSON
# MAYNARD:PERSON
# ROOMATE
#
# :WORK_OF_ART
# WITCH:ORG
# CAROL CLEVELAND:PERSON
# ARTHUR:PERSON
# RITA DAVIES:PERSON
# TAYLOR
# 			:PERSON
# SALLY KINGHORN:PERSON
# STEWART:ORG
# WINSTON
#
# :PERSON
# PYTHON:ORG
# MONTY):ORG
# 20 Fitzroy Square:QUANTITY
# London:GPE
# 1138069:DATE
# England:GPE

# %%
def new_dictionary2(document):
    ent_text2 = []
    for entity in document2.ents:
        ent_text2.append(entity.text)

    dict_ent_name2 = Counter(ent_text2)

    return dict_ent_name2

def new_dataframe2(document):
    df_ent2 = new_dictionary2(document)
    df_doc2 = pd.DataFrame(data = {'name' :df_ent2.keys(), 'count' : df_ent2.values()})
    return df_doc2

my_new_dict_2 = new_dictionary2(document2)
new_doc2 = new_dataframe2(my_new_dict_2)
new_doc2.head(5)
sorted_Monty_1 = new_doc2.sort_values(by = 'count', ascending = False)
sorted_Monty_1_20 = sorted_Monty_1[:20]
sorted_Monty_1_20.head()
# Out:
#           name  count
# 171     ARTHUR     98
# 272    KNIGHTS     57
# 259  LAUNCELOT     50
# 242   BEDEVERE     29
# 190     SECOND     28

# %%
def new_dictionary22(document):
    ent_label22 = []
    for entity in document2.ents:
        ent_label22.append(entity.label_)

    dict_ent_name22 = Counter(ent_label22)

    return dict_ent_name22

def new_dataframe22(document):
    df_ent22 = new_dictionary22(document)
    df_doc22 = pd.DataFrame(data = {'name' :df_ent22.keys(), 'count' : df_ent22.values()})
    return df_doc22

my_new_dict_22 = new_dictionary22(document2)
new_doc22 = new_dataframe22(my_new_dict_22)
sorted_Monty_22 = new_doc22.sort_values(by = 'count', ascending = False)
#sorted_Monty_22.head(20)

# %%
plt.bar(sorted_Monty_1_20['name'], sorted_Monty_1_20['count'], color = 'blue')
fig = plt.gcf()
fig.set_size_inches(13.5, 10.5)
plt.xticks(rotation = 45)
plt.title('20 Most Common Named Entities')
plt.xlabel('Names')
plt.ylabel('Count')
xs = sorted_Monty_1_20['name']
ys = sorted_Monty_1_20['count']
for x,y in zip(xs,ys):

    label = "{:.2f}".format(y)

    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') 
plt.show()

# %%
plt.bar(sorted_Monty_22['name'], sorted_Monty_22['count'], color = 'blue')
fig = plt.gcf()
fig.set_size_inches(10.5, 10.5)
plt.xticks(rotation = 45)
plt.rcParams["figure.figsize"] = (40,3)
plt.title('Count of Entities')
plt.xlabel('Entities')
plt.ylabel('Count')
xs = sorted_Monty_22['name']
ys = sorted_Monty_22['count']
for x,y in zip(xs,ys):

    label = "{:.2f}".format(y)

    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') 
plt.show()

# %% [markdown]
# ### Sherlock Holmes

# %%
document3 = nlp_lg(Path('The Adventures of Sherlock Holmes.txt').read_text(encoding = 'utf-8'))

# %%
for entity in document3.ents: #run through the document.ents (adding entity and label)
    print(f'{entity.text}:{entity.label_}')
# Out:
# Gutenberg:PERSON
# The Adventures of Sherlock Holmes:WORK_OF_ART
# Arthur Conan Doyle:PERSON
# eBook:EVENT
# the Project Gutenberg License:ORG
# eBook:EVENT
# www.gutenberg.net
#
#
# Title:ORG
# Sherlock Holmes:PERSON
# Arthur Conan Doyle:PERSON
# April 18, 2011:DATE
# 1661:MONEY
# November 29, 2002:DATE
# SHERLOCK HOLMES:PERSON
# Gutenberg:PERSON
# Jose Menendez
#
#
#
#
#
#
#
#
#
# :PERSON
# SHERLOCK HOLMES:PERSON
# ARTHUR CONAN DOYLE
#
#
#
#    I. A Scandal:PERSON
# Bohemia
#   II:GPE
# League
#  III:ORG
# The Boscombe Valley Mystery:ORG
# Five:CARDINAL
# The Adventure of the Blue Carbuncle
# VIII:WORK_OF_ART
# The Adventure of the Speckled Band
#   IX:PRODUCT
# The Adventure of the Engineer's Thumb:WORK_OF_ART
# X. The Adventure of the Noble Bachelor
#   XI:WORK_OF_ART
# The Adventure of the Beryl Coronet
#  XII:WORK_OF_ART
# The Adventure of the Copper Beeches
#
#
#
#
# ADVENTURE I. A SCANDAL IN BOHEMIA:WORK_OF_ART
# Sherlock Holmes:PERSON
# Irene Adler:PERSON
# one:CARDINAL
# Irene Adler:PERSON
# Holmes:PERSON
# first:ORDINAL
# Holmes:PERSON
# Bohemian:NORP
# Baker Street:WORK_OF_ART
# from
# week to week:DATE
# Odessa:GPE
# Trepoff:PERSON
# Atkinson:PERSON
# Trincomalee:ORG
# Holland:GPE
# daily:DATE
# One night:TIME
# the twentieth of March:DATE
# 1888:CARDINAL
# Baker Street:FAC
# Holmes
# :PERSON
# Watson:PERSON
# seven and a half pounds:CARDINAL
# Seven:CARDINAL
# Watson:PERSON
# Holmes:PERSON
# a few centuries ago:DATE
# Thursday:DATE
# Mary Jane:PERSON
# six:CARDINAL
# London:GPE
# some hundreds:CARDINAL
# seventeen:CARDINAL
# one:CARDINAL
# two:CARDINAL
# a quarter to eight
# o'clock:DATE
# one:CARDINAL
# Europe:LOC
# that hour:TIME
# one:CARDINAL
# Holmes:PERSON
# English:LANGUAGE
# Holmes:PERSON
# Gesellschaft:ORG
# German:NORP
# Continental:ORG
# Gazetteer:GPE
# Eglow, Eglonitz:ORG
# German:LANGUAGE
# Bohemia:GPE
# Carlsbad:GPE
# Wallenstein:PERSON
# Bohemia:GPE
# German:NORP
# all quarters:DATE
# Frenchman:NORP
# Russian:NORP
# German:NORP
# German:NORP
# Bohemian:NORP
# Holmes:PERSON
# A hundred and fifty guineas:CARDINAL
# Watson:PERSON
# Holmes:PERSON
# Boswell:PERSON
# Holmes:PERSON
# less than six feet:QUANTITY
# six
# inches:QUANTITY
# Hercules:PRODUCT
# England:GPE
# vizard mask:PERSON
# German:NORP
# one:CARDINAL
# Holmes:PERSON
# Watson:PERSON
# Von Kramm:PERSON
# Bohemian:NORP
# Holmes:PERSON
# two years:DATE
# European:NORP
# Holmes:PERSON
# I.:ORG
# august:DATE
# Holmes:PERSON
# Europe:LOC
# House:ORG
# Ormstein:ORG
# Bohemia:GPE
# Holmes:PERSON
# Europe:LOC
# Holmes:PERSON
# Holmes:PERSON
# Wilhelm Gottsreich
# :PERSON
# von Ormstein:PERSON
# Grand Duke:ORG
# Cassel-Felstein:ORG
# King of Bohemia:ORG
# Prague:GPE
# Holmes:PERSON
# Some five years ago:DATE
# Warsaw:GPE
# Irene Adler:PERSON
# Holmes:PERSON
# many years:DATE
# Hebrew:NORP
# Holmes:PERSON
# New Jersey:GPE
# the year
# 1858:DATE
# La Scala:PERSON
# Imperial Opera:ORG
# Warsaw:GPE
# London:GPE
# Majesty:ORG
# Crown Prince:PERSON
# Five:CARDINAL
# house:ORG
# Holmes:PERSON
# Clotilde Lothman:PERSON
# von Saxe-Meningen:PERSON
# second:ORDINAL
# Scandinavia:LOC
# Irene Adler:PERSON
# next Monday:DATE
# three days:DATE
# Holmes:PERSON
# one:CARDINAL
# two:CARDINAL
# London:GPE
# Langham:PERSON
# Von Kramm:PERSON
# The King:WORK_OF_ART
# three hundred pounds:MONEY
# seven hundred:CARDINAL
# Holmes:PERSON
# Mademoiselle:PERSON
# Briony Lodge:PERSON
# Serpentine Avenue:ORG
# St. John's Wood:GPE
# Holmes:PERSON
# One:CARDINAL
# good-night:TIME
# Majesty:ORG
# Watson:PERSON
# afternoon:TIME
# three
# o'clock:TIME
# three o'clock:TIME
# Baker Street:FAC
# Holmes:PERSON
# shortly after eight o'clock in the morning:TIME
# two:CARDINAL
# three:CARDINAL
# five minutes:TIME
# some minutes:TIME
# Irene Adler:PERSON
# a little after eight o'clock this
# :TIME
# morning:TIME
# one:CARDINAL
# Briony Lodge:PERSON
# two:CARDINAL
# Chubb:ORG
# English:LANGUAGE
# one:CARDINAL
# two:CARDINAL
# Adler:PERSON
# half a dozen:CARDINAL
# Irene Adler:PERSON
# five every day:DATE
# seven:CARDINAL
# only one:CARDINAL
# Godfrey Norton:PERSON
# the Inner Temple:ORG
# a dozen:CARDINAL
# Serpentine-mews:ORG
# Briony Lodge:PERSON
# This Godfrey Norton:PRODUCT
# Briony
# Lodge:ORG
# the
# Temple:ORG
# Briony Lodge:PERSON
# about half an hour:TIME
# first:ORDINAL
# Gross & Hankey's:ORG
# the Church of St. Monica:ORG
# the Edgeware Road:FAC
# Half:CARDINAL
# twenty minutes:TIME
# only half:CARDINAL
# 'The Church of St. Monica:WORK_OF_ART
# half:CARDINAL
# twenty minutes:TIME
# Watson:PERSON
# landau:PERSON
# The Church of St. Monica:ORG
# half:CARDINAL
# twenty minutes:TIME
# twenty-five minutes to
# :TIME
# landau:PERSON
# two:CARDINAL
# three:CARDINAL
# three:CARDINAL
# Godfrey Norton:PERSON
# God:PERSON
# only three minutes:TIME
# half:CARDINAL
# Irene Adler:PERSON
# Godfrey Norton:PERSON
# Temple:ORG
# five:CARDINAL
# this evening:TIME
# Turner:PERSON
# two hours:TIME
# Irene:PERSON
# Briony Lodge:PERSON
# Four or five minutes:TIME
# ten
# minutes:TIME
# a few minutes:TIME
# John Hare:PERSON
# Holmes:PERSON
# a quarter past six:DATE
# Baker Street:FAC
# ten minutes to the hour:TIME
# dusk:TIME
# Briony Lodge:PERSON
# Sherlock Holmes':PERSON
# two:CARDINAL
# Holmes:PERSON
# house:ORG
# Godfrey
# :PERSON
# Norton:ORG
# Two:CARDINAL
# a few days:DATE
# Pshaw:PERSON
# landau:PERSON
# Briony Lodge:PERSON
# one:CARDINAL
# two:CARDINAL
# one:CARDINAL
# Holmes
# :PERSON
# one:CARDINAL
# Irene Adler:PERSON
# Briony Lodge:PERSON
# Holmes:PERSON
# Holmes:PERSON
# ulster:GPE
# Holmes:PERSON
# Holmes:PERSON
# ten minutes:TIME
# some few minutes:TIME
# Arnsworth Castle:FAC
# bell-pull:ORG
# half:CARDINAL
# Majesty:ORG
# eight in the morning:TIME
# Baker Street:FAC
# Good-night:TIME
# Sherlock Holmes:PERSON
# ulster:GPE
# Holmes:PERSON
# Baker Street:FAC
# the King of Bohemia:ORG
# Sherlock Holmes:PERSON
# Briony Lodge:PERSON
# Irene Adler:PERSON
# Holmes:PERSON
# Married!:WORK_OF_ART
# Yesterday:DATE
# English:LANGUAGE
# Norton:ORG
# Majesty:PERSON
# Majesty:ORG
# Briony Lodge:PERSON
# Sherlock Holmes:PERSON
# Holmes:PERSON
# this morning:TIME
# Charing
# Cross:ORG
# Continent:LOC
# Sherlock Holmes:PERSON
# England:GPE
# Holmes:PERSON
# Irene Adler
# :PERSON
# evening:TIME
# Sherlock Holmes:PERSON
# three:CARDINAL
# midnight of:WORK_OF_ART
# the preceding night:TIME
# SHERLOCK HOLMES,--You:PERSON
# months ago:DATE
# John:PERSON
# Sherlock
# :PERSON
# King:ORG
# Sherlock Holmes:PERSON
# IRENE NORTON:PERSON
# ADLER:ORG
# the King of Bohemia:PERSON
# three:CARDINAL
# Majesty:ORG
# Holmes:PERSON
# Majesty:ORG
# Holmes:PERSON
# The King:WORK_OF_ART
# Irene:PERSON
# Majesty:PERSON
# good-morning:TIME
# Bohemia:GPE
# Sherlock Holmes:PERSON
# Irene Adler:PERSON
# ADVENTURE II:PRODUCT
# Sherlock Holmes:PERSON
# one day:DATE
# the
# autumn of:DATE
# last year:DATE
# Holmes:PERSON
# Watson:PERSON
# Wilson:PERSON
# half:CARDINAL
# Holmes:PERSON
# Watson:PERSON
# the other day:DATE
# Mary
# Sutherland:PERSON
# Jabez Wilson:PERSON
# this morning:TIME
# Wilson:PERSON
# Watson:PERSON
# thousands:CARDINAL
# British:NORP
# Albert:PERSON
# Sherlock Holmes':PERSON
# Freemason:PERSON
# China:GPE
# Jabez Wilson:PERSON
# Holmes:PERSON
# Freemasonry:ORG
# five inches:QUANTITY
# China:GPE
# China:GPE
# China:GPE
# Chinese:NORP
# Jabez Wilson:PERSON
# first:ORDINAL
# Watson:PERSON
# Holmes:PERSON
# Omne:PERSON
# Wilson:PERSON
# Lebanon:GPE
# Pennsylvania:GPE
# the League to a:ORG
# 4 pounds:MONEY
# the age
# :DATE
# twenty-one years:DATE
# Monday:DATE
# Duncan Ross:PERSON
# 7:CARDINAL
# Pope's:ORG
# Court:ORG
# Fleet Street:FAC
# Holmes:PERSON
# Wilson:PERSON
# first:ORDINAL
# The Morning Chronicle:WORK_OF_ART
# April 27, 1890:DATE
# Just two months
# ago:DATE
# Wilson:PERSON
# Sherlock
# Holmes:PERSON
# Jabez Wilson:PERSON
# Coburg Square:FAC
# more than:CARDINAL
# two:CARDINAL
# Sherlock Holmes:PERSON
# Vincent Spaulding:PERSON
# Holmes:PERSON
# Wilson:PERSON
# fourteen:DATE
# three:CARDINAL
# first:ORDINAL
# Spaulding:PERSON
# this day eight
# weeks:DATE
# Wilson:PERSON
# the League of the
# :ORG
# Holmes:PERSON
# weeks:DATE
# the League of the Red-:ORG
# one:CARDINAL
# a couple of hundred:CARDINAL
# some years:DATE
# I.:ORG
# American:NORP
# Ezekiah
# Hopkins:ORG
# millions:CARDINAL
# Londoners:NORP
# American:NORP
# London:GPE
# Wilson:PERSON
# a
# few hundred pounds:MONEY
# Vincent
# Spaulding:PERSON
# a holiday:DATE
# Holmes:PERSON
# Pope:PERSON
# Irish:NORP
# Spaulding:ORG
# Spaulding:ORG
# Holmes:PERSON
# Jabez Wilson:PERSON
# one:CARDINAL
# Duncan Ross:PERSON
# Wilson:PERSON
# Holmes:PERSON
# a few minutes:TIME
# I.:ORG
# Wilson:PERSON
# Vincent Spaulding:PERSON
# the hours:TIME
# Ten to two:CARDINAL
# an evening:TIME
# Holmes:PERSON
# Thursday:DATE
# Friday:DATE
# evening:TIME
# pay-day:DATE
# 4 pounds:QUANTITY
# only four hours:TIME
# I.:ORG
# Duncan Ross:PERSON
# the "Encyclopaedia Britannica:ORG
# first:ORDINAL
# Jabez Wilson:PERSON
# all day:DATE
# evening:TIME
# Encyclopaedia Britannica:ORG
# Vincent Spaulding:PERSON
# a penny:MONEY
# seven:CARDINAL
# Duncan Ross
# :PERSON
# two o'clock:TIME
# good-day:DATE
# Holmes:PERSON
# Saturday:DATE
# four:CARDINAL
# my
# week's:DATE
# next week:DATE
# the same the week
# after:DATE
# Every morning:TIME
# ten:CARDINAL
# two:CARDINAL
# Duncan Ross:PERSON
# a morning:TIME
# Eight weeks:DATE
# Archery:ORG
# Armour:FAC
# Attica:GPE
# ten o'clock:TIME
# October 9, 1890:DATE
# Sherlock Holmes:PERSON
# curt:PERSON
# Holmes:PERSON
# half:CARDINAL
# Duncan:PERSON
# Ross:PERSON
# 4:CARDINAL
# William Morris:PERSON
# yesterday:DATE
# 17:CARDINAL
# St. Paul's:GPE
# Holmes:PERSON
# William Morris:PERSON
# Duncan Ross:PERSON
# Holmes:PERSON
# Saxe:NORP
# Holmes:PERSON
# Holmes:PERSON
# first:ORDINAL
# Jabez Wilson:PERSON
# four:CARDINAL
# Holmes:PERSON
# some
# :PERCENT
# the minute:TIME
# two and thirty pounds:QUANTITY
# first:ORDINAL
# one:CARDINAL
# two:CARDINAL
# Wilson:PERSON
# About a month:DATE
# half:CARDINAL
# this Vincent Spaulding:PERSON
# thirty:CARDINAL
# Holmes:PERSON
# Holmes:PERSON
# a
# morning:TIME
# Wilson:PERSON
# two:CARDINAL
# Saturday:DATE
# Monday:DATE
# Watson:PERSON
# Holmes:PERSON
# Holmes:PERSON
# three:CARDINAL
# fifty minutes:TIME
# Sarasate:PERSON
# the St. James's Hall:FAC
# this afternoon:TIME
# Watson:PERSON
# a few hours:TIME
# German:NORP
# Italian:NORP
# French:NORP
# Aldersgate:ORG
# Saxe:NORP
# four:CARDINAL
# two:CARDINAL
# laurel-bushes:PRODUCT
# Three:CARDINAL
# JABEZ WILSON:ORG
# Sherlock Holmes:PERSON
# one:CARDINAL
# two:CARDINAL
# three:CARDINAL
# Holmes:PERSON
# Third:ORDINAL
# fourth:ORDINAL
# Holmes:PERSON
# fourth:ORDINAL
# London:GPE
# third:ORDINAL
# Wilson:PERSON
# Saxe:NORP
# Saxe:NORP
# one:CARDINAL
# Holmes:PERSON
# London:GPE
# Mortimer:PERSON
# shop:ORG
# Coburg:GPE
# the City and Suburban Bank:GPE
# the Vegetarian Restaurant:ORG
# McFarlane:PERSON
# Holmes:PERSON
# Holmes:PERSON
# days:DATE
# St. James's Hall:FAC
# some hours:TIME
# Coburg Square:FAC
# Saturday:DATE
# Ten:CARDINAL
# Baker Street:FAC
# ten:CARDINAL
# Sherlock Holmes:PERSON
# Kensington:GPE
# Encyclopaedia:WORK_OF_ART
# Saxe-Coburg:GPE
# Holmes:PERSON
# quarter-past nine:DATE
# Oxford Street:ORG
# Baker
# Street:ORG
# Two:CARDINAL
# Holmes:PERSON
# two:CARDINAL
# Peter Jones:PERSON
# Holmes:PERSON
# Watson:PERSON
# Jones:PERSON
# Scotland Yard:ORG
# Merryweather:PERSON
# Jones:PERSON
# Merryweather:PERSON
# Holmes:PERSON
# Sholto:PERSON
# Agra:GPE
# Jones:PERSON
# Saturday:DATE
# night:TIME
# seven-and-twenty years:TIME
# Sherlock Holmes:PERSON
# Merryweather:PERSON
# some 30,000 pounds:QUANTITY
# Jones:PERSON
# John Clay:PERSON
# Merryweather:PERSON
# London:GPE
# John
# Clay:PERSON
# Eton:ORG
# Oxford:ORG
# Scotland:GPE
# one week:DATE
# Cornwall:GPE
# years:DATE
# one:CARDINAL
# two:CARDINAL
# John Clay:PERSON
# two:CARDINAL
# first:ORDINAL
# Watson:PERSON
# second:ORDINAL
# Sherlock Holmes:PERSON
# Farrington Street:FAC
# Merryweather:PERSON
# Jones:PERSON
# Merryweather:PERSON
# Merryweather:PERSON
# Holmes:PERSON
# Merryweather:PERSON
# Holmes
# :PERSON
# Merryweather:PERSON
# Holmes:PERSON
# A few
# seconds:PERCENT
# at least an hour:TIME
# a minute:TIME
# City:GPE
# one:CARDINAL
# London:GPE
# Merryweather:PERSON
# London:GPE
# French:NORP
# French:NORP
# some months ago:DATE
# 30,000:CARDINAL
# the Bank of
# :ORG
# France:GPE
# 2,000:CARDINAL
# Holmes:PERSON
# an
# hour:TIME
# Merryweather:PERSON
# first:ORDINAL
# Watson:PERSON
# Holmes:PERSON
# one:CARDINAL
# Holmes:PERSON
# Saxe:GPE
# Jones:PERSON
# two:CARDINAL
# an hour:TIME
# Jones:PERSON
# first:ORDINAL
# a minute:TIME
# Great Scott:PERSON
# Archie:ORG
# Sherlock Holmes:PERSON
# Jones:PERSON
# Holmes:PERSON
# John Clay:PERSON
# Holmes:PERSON
# three:CARDINAL
# Holmes:PERSON
# Holmes:PERSON
# Jones:PERSON
# Jones:PERSON
# march:DATE
# John Clay:PERSON
# three:CARDINAL
# Holmes:PERSON
# Merryweather:PERSON
# one:CARDINAL
# two:CARDINAL
# John Clay:PERSON
# Holmes:PERSON
# Watson:PERSON
# the early hours of the morning:TIME
# Baker Street:FAC
# first:ORDINAL
# every day:DATE
# Clay:PERSON
# 4 pounds:QUANTITY
# thousands:CARDINAL
# one:CARDINAL
# the
# week:DATE
# one:CARDINAL
# London:GPE
# many hours:TIME
# months on end:DATE
# the City and
# :GPE
# Bank:ORG
# Scotland Yard:ORG
# League:ORG
# Jabez Wilson's:PERSON
# Saturday:DATE
# other day:DATE
# two days:DATE
# one:CARDINAL
# I.:ORG
# L'homme c'est rien--l'oeuvre
# c'est tout:GPE
# Gustave Flaubert:PERSON
# George Sand:PERSON
# Sherlock Holmes:PERSON
# Baker Street:FAC
# Holmes:PERSON
# three:CARDINAL
# here"--I:ORG
# morning:TIME
# half:CARDINAL
# Holmes:PERSON
# Dundas:GPE
# some weeks:DATE
# the King of Bohemia:GPE
# Irene Adler:PERSON
# Holland:GPE
# one:CARDINAL
# two:CARDINAL
# Some ten or twelve:CARDINAL
# Marseilles:GPE
# London:GPE
# Duchess:PERSON
# Devonshire:GPE
# Holmes:PERSON
# affaire de coeur:ORG
# Mary Sutherland:PERSON
# Sherlock Holmes:PERSON
# first:ORDINAL
# Holmes:PERSON
# Holmes:PERSON
# Etherege:PERSON
# Holmes:PERSON
# a hundred:CARDINAL
# Hosmer Angel:PERSON
# Sherlock Holmes:PERSON
# Mary Sutherland:PERSON
# Mr.
# Windibank:ORG
# Holmes:PERSON
# only five years and:DATE
# two months:DATE
# Holmes:PERSON
# nearly fifteen years:DATE
# the Tottenham Court Road:ORG
# Hardy:PERSON
# Windibank:PERSON
# 4700 pounds:MONEY
# Sherlock Holmes:PERSON
# Auckland:GPE
# New Zealand:GPE
# 4 1/2:CARDINAL
# Two thousand:CARDINAL
# Holmes:PERSON
# about 60 pounds:MONEY
# Holmes:PERSON
# Windibank:PERSON
# fifteen to twenty:CARDINAL
# a day:DATE
# Holmes:PERSON
# Watson:PERSON
# Hosmer Angel:PERSON
# Sutherland:PERSON
# first:ORDINAL
# Windibank:PERSON
# Sunday:DATE
# France:GPE
# Hardy:PERSON
# Hosmer Angel:PERSON
# Holmes:PERSON
# Windibank:PERSON
# France:GPE
# Hosmer Angel:PERSON
# that night:TIME
# next day:DATE
# Holmes:PERSON
# Hosmer:PERSON
# house:ORG
# Hosmer:PERSON
# France:GPE
# a week:DATE
# Hosmer
# :PERSON
# every day:DATE
# Holmes:PERSON
# first:ORDINAL
# Hosmer:ORG
# Angel:PERSON
# Leadenhall Street:FAC
# Holmes:PERSON
# premises:LOC
# Leadenhall Street:FAC
# the Leadenhall Street Post Office:ORG
# Holmes:PERSON
# Holmes:PERSON
# Hosmer Angel:PERSON
# Holmes:PERSON
# Windibank:PERSON
# France:GPE
# Hosmer:PERSON
# Testament:PERSON
# Mother:PERSON
# first:ORDINAL
# the
# week:DATE
# Holmes:PERSON
# only a few years:DATE
# Bordeaux:GPE
# French:NORP
# England:GPE
# Friday:DATE
# St. Saviour's:ORG
# King's Cross:ORG
# two:CARDINAL
# first:ORDINAL
# four-wheeler:CARDINAL
# cabman:ORG
# last Friday:DATE
# Holmes:PERSON
# Holmes:PERSON
# the morning:TIME
# wedding-morning:TIME
# One:CARDINAL
# Hosmer:PERSON
# night:TIME
# Holmes:PERSON
# Hosmer Angel:PERSON
# last Saturday's:DATE
# Chronicle:ORG
# four:CARDINAL
# 31:CARDINAL
# Lyon Place:ORG
# Camberwell:GPE
# Angel:PERSON
# Westhouse & Marbank:ORG
# Fenchurch Street:ORG
# Holmes:PERSON
# Sherlock Holmes:PERSON
# a few minutes:TIME
# Andover:GPE
# '77:DATE
# Hague:GPE
# last year:DATE
# one:CARDINAL
# two:CARDINAL
# Watson:PERSON
# Sherlock Holmes:PERSON
# Watson:PERSON
# first:ORDINAL
# first:ORDINAL
# One:CARDINAL
# two:CARDINAL
# five:CARDINAL
# first:ORDINAL
# third:ORDINAL
# fifth:ORDINAL
# half:CARDINAL
# this morning:TIME
# Watson:PERSON
# Hosmer Angel:PERSON
# the morning of the fourteenth:TIME
# Hosmer Angel:PERSON
# About five:CARDINAL
# seven:CARDINAL
# Albert
# :PERSON
# Harris:PERSON
# Leadenhall Street:FAC
# Holmes:PERSON
# Angel:PERSON
# Balzac:PERSON
# Leadenhall Street:FAC
# two:CARDINAL
# One:CARDINAL
# Windibank:PERSON
# six o'clock tomorrow
# :TIME
# evening:TIME
# the King of Bohemia:ORG
# Irene Adler:PERSON
# Four:CARDINAL
# Mary
# Sutherland:PERSON
# Baker Street:FAC
# Sherlock Holmes:PERSON
# half:CARDINAL
# his day:DATE
# yesterday:DATE
# Miss
# Sutherland:PERSON
# Holmes:PERSON
# James Windibank:PERSON
# Holmes:PERSON
# six:CARDINAL
# thirty years of age:DATE
# Good-evening:TIME
# James Windibank:PERSON
# Holmes:PERSON
# six o'clock:TIME
# Sutherland:PERSON
# this Hosmer Angel:PERSON
# Holmes:PERSON
# Hosmer Angel:PERSON
# Windibank:PERSON
# Holmes:PERSON
# one:CARDINAL
# Windibank:PERSON
# fourteen:CARDINAL
# Holmes:PERSON
# Windibank:PERSON
# Holmes:PERSON
# four:CARDINAL
# fourteen:CARDINAL
# Windibank:PERSON
# Holmes:PERSON
# Holmes:PERSON
# Windibank:PERSON
# Holmes:PERSON
# Windibank:PERSON
# Holmes:PERSON
# a hundred:CARDINAL
# Hosmer Angel:PERSON
# first:ORDINAL
# France:GPE
# Angel:PERSON
# France:GPE
# Testament:PERSON
# the very morning:TIME
# James Windibank:PERSON
# Miss
# Sutherland:ORG
# Hosmer Angel:PERSON
# ten years:DATE
# Windibank:PERSON
# Holmes
# :ORG
# Holmes:PERSON
# first:ORDINAL
# Holmes:PERSON
# Jove:ORG
# to--:PERSON
# two:CARDINAL
# James Windibank:PERSON
# Holmes:PERSON
# first:ORDINAL
# Hosmer Angel:PERSON
# two:CARDINAL
# Westhouse & Marbank:ORG
# Fenchurch Street:ORG
# James Windibank:PERSON
# Voilà:ORG
# Sutherland:PERSON
# Persian:NORP
# Hafiz:PERSON
# Horace:PERSON
# one morning:TIME
# Sherlock Holmes:PERSON
# a couple of days:DATE
# England:GPE
# Boscombe Valley:GPE
# Paddington:ORG
# Sherlock Holmes:PERSON
# one:CARDINAL
# only half an hour:TIME
# Afghanistan:GPE
# Paddington Station:ORG
# Sherlock
# Holmes:PERSON
# gaunt
# :ORG
# Watson:PERSON
# two:CARDINAL
# Holmes:PERSON
# some days:DATE
# London:GPE
# Boscombe Valley:GPE
# Ross:PERSON
# Herefordshire:GPE
# John Turner:PERSON
# Australia:GPE
# some years ago:DATE
# One:CARDINAL
# Hatherley:ORG
# Charles McCarthy:PERSON
# Turner:PERSON
# McCarthy:PERSON
# McCarthy:PERSON
# one:CARDINAL
# eighteen:DATE
# Turner:PERSON
# English:LANGUAGE
# McCarthys:ORG
# McCarthy:PERSON
# two:CARDINAL
# Turner:PERSON
# some half-dozen:CARDINAL
# June 3rd:DATE
# Monday:DATE
# McCarthy:PERSON
# Hatherley:NORP
# three in the afternoon:TIME
# the Boscombe Valley:LOC
# Ross:PERSON
# three:CARDINAL
# Hatherley Farm-house:ORG
# the Boscombe Pool:FAC
# a quarter:CARDINAL
# two:CARDINAL
# One:CARDINAL
# William Crowder:PERSON
# Turner:PERSON
# McCarthy:PERSON
# a few minutes:TIME
# McCarthy:PERSON
# James McCarthy:PERSON
# two:CARDINAL
# William Crowder:PERSON
# The Boscombe Pool:ORG
# fourteen:CARDINAL
# Patience Moran:PERSON
# Boscombe Valley:GPE
# McCarthy:PERSON
# McCarthy:PERSON
# two:CARDINAL
# McCarthys:ORG
# Boscombe Pool:ORG
# McCarthy:PERSON
# Tuesday:DATE
# Wednesday:DATE
# Ross:PERSON
# Holmes
# :PERSON
# one:CARDINAL
# Turner:PERSON
# Lestrade:PERSON
# Lestrade:PERSON
# two:CARDINAL
# fifty miles:QUANTITY
# Lestrade:PERSON
# first:ORDINAL
# Lestrade:PERSON
# every morning:TIME
# this
# season:DATE
# one:CARDINAL
# two:CARDINAL
# Hatherley Farm:ORG
# Holmes:PERSON
# bandy:PERSON
# one:CARDINAL
# two:CARDINAL
# Herefordshire:GPE
# James McCarthy:PERSON
# three days:DATE
# Bristol:GPE
# the
# morning:TIME
# last Monday:DATE
# 3rd:ORDINAL
# Ross:PERSON
# John Cobb:PERSON
# the Boscombe Pool:ORG
# William
# Crowder:PERSON
# about a hundred yards:QUANTITY
# Hatherley Farm:ORG
# more than 150 yards:QUANTITY
# some minutes:TIME
# Turner:PERSON
# The Coroner:WORK_OF_ART
# The Coroner:WORK_OF_ART
# The Coroner:WORK_OF_ART
# Coroner:PERSON
# The Coroner: That is:WORK_OF_ART
# Coroner:PERSON
# The Coroner: How was it:WORK_OF_ART
# Bristol:GPE
# Juryman:PERSON
# The Coroner:WORK_OF_ART
# 'A dozen:CARDINAL
# a dozen
# yards:PERCENT
# McCarthy:PERSON
# Holmes:PERSON
# Petrarch:PERSON
# Swindon:GPE
# twenty minutes:TIME
# nearly four o'clock:TIME
# Stroud Valley:GPE
# Severn:ORG
# Ross:ORG
# Lestrade:PERSON
# Scotland Yard:ORG
# the Hereford Arms:LOC
# Lestrade:PERSON
# Holmes:PERSON
# Lestrade:PERSON
# Twenty-nine:CARDINAL
# Lestrade:PERSON
# Sherlock Holmes:PERSON
# one:CARDINAL
# James:PERSON
# Turner:PERSON
# Sherlock Holmes:PERSON
# Lestrade:PERSON
# Lestrade:PERSON
# Holmes:PERSON
# James:PERSON
# McCarthy:PERSON
# James:PERSON
# one:CARDINAL
# Holmes:PERSON
# McCarthy:PERSON
# Holmes:PERSON
# Willows:PERSON
# McCarthy:PERSON
# Victoria:GPE
# Victoria:GPE
# Turner:PERSON
# Turner:PERSON
# James:PERSON
# Holmes:PERSON
# Turner:PERSON
# Holmes:PERSON
# Lestrade:PERSON
# a
# few minutes:TIME
# James McCarthy:PERSON
# Holmes:PERSON
# Hereford:GPE
# Watson:PERSON
# a couple of hours:TIME
# the
# day:DATE
# weekly:DATE
# third:ORDINAL
# half:CARDINAL
# Holmes:PERSON
# McCarthy:PERSON
# Lestrade:PERSON
# Sherlock Holmes':PERSON
# McCarthy:PERSON
# Sherlock Holmes:PERSON
# Lestrade:PERSON
# McCarthy:PERSON
# Turner:PERSON
# some two years ago:DATE
# five years:DATE
# Bristol:GPE
# Miss
# Turner:ORG
# the last three days:DATE
# Bristol:GPE
# Bermuda Dockyard:WORK_OF_ART
# McCarthy:PERSON
# two:CARDINAL
# One:CARDINAL
# second:ORDINAL
# George Meredith:PERSON
# Holmes:PERSON
# the morning:TIME
# nine o'clock Lestrade:TIME
# Hatherley Farm:ORG
# the Boscombe
# Pool:GPE
# this morning:TIME
# Lestrade:PERSON
# Turner:PERSON
# Holmes:PERSON
# About sixty:CARDINAL
# McCarthy:ORG
# Hatherley Farm:ORG
# Holmes:PERSON
# a hundred:CARDINAL
# McCarthy:PERSON
# Turner:ORG
# Turner:ORG
# Turner:PERSON
# Lestrade:PERSON
# Holmes:PERSON
# Holmes:PERSON
# Lestrade:PERSON
# McCarthy:PERSON
# McCarthy:PERSON
# Holmes:PERSON
# Hatherley
# Farm:ORG
# two:CARDINAL
# Holmes:PERSON
# seven or eight:CARDINAL
# Holmes
# :PERSON
# Boscombe Pool:GPE
# Sherlock Holmes:PERSON
# Baker Street:WORK_OF_ART
# two:CARDINAL
# the Boscombe Pool:FAC
# Holmes:PERSON
# Lestrade:PERSON
# The Boscombe Pool:ORG
# some fifty yards:QUANTITY
# Hatherley Farm:ORG
# Turner:PERSON
# Hatherley:ORG
# Lestrade:PERSON
# Holmes:PERSON
# six or
# eight feet:DATE
# three:CARDINAL
# the same feet:QUANTITY
# McCarthy:PERSON
# Holmes:PERSON
# Moran:PERSON
# about ten minutes:TIME
# Ross, Holmes:ORG
# Lestrade:PERSON
# a few
# days:DATE
# Indian:NORP
# Lestrade:PERSON
# British:NORP
# Nous:ORG
# Holmes:PERSON
# this afternoon:TIME
# London:GPE
# evening:TIME
# Lestrade:PERSON
# Scotland Yard:ORG
# Holmes:PERSON
# Lestrade:PERSON
# Holmes:PERSON
# Watson:PERSON
# two:CARDINAL
# McCarthy:PERSON
# One:CARDINAL
# Bristol:GPE
# Australian:NORP
# Australians:NORP
# McCarthy:PERSON
# Boscombe Pool:FAC
# Australia:GPE
# Sherlock Holmes:PERSON
# the Colony of Victoria:LOC
# Bristol:GPE
# last night:TIME
# ARAT:WORK_OF_ART
# BALLARAT:ORG
# the last two:DATE
# Ballarat:GPE
# third:ORDINAL
# Australian:NORP
# Ballarat:GPE
# to-day:DATE
# Lestrade:PERSON
# Indian:NORP
# 140:CARDINAL
# Indian:NORP
# Rotterdam:GPE
# Holmes:PERSON
# John Turner:PERSON
# Holmes:PERSON
# Holmes:PERSON
# McCarthy:PERSON
# Assizes:ORG
# Holmes:PERSON
# Holmes:PERSON
# Young McCarthy:PERSON
# Turner:ORG
# a
# month:DATE
# Holmes:PERSON
# Watson
# :PERSON
# McCarthy:PERSON
# Assizes:ORG
# Alice:PERSON
# McCarthy:PERSON
# these twenty years:DATE
# first:ORDINAL
# the early '60's:DATE
# bush:PERSON
# six:CARDINAL
# Black Jack:PERSON
# Ballarat:GPE
# the Ballarat Gang:FAC
# One day:DATE
# Ballarat:GPE
# Melbourne:GPE
# six:CARDINAL
# six:CARDINAL
# four:CARDINAL
# first:ORDINAL
# Three:CARDINAL
# McCarthy:PERSON
# England:GPE
# Alice:PERSON
# McCarthy:PERSON
# Jack:PERSON
# two:CARDINAL
# England:GPE
# Alice:PERSON
# Alice:PERSON
# McCarthy:PERSON
# Holmes:PERSON
# Holmes:PERSON
# McCarthy:PERSON
# Farewell:WORK_OF_ART
# Holmes:PERSON
# Baxter:PERSON
# Sherlock Holmes:PERSON
# James McCarthy:PERSON
# Assizes:ORG
# Holmes:PERSON
# Turner:PERSON
# seven
# months:DATE
# FIVE:CARDINAL
# between the years ':DATE
# 82 and '90:DATE
# one:CARDINAL
# year '87:DATE
# the Paradol Chamber:ORG
# British:NORP
# Sophy Anderson:PERSON
# Grice Patersons:PERSON
# Uffa:GPE
# Camberwell:PERSON
# Sherlock Holmes:PERSON
# two hours:TIME
# the latter days of September:DATE
# London:GPE
# evening:TIME
# Sherlock Holmes:PERSON
# Clark Russell's:PERSON
# a
# few days:DATE
# Baker
# Street:ORG
# such an hour:TIME
# Sherlock Holmes:PERSON
# two:CARDINAL
# Holmes:PERSON
# Horsham:GPE
# Holmes:PERSON
# Tankerville Club:ORG
# four:CARDINAL
# three:CARDINAL
# Holmes:PERSON
# John Openshaw:PERSON
# two:CARDINAL
# Elias
# :PERSON
# Joseph:PERSON
# Coventry:GPE
# Openshaw:ORG
# Elias:PERSON
# America:GPE
# Florida:GPE
# Jackson:GPE
# Hood:WORK_OF_ART
# Lee:PERSON
# three or four years:DATE
# About 1869 or 1870:DATE
# Europe:LOC
# Sussex:GPE
# Horsham:GPE
# States:GPE
# Republican:NORP
# all the years:DATE
# Horsham:GPE
# two or
# three:DATE
# weeks:DATE
# twelve or so:DATE
# the year 1878:DATE
# eight or nine years:DATE
# England:GPE
# sixteen:DATE
# one:CARDINAL
# One day:DATE
# March:DATE
# 1883:DATE
# India:GPE
# Pondicherry:GPE
# five:CARDINAL
# K. K. K.!':PERSON
# three:CARDINAL
# five:CARDINAL
# Fordham:ORG
# Horsham:GPE
# two:CARDINAL
# Fordham:PERSON
# the weeks:DATE
# a cold day:DATE
# Holmes:PERSON
# two feet:QUANTITY
# some 14,000 pounds:QUANTITY
# One:CARDINAL
# Holmes:PERSON
# one:CARDINAL
# March 10, 1883:DATE
# seven weeks
# later:DATE
# May 2nd:DATE
# Horsham:ORG
# K. K. K.:PERSON
# Openshaw:PERSON
# Southern:NORP
# North:LOC
# Horsham:GPE
# the
# January of '85:DATE
# the fourth day:DATE
# five:CARDINAL
# John:PERSON
# K. K. K.:PERSON
# I.:ORG
# Dundee:GPE
# the third day:DATE
# Freebody:PERSON
# one:CARDINAL
# Portsdown Hill:LOC
# the second day:DATE
# over one:CARDINAL
# one:CARDINAL
# January, '85:DATE
# two
# years:DATE
# eight months:DATE
# Horsham:GPE
# yesterday:DATE
# morning:TIME
# London:GPE
# eastern:ORG
# K. K. K.':PERSON
# Holmes:PERSON
# Tut:ORG
# Sherlock Holmes:PERSON
# Holmes:PERSON
# Holmes:PERSON
# two days:DATE
# one:CARDINAL
# John Openshaw:PERSON
# Holmes:PERSON
# March, 1869:DATE
# 4th:ORDINAL
# Hudson:PERSON
# 7th:ORDINAL
# McCauley:ORG
# Paramore:PERSON
# John Swain:PERSON
# St. Augustine:GPE
# 9th:ORDINAL
# McCauley:ORG
# 10th:ORDINAL
# John Swain:PERSON
# 12th:DATE
# Paramore:PERSON
# Holmes:PERSON
# one:CARDINAL
# first:ORDINAL
# second:ORDINAL
# Waterloo:GPE
# nine:CARDINAL
# Horsham:GPE
# London:GPE
# two days:DATE
# Sherlock Holmes:PERSON
# Watson:PERSON
# the Sign of Four:PRODUCT
# John Openshaw:PERSON
# this K. K. K.:PERSON
# Sherlock Holmes:PERSON
# Cuvier:PERSON
# one:CARDINAL
# these days:DATE
# one:CARDINAL
# the early days:DATE
# zero:CARDINAL
# fifty miles:QUANTITY
# Holmes:PERSON
# American Encyclopaedia':ORG
# first:ORDINAL
# Openshaw:PERSON
# America:GPE
# Florida:GPE
# English:NORP
# England:GPE
# first:ORDINAL
# Pondicherry:GPE
# second:ORDINAL
# Dundee:GPE
# London:GPE
# East London:GPE
# Pondicherry:GPE
# seven weeks:DATE
# Dundee:GPE
# only some three:CARDINAL
# four days:DATE
# Dundee:GPE
# Pondicherry:GPE
# seven weeks:DATE
# seven weeks:DATE
# Openshaw:ORG
# one:CARDINAL
# London:GPE
# Openshaw:ORG
# more than one:CARDINAL
# two:CARDINAL
# K. K. K.:PERSON
# Sherlock Holmes:PERSON
# the Ku Klux Klan:ORG
# Holmes:PERSON
# 'Ku Klux Klan:WORK_OF_ART
# Southern:NORP
# the Civil War:EVENT
# Tennessee:GPE
# Louisiana:GPE
# Carolinas:GPE
# Georgia:GPE
# Florida:GPE
# some years:DATE
# United States:GPE
# South:LOC
# the year
# 1869:DATE
# Holmes:PERSON
# Openshaw:ORG
# America:GPE
# South:LOC
# night:TIME
# C. Well:PERSON
# Openshaw:ORG
# the morning:TIME
# Sherlock Holmes:PERSON
# Openshaw:ORG
# first:ORDINAL
# Horsham:GPE
# first:ORDINAL
# Holmes:PERSON
# Openshaw:ORG
# Waterloo Bridge:FAC
# Between nine and ten:DATE
# Cook:PERSON
# the H
# Division:ORG
# Waterloo Bridge:FAC
# John Openshaw:PERSON
# Horsham:GPE
# Waterloo Station:FAC
# one:CARDINAL
# some minutes:TIME
# Holmes:PERSON
# Watson:PERSON
# Embankment:LOC
# such a night:TIME
# Watson:PERSON
# Baker Street:FAC
# Sherlock Holmes
# :PERSON
# nearly ten o'clock before he:TIME
# Watson:PERSON
# five:CARDINAL
# S. H.:PERSON
# Captain
# James Calhoun:WORK_OF_ART
# Lone Star:PERSON
# Savannah:GPE
# Georgia:GPE
# a sleepless night:TIME
# Openshaw:ORG
# Calhoun:PERSON
# first:ORDINAL
# the whole day:DATE
# Lloyd's:ORG
# Pondicherry:GPE
# January and February:DATE
# 83:CARDINAL
# thirty-six:CARDINAL
# those months:DATE
# Lone Star:PERSON
# London:GPE
# one:CARDINAL
# Texas:GPE
# American:NORP
# Dundee:GPE
# Lone Star':ORG
# January, '85:DATE
# London:GPE
# Lone Star':ORG
# last week:DATE
# Albert Dock:PERSON
# this morning:TIME
# Savannah:GPE
# Gravesend:GPE
# the Isle of Wight:LOC
# two:CARDINAL
# Americans:NORP
# Finns:NORP
# Germans:NORP
# three:CARDINAL
# last night:TIME
# Savannah:GPE
# Savannah:GPE
# three:CARDINAL
# John Openshaw:PERSON
# Lone Star:PRODUCT
# Savannah:GPE
# Atlantic:LOC
# Lone Star:PRODUCT
# Isa Whitney:PERSON
# Elias Whitney:PERSON
# D.D.:ORG
# the Theological College of St. George's:ORG
# De
# Quincey's:ORG
# many
# years:DATE
# One:CARDINAL
# June:DATE
# 89:CARDINAL
# about the hour:TIME
# first:ORDINAL
# a weary day:DATE
# Kate Whitney:PERSON
# Kate:PERSON
# James:PERSON
# Isa:ORG
# two days:DATE
# first:ORDINAL
# one day:DATE
# Upper Swandam Lane:FAC
# one:CARDINAL
# second:ORDINAL
# Isa Whitney's:ORG
# two hours:TIME
# first:ORDINAL
# Upper Swandam Lane:PERSON
# London Bridge:ORG
# three:CARDINAL
# two:CARDINAL
# Malay:NORP
# Isa Whitney:PERSON
# Whitney:PERSON
# Watson:PERSON
# Watson:PERSON
# Nearly eleven:CARDINAL
# what day:DATE
# Friday, June 19th:DATE
# Wednesday:DATE
# Wednesday:DATE
# Friday:DATE
# two days:DATE
# Watson:PERSON
# a few hours:TIME
# three:CARDINAL
# four:CARDINAL
# Kate:PERSON
# Kate:PERSON
# one:CARDINAL
# Watson:PERSON
# two:CARDINAL
# I.:PERSON
# Sherlock Holmes:PERSON
# half:CARDINAL
# Holmes:PERSON
# five minutes:TIME
# Sherlock Holmes':PERSON
# Whitney
# :PERSON
# a
# few minutes:TIME
# Whitney:ORG
# Sherlock Holmes:PERSON
# two:CARDINAL
# Watson:PERSON
# Watson:PERSON
# an
# hour:TIME
# Lascar:PERSON
# Paul's Wharf:FAC
# moonless
# :DATE
# nights:TIME
# Watson:PERSON
# 1000 pounds:MONEY
# Neville St. Clair:PERSON
# two:CARDINAL
# Watson:PERSON
# Holmes:PERSON
# two:CARDINAL
# Cedars:FAC
# Cedars:FAC
# St. Clair's:PERSON
# Kent:GPE
# seven-mile:QUANTITY
# John:PERSON
# half:CARDINAL
# about eleven:DATE
# two:CARDINAL
# Holmes:PERSON
# several miles:QUANTITY
# Watson:PERSON
# Lee:PERSON
# Watson:PERSON
# Some years ago:DATE
# May:DATE
# 1884:DATE
# Lee
# :PERSON
# Neville St. Clair:PERSON
# 1887:DATE
# two:CARDINAL
# Cannon
# Street:PRODUCT
# every night:TIME
# St. Clair:PERSON
# thirty-seven years:DATE
# 88 pounds:MONEY
# 220 pounds:QUANTITY
# Counties Bank:ORG
# Last Monday:DATE
# Neville St. Clair:PERSON
# two:CARDINAL
# Monday:DATE
# the Aberdeen Shipping Company:ORG
# London:GPE
# Fresno:GPE
# Upper Swandam Lane:FAC
# St. Clair:PERSON
# Swandam Lane:PERSON
# Monday:DATE
# an exceedingly hot day:DATE
# St.
# Clair:PERSON
# Swandam Lane:PERSON
# second:ORDINAL
# One:CARDINAL
# first:ORDINAL
# Lascar:PERSON
# Dane:PERSON
# Fresno Street:FAC
# two:CARDINAL
# St. Clair:PERSON
# Lascar:WORK_OF_ART
# afternoon:TIME
# St. Clair:PERSON
# one:CARDINAL
# at least four and a:CARDINAL
# Neville St. Clair:PERSON
# Neville St.
# Clair:PERSON
# Lascar:WORK_OF_ART
# St. Clair's:PERSON
# a very few
# seconds:DATE
# one:CARDINAL
# Hugh Boone:PERSON
# Lascar:WORK_OF_ART
# second:ORDINAL
# Neville St.
# Clair:PERSON
# Hugh Boone:PERSON
# Threadneedle Street:FAC
# daily:DATE
# I.:PERSON
# Watson:PERSON
# St. Clair:PERSON
# Barton:PERSON
# One:CARDINAL
# Boone:ORG
# some few minutes:TIME
# Lascar:PERSON
# Neville St. Clair:PERSON
# St. Clair's:PERSON
# Neville St. Clair's:PERSON
# Neville St. Clair:PERSON
# half:CARDINAL
# 270 half-pennies:CARDINAL
# Boone:ORG
# Neville St. Clair:PERSON
# Lascar confederate:WORK_OF_ART
# Boone:ORG
# years:DATE
# Neville St. Clair:PERSON
# Hugh Boone:PERSON
# first:ORDINAL
# Sherlock Holmes:PERSON
# two:CARDINAL
# Lee:GPE
# three:CARDINAL
# English:NORP
# Middlesex:ORG
# Surrey:ORG
# Kent:GPE
# Cedars:FAC
# Baker Street:FAC
# St. Clair:PERSON
# two:CARDINAL
# Watson:PERSON
# Holmes:PERSON
# mousseline de soie:ORG
# one
# half:CARDINAL
# two:CARDINAL
# a long day:DATE
# Watson:PERSON
# Sherlock Holmes:PERSON
# one:CARDINAL
# two:CARDINAL
# Neville:PERSON
# Sherlock Holmes:PERSON
# Monday:DATE
# Holmes:PERSON
# Sherlock Holmes:PERSON
# Gravesend:GPE
# the day
# before:DATE
# midnight:TIME
# Holmes:PERSON
# One:CARDINAL
# One:CARDINAL
# Neville:PERSON
# Gravesend:GPE
# St. Clair:PERSON
# Holmes:PERSON
# Monday:DATE
# Holmes:PERSON
# the very day:DATE
# Monday:DATE
# Swandam Lane:PERSON
# Lascar:WORK_OF_ART
# Swandam Lane:PERSON
# St. Clair:PERSON
# night:TIME
# Sherlock Holmes:PERSON
# a week:DATE
# all-night:TIME
# Eastern:NORP
# briar:ORG
# summer:DATE
# the previous night:TIME
# Watson:PERSON
# Game for a morning:WORK_OF_ART
# the previous night:TIME
# twenty-five minutes past four:TIME
# Holmes:PERSON
# Watson:PERSON
# one:CARDINAL
# Europe:LOC
# Charing Cross:ORG
# Gladstone:GPE
# half:CARDINAL
# the London Road:LOC
# Holmes:PERSON
# Surrey:ORG
# the Waterloo Bridge Road:FAC
# Wellington Street:FAC
# Sherlock Holmes:PERSON
# two:CARDINAL
# One:CARDINAL
# Holmes:PERSON
# Bradstreet:PERSON
# Bradstreet:PERSON
# Bradstreet:PERSON
# Holmes:PERSON
# Holmes:PERSON
# Boone:ORG
# Neville St.
# Clair:PERSON
# Lee:PERSON
# third:ORDINAL
# three:CARDINAL
# Holmes:PERSON
# Gladstone:GPE
# half:CARDINAL
# Holmes:PERSON
# Neville St. Clair:PERSON
# Lee:PERSON
# Kent:GPE
# Neville St.--:PERSON
# twenty-seven years:DATE
# Neville St. Clair:PERSON
# Holmes:PERSON
# Sherlock Holmes:PERSON
# Bradstreet:PERSON
# Chesterfield:GPE
# evening:TIME
# London:GPE
# One day:DATE
# seven hours:TIME
# 4d:CARDINAL
# 25 pounds:QUANTITY
# fortnight:DATE
# ten days:DATE
# 2 pounds:QUANTITY
# first:ORDINAL
# Swandam Lane:FAC
# the evenings:DATE
# Lascar:ORG
# London:GPE
# 700 pounds:QUANTITY
# 2 pounds:QUANTITY
# Last Monday:DATE
# the day:DATE
# Lascar:WORK_OF_ART
# that morning:TIME
# Thames:GPE
# a few minutes:TIME
# Neville St. Clair:PERSON
# Lascar at:WORK_OF_ART
# yesterday:DATE
# Holmes:PERSON
# Lascar:WORK_OF_ART
# Bradstreet:PERSON
# some days:DATE
# Holmes:PERSON
# Bradstreet:PERSON
# Hugh Boone:PERSON
# Holmes:PERSON
# five:CARDINAL
# Watson:PERSON
# Baker Street:FAC
# Sherlock Holmes:PERSON
# morning:TIME
# Christmas:DATE
# the season:DATE
# morning:TIME
# Sherlock Holmes:PERSON
# Only one:CARDINAL
# four million:CARDINAL
# a few square miles:QUANTITY
# six:CARDINAL
# three:CARDINAL
# Irene Adler:PERSON
# Mary Sutherland:PERSON
# Peterson:PERSON
# first:ORDINAL
# Christmas:DATE
# morning:TIME
# Peterson:PERSON
# about four o'clock:TIME
# Christmas:DATE
# morning:TIME
# Peterson:PERSON
# Tottenham Court Road:FAC
# Goodge Street:FAC
# One:CARDINAL
# Peterson:PERSON
# Tottenham
# Court Road:ORG
# Peterson:PERSON
# Christmas:DATE
# Henry Baker':PERSON
# bird:ORG
# some thousands:CARDINAL
# Bakers:ORG
# some hundreds:CARDINAL
# Henry Bakers:ORG
# one:CARDINAL
# Peterson:PERSON
# Christmas:DATE
# morning:TIME
# this morning:TIME
# Christmas:DATE
# Holmes:PERSON
# H. B.:PERSON
# Watson:PERSON
# last three years:DATE
# Holmes:PERSON
# last few days:DATE
# Holmes:PERSON
# Holmes:PERSON
# cubic:CARDINAL
# three years old:DATE
# three years ago:DATE
# Sherlock Holmes:PERSON
# weeks:DATE
# Watson:PERSON
# week:DATE
# One:CARDINAL
# two:CARDINAL
# no less than five:DATE
# night:TIME
# Sherlock Holmes:PERSON
# Peterson:PERSON
# Holmes:PERSON
# Holmes:PERSON
# Sherlock Holmes:PERSON
# Jove:ORG
# Peterson:PERSON
# Not the Countess:WORK_OF_ART
# Morcar:ORG
# Times:ORG
# every day:DATE
# 1000 pounds:QUANTITY
# A thousand pounds:QUANTITY
# Countess:ORG
# half:CARDINAL
# the Hotel Cosmopolitan:FAC
# December 22nd:DATE
# just five days ago:DATE
# John Horner:PERSON
# Assizes:ORG
# one:CARDINAL
# Hotel Cosmopolitan Jewel Robbery:ORG
# John Horner:PERSON
# 26:DATE
# 22nd:ORDINAL
# James Ryder:PERSON
# Horner:PERSON
# Countess:ORG
# Morcar:ORG
# second:ORDINAL
# Horner:PERSON
# Horner:PERSON
# morocco:GPE
# Countess:ORG
# Ryder:ORG
# Horner:PERSON
# the same evening:TIME
# Catherine Cusack:PERSON
# Countess:ORG
# Ryder:ORG
# Bradstreet:PERSON
# Horner:PERSON
# Assizes:ORG
# Horner:PERSON
# Holmes:PERSON
# one end to:DATE
# Tottenham Court Road:FAC
# Watson:PERSON
# Henry
# Baker:PERSON
# first:ORDINAL
# evening:TIME
# Goodge Street:FAC
# Henry Baker:PERSON
# 6:30 this evening:TIME
# 221B:PERSON
# Baker Street:FAC
# Peterson
# :ORG
# Peterson:PERSON
# evening:TIME
# Globe:ORG
# St. James's:ORG
# Evening News:ORG
# Echo:ORG
# Peterson:PERSON
# Holmes:PERSON
# twenty years old:DATE
# the Amoy River:LOC
# China:GPE
# two:CARDINAL
# forty:CARDINAL
# Countess:ORG
# Horner:PERSON
# Henry Baker:PERSON
# Henry Baker:PERSON
# the hour:TIME
# seven:CARDINAL
# Hudson:PERSON
# a little after half-past
# :DATE
# six:CARDINAL
# Baker Street:FAC
# Holmes:PERSON
# Henry Baker:PERSON
# Baker:PERSON
# summer:DATE
# winter:DATE
# Watson:PERSON
# Baker:PERSON
# Holmes:PERSON
# some days:DATE
# Holmes:PERSON
# half:CARDINAL
# Baker:PERSON
# Sherlock Holmes:PERSON
# one:CARDINAL
# Baker:PERSON
# the Alpha Inn:LOC
# Museum:ORG
# Museum:ORG
# the day:DATE
# This year:DATE
# Windigate:ORG
# some few pence:MONEY
# Christmas:DATE
# My pence:MONEY
# Henry Baker:PERSON
# Holmes:PERSON
# Watson:PERSON
# a bitter night:TIME
# ' quarter:DATE
# Harley Street:FAC
# Wigmore Street:FAC
# a quarter of an hour:DATE
# Bloomsbury:ORG
# the Alpha Inn:LOC
# one:CARDINAL
# Holborn:ORG
# Holmes:PERSON
# two:CARDINAL
# only half an hour ago:TIME
# Henry Baker:PERSON
# two dozen:CARDINAL
# Covent Garden:GPE
# Breckinridge:ORG
# Good-night:TIME
# Breckinridge:PERSON
# Remember:WORK_OF_ART
# Watson:PERSON
# one:CARDINAL
# seven years':DATE
# march:DATE
# Holborn:ORG
# Endell Street:FAC
# Covent Garden Market:FAC
# One:CARDINAL
# Breckinridge:ORG
# Good-evening:TIME
# Holmes:PERSON
# Holmes:PERSON
# five hundred:CARDINAL
# morning:TIME
# Alpha:LOC
# a couple of dozen:CARDINAL
# Alpha:LOC
# an end
# :DATE
# One:CARDINAL
# Holmes:PERSON
# Bill:PERSON
# Cocksure:PERSON
# third:ORDINAL
# Oakshott:PERSON
# 117:CARDINAL
# Brixton Road--249:GPE
# Holmes:PERSON
# Holmes:PERSON
# 117:CARDINAL
# Brixton Road:FAC
# 'December 22nd:DATE
# Twenty-four:CARDINAL
# 7s:CARDINAL
# 6d:CARDINAL
# Windigate:PERSON
# Sherlock Holmes:PERSON
# 100 pounds:QUANTITY
# Watson:PERSON
# the end of our:DATE
# Oakshott to-:PERSON
# Breckinridge:ORG
# one:CARDINAL
# Oakshott:PERSON
# Proosia:PERSON
# Brixton Road:FAC
# Holmes:PERSON
# Holmes:PERSON
# Sherlock Holmes:PERSON
# Oakshott:PERSON
# Brixton
# Road:ORG
# Breckinridge:ORG
# Henry Baker:PERSON
# Sherlock Holmes:PERSON
# four:CARDINAL
# John Robinson:PERSON
# Holmes:PERSON
# James Ryder:PERSON
# the Hotel Cosmopolitan:FAC
# us with
# half:CARDINAL
# half:CARDINAL
# half an hour:TIME
# Baker Street:FAC
# Holmes:PERSON
# Ryder:PERSON
# one:CARDINAL
# Holmes:PERSON
# Ryder:ORG
# Ryder:ORG
# Holmes:PERSON
# Watson:PERSON
# Ryder:ORG
# Morcar's:ORG
# Catherine Cusack:PERSON
# Ryder:ORG
# Horner:PERSON
# Cusack:PERSON
# Bible:WORK_OF_ART
# Holmes:PERSON
# Horner:PERSON
# Holmes:PERSON
# Horner:PERSON
# Oakshott:PERSON
# Brixton
# Road:GPE
# the Brixton Road:LOC
# Maudsley:ORG
# Pentonville:GPE
# One day:DATE
# one:CARDINAL
# two:CARDINAL
# Kilburn:GPE
# some weeks:DATE
# Christmas:DATE
# Kilburn:GPE
# Jem:PERSON
# Christmas:DATE
# Jem:PERSON
# twenty-six:DATE
# two dozen:CARDINAL
# Maggie:PERSON
# three pound:QUANTITY
# I.:ORG
# Holmes:PERSON
# Kilburn:GPE
# Maggie:PERSON
# Jem:PERSON
# Breckinridge:ORG
# Covent Garden:FAC
# Jem:PERSON
# two:CARDINAL
# as my
# feet:PERCENT
# Breckinridge:ORG
# Sherlock Holmes':PERSON
# Watson:PERSON
# Holmes:PERSON
# Horner:PERSON
# the season of:DATE
# seventy odd:CARDINAL
# the last eight years:DATE
# Sherlock Holmes:PERSON
# Surrey:PERSON
# the Roylotts of Stoke Moran:LOC
# the early days:DATE
# Holmes:PERSON
# Baker Street:FAC
# the last month:DATE
# Grimesby Roylott:PERSON
# April in the year '83:DATE
# one morning:TIME
# Sherlock Holmes:PERSON
# quarter-past seven:DATE
# Watson:PERSON
# this morning:TIME
# Hudson:PERSON
# this hour of the morning:TIME
# Holmes:PERSON
# a few minutes:TIME
# Good-morning:TIME
# Holmes:PERSON
# Sherlock
# Holmes:ORG
# Watson:PERSON
# Hudson:PERSON
# Holmes:PERSON
# thirty:CARDINAL
# Sherlock Holmes:PERSON
# this morning:TIME
# half:CARDINAL
# before six:DATE
# Leatherhead:PERSON
# twenty past:DATE
# first:ORDINAL
# Waterloo:GPE
# only one:CARDINAL
# Holmes:PERSON
# Farintosh:PERSON
# the hour:TIME
# a month or:DATE
# six weeks:DATE
# Holmes:PERSON
# Farintosh:WORK_OF_ART
# Watson:PERSON
# Holmes:PERSON
# Helen Stoner:PERSON
# one:CARDINAL
# England:GPE
# the Roylotts of Stoke Moran:GPE
# Holmes:PERSON
# England:GPE
# Berkshire:GPE
# Hampshire:GPE
# the last century:DATE
# four:CARDINAL
# the
# days:DATE
# Regency:ORG
# a few acres:QUANTITY
# two-hundred-year-old:CARDINAL
# Calcutta:GPE
# England:GPE
# Roylott:PERSON
# India:GPE
# Stoner:PERSON
# Stoner:PERSON
# the Bengal Artillery:LOC
# only two years old:DATE
# less than 1000 pounds:MONEY
# Roylott:PERSON
# annual:DATE
# England:GPE
# eight years ago:DATE
# Crewe:GPE
# Roylott:PERSON
# London:GPE
# Stoke Moran:PERSON
# first:ORDINAL
# Roylott:PERSON
# Stoke Moran:PERSON
# two:CARDINAL
# Last week:DATE
# the few
# acres:QUANTITY
# weeks:DATE
# Indian:NORP
# thirty:CARDINAL
# just two years ago:DATE
# Honoria Westphail:PERSON
# Harrow:PERSON
# Julia:PERSON
# Christmas two years ago:DATE
# half:CARDINAL
# marines:ORG
# a fortnight:DATE
# the day:DATE
# Sherlock Holmes:PERSON
# only one:CARDINAL
# first:ORDINAL
# Roylott:PERSON
# second:ORDINAL
# third:ORDINAL
# three:CARDINAL
# Roylott:PERSON
# Indian:NORP
# Helen:PERSON
# the night:TIME
# I.:ORG
# the last few nights:DATE
# about three:CARDINAL
# the morning:TIME
# a few moments later:TIME
# Holmes:PERSON
# night:TIME
# that night:TIME
# two:CARDINAL
# a wild night:TIME
# a few moments later:TIME
# first:ORDINAL
# Helen:PERSON
# One:CARDINAL
# Holmes:PERSON
# Roylott:PERSON
# every night:TIME
# four:CARDINAL
# Holmes:PERSON
# Two years:DATE
# A month ago:DATE
# many years:DATE
# Armitage:ORG
# Percy Armitage:PERSON
# Armitage:PERSON
# Crane Water:ORG
# the spring:DATE
# Two days ago:DATE
# last
# night:TIME
# the night:TIME
# the Crown Inn:LOC
# Leatherhead:ORG
# this morning:TIME
# one:CARDINAL
# Roylott:PERSON
# Holmes:PERSON
# Five:CARDINAL
# four:CARDINAL
# Holmes:PERSON
# Holmes:PERSON
# a
# thousand:CARDINAL
# Stoke Moran:PERSON
# all
# day:DATE
# Watson:PERSON
# one:CARDINAL
# two:CARDINAL
# twelve o'clock:TIME
# early in the afternoon:TIME
# this afternoon:TIME
# Watson:PERSON
# Sherlock Holmes:PERSON
# night:TIME
# Helen Stoner:PERSON
# one:CARDINAL
# I.:PERSON
# Stoke Moran:PERSON
# this day:DATE
# a thousand:CARDINAL
# Holmes:PERSON
# Grimesby Roylott:PERSON
# Stoke Moran:PERSON
# Holmes:PERSON
# the year:DATE
# Holmes:PERSON
# Holmes:PERSON
# Holmes:PERSON
# Holmes:PERSON
# Holmes:PERSON
# Stoner:PERSON
# Holmes:PERSON
# Watson:PERSON
# Doctors' Commons:ORG
# nearly one o'clock:TIME
# Sherlock Holmes:PERSON
# 1100 pounds:QUANTITY
# more than 750 pounds:QUANTITY
# 250 pounds:QUANTITY
# morning:TIME
# Watson:PERSON
# Waterloo:GPE
# Eley:ORG
# 2:CARDINAL
# Waterloo:GPE
# Leatherhead:PERSON
# four:CARDINAL
# five miles:QUANTITY
# Surrey:FAC
# first:ORDINAL
# the spring and this:DATE
# Stoke Moran:PERSON
# Grimesby Roylott:PERSON
# Holmes:PERSON
# Miss Stoner:PERSON
# Holmes:PERSON
# Leatherhead:ORG
# Holmes:PERSON
# the morning:TIME
# Roylott:PERSON
# evening:TIME
# Holmes:PERSON
# Stoner:PERSON
# Harrow:PERSON
# two:CARDINAL
# one:CARDINAL
# Holmes:PERSON
# one:CARDINAL
# Roylott:PERSON
# three:CARDINAL
# night:TIME
# Holmes:PERSON
# three:CARDINAL
# Holmes:PERSON
# third:ORDINAL
# second:ORDINAL
# Miss
# Stoner:ORG
# one:CARDINAL
# two:CARDINAL
# Wilton:ORG
# Holmes:PERSON
# last
# :DATE
# a couple of years ago:DATE
# a few minutes:TIME
# Holmes:PERSON
# one:CARDINAL
# two:CARDINAL
# Holmes:PERSON
# Miss Stoner:PERSON
# Grimesby Roylott:PERSON
# Holmes:PERSON
# some years ago:DATE
# one:CARDINAL
# one:CARDINAL
# Watson:PERSON
# Miss Stoner:PERSON
# Miss
# Stoner:PERSON
# Miss Stoner:PERSON
# first:ORDINAL
# the night:TIME
# Stoner:PERSON
# Crown:PRODUCT
# the night:TIME
# one night:TIME
# the night:TIME
# Holmes:PERSON
# Miss Stoner:PERSON
# Miss Stoner:PERSON
# Roylott:PERSON
# Sherlock Holmes:PERSON
# the Crown Inn:LOC
# Stoke Moran Manor House:PERSON
# Grimesby Roylott:PERSON
# a few
# minutes:TIME
# Watson:PERSON
# Holmes:PERSON
# two:CARDINAL
# Stoke Moran:PERSON
# Holmes:PERSON
# Roylott:PERSON
# two:CARDINAL
# Holmes:PERSON
# first:ORDINAL
# Palmer:PERSON
# Pritchard:PERSON
# Watson:PERSON
# a few hours:TIME
# About nine o'clock:TIME
# the Manor House:FAC
# Two hours
# :TIME
# Holmes:PERSON
# one:CARDINAL
# laurel
# bushes:ORG
# Holmes:PERSON
# I.:PERSON
# Holmes:PERSON
# Holmes:PERSON
# a few feet:QUANTITY
# every quarter of
# :DATE
# Twelve:CARDINAL
# one:CARDINAL
# two:CARDINAL
# half an hour:TIME
# Holmes
# :PERSON
# Watson:PERSON
# Holmes:PERSON
# the night:TIME
# one:CARDINAL
# Holmes:PERSON
# Holmes:PERSON
# Roylott:PERSON
# half:CARDINAL
# Grimesby Roylott:PERSON
# Turkish:NORP
# the day:DATE
# Holmes:PERSON
# Holmes:PERSON
# India:GPE
# ten seconds:TIME
# Grimesby Roylott:PERSON
# Stoke Moran:PERSON
# Harrow:PERSON
# Sherlock Holmes:PERSON
# next day:DATE
# Watson:PERSON
# India:GPE
# Eastern:ORG
# two:CARDINAL
# morning:TIME
# the hour:TIME
# every night:TIME
# a week:DATE
# Miss Stoner:PERSON
# first:ORDINAL
# Grimesby Roylott:PERSON
# Sherlock Holmes:PERSON
# the years:DATE
# only two:CARDINAL
# Hatherley:PERSON
# Colonel
# Warburton's:ORG
# a single half:CARDINAL
# two years:DATE
# the summer of '89:DATE
# Holmes:PERSON
# Baker:PERSON
# Bohemian:NORP
# Paddington
# Station:ORG
# One:CARDINAL
# One morning:TIME
# a little before seven o'clock:TIME
# two:CARDINAL
# Paddington:ORG
# heather tweed:PERSON
# one:CARDINAL
# five:CARDINAL
# the night:TIME
# this morning:TIME
# Paddington:GPE
# Victor Hatherley:PERSON
# 16A, Victoria Street:ORG
# 3rd:ORDINAL
# four:CARDINAL
# one:CARDINAL
# justice:ORG
# Sherlock Holmes:PERSON
# five minutes:TIME
# Baker Street:FAC
# Sherlock Holmes:PERSON
# The
# Times:ORG
# the day
# before:DATE
# Hatherley:PERSON
# Holmes:PERSON
# London:GPE
# the seven years:DATE
# Venner &
# Matheson:ORG
# Greenwich:GPE
# Two years ago:DATE
# Victoria:GPE
# first:ORDINAL
# two years:DATE
# three:CARDINAL
# one:CARDINAL
# 27 pounds:MONEY
# from
# nine:CARDINAL
# four in the afternoon:TIME
# Yesterday:DATE
# Lysander Stark':PERSON
# Hatherley:PERSON
# German:NORP
# Hatherley:PERSON
# London:GPE
# fifty guineas:MONEY
# night:TIME
# night:TIME
# Eyford:ORG
# Berkshire:GPE
# Oxfordshire:GPE
# seven miles:QUANTITY
# Paddington:GPE
# seven miles:QUANTITY
# Eyford Station:ORG
# hour:TIME
# fifty guineas:MONEY
# one:CARDINAL
# two:CARDINAL
# England:GPE
# ten miles:QUANTITY
# one:CARDINAL
# two:CARDINAL
# house:ORG
# Eyford:NORP
# I.:ORG
# excavating fuller's-earth:ORG
# Hatherley:PERSON
# one:CARDINAL
# midnight:TIME
# Paddington:GPE
# Eyford:ORG
# eleven o'clock:TIME
# the morning:TIME
# One:CARDINAL
# Holmes:PERSON
# at least an hour:TIME
# Lysander Stark:PERSON
# only seven miles:QUANTITY
# nearer twelve:CARDINAL
# more than
# :CARDINAL
# Lysander Stark:PERSON
# Stark:PERSON
# a
# few minutes:TIME
# German:NORP
# German:NORP
# two:CARDINAL
# German:NORP
# ten miles:QUANTITY
# Eyford:ORG
# Reading:PERSON
# fifty-guinea:CARDINAL
# one:CARDINAL
# English:LANGUAGE
# fifty-guinea:CARDINAL
# Lysander Stark:PERSON
# Ferguson:PERSON
# Ferguson:PERSON
# two:CARDINAL
# Ferguson:PERSON
# Lysander Stark:PERSON
# three:CARDINAL
# one:CARDINAL
# Ferguson:PERSON
# one:CARDINAL
# india:GPE
# German:NORP
# a minute:TIME
# two:CARDINAL
# two:CARDINAL
# a few
# moments:PERCENT
# two:CARDINAL
# two:CARDINAL
# one:CARDINAL
# Lysander Stark:PERSON
# more than thirty feet:QUANTITY
# Fritz:PERSON
# Fritz:PERSON
# English:LANGUAGE
# Elise:PERSON
# first:ORDINAL
# a bright morning:TIME
# night:TIME
# house:ORG
# the previous night:TIME
# those dreadful hours:TIME
# Half:CARDINAL
# about the morning:TIME
# less than an hour:TIME
# Lysander Stark:PERSON
# the night:TIME
# one:CARDINAL
# a little past six:DATE
# Sherlock Holmes:PERSON
# about a year ago:DATE
# 9th:ORDINAL
# Jeremiah Hayling:PERSON
# twenty-six:CARDINAL
# ten
# o'clock at night:TIME
# Scotland Yard:ORG
# Some three hours:TIME
# Berkshire village:GPE
# Sherlock Holmes:PERSON
# Bradstreet:PERSON
# Scotland Yard:ORG
# Bradstreet:PERSON
# Eyford:ORG
# ten miles:QUANTITY
# ten miles:QUANTITY
# Bradstreet:PERSON
# Holmes:PERSON
# twelve-mile:QUANTITY
# Hatherley:ORG
# Six:CARDINAL
# six:CARDINAL
# twelve miles:QUANTITY
# Bradstreet
# :PERSON
# Holmes:PERSON
# half:CARDINAL
# thousand:CARDINAL
# Eyford Station:ORG
# Bradstreet:PERSON
# the night:TIME
# Becher:PERSON
# Becher:PERSON
# German:NORP
# Becher:PERSON
# Englishman:NORP
# Berkshire:GPE
# three:CARDINAL
# Hatherley:PERSON
# second:ORDINAL
# Holmes:PERSON
# last night:TIME
# Holmes:PERSON
# that day to this
# :DATE
# German:NORP
# Englishman:NORP
# Early that morning:TIME
# Holmes:PERSON
# second:ORDINAL
# two:CARDINAL
# one:CARDINAL
# Englishman:NORP
# London:GPE
# fifty:CARDINAL
# Holmes:PERSON
# four-year-old:DATE
# Sherlock Holmes:PERSON
# a few weeks:DATE
# Holmes:PERSON
# Baker Street:FAC
# afternoon:TIME
# all day:DATE
# Jezail:ORG
# Afghan:NORP
# one:CARDINAL
# the day:DATE
# morning:TIME
# One:CARDINAL
# England:GPE
# Watson:PERSON
# Lestrade:PERSON
# Scotland Yard:ORG
# four o'clock:TIME
# Grosvenor Mansions:ORG
# Holmes
# :PERSON
# four o'clock:TIME
# three:CARDINAL
# an
# hour:TIME
# Robert Walsingham:PERSON
# second:ORDINAL
# Balmoral:LOC
# three:CARDINAL
# 1846:DATE
# forty-one years of age:DATE
# Foreign Affairs:ORG
# Tudor:PERSON
# Watson:PERSON
# Grosvenor Square:FAC
# first:ORDINAL
# first:ORDINAL
# the Morning Post:WORK_OF_ART
# some weeks
# back::DATE
# Robert
# St. Simon:PERSON
# second:ORDINAL
# Balmoral:LOC
# Hatty
# Doran:PERSON
# Aloysius Doran:PERSON
# San
# Francisco:GPE
# Cal.:GPE
# U.S.A.:GPE
# Holmes:PERSON
# the same week:DATE
# One:CARDINAL
# one:CARDINAL
# Great:GPE
# Britain:GPE
# Atlantic:LOC
# the last
# week:DATE
# St. Simon:PERSON
# over twenty years:DATE
# Hatty
# Doran:PERSON
# California:GPE
# Miss
# Doran:PERSON
# six:CARDINAL
# Balmoral:GPE
# the last few years:DATE
# Birchmoor:ORG
# Californian:ORG
# Republican:NORP
# British:NORP
# Holmes:PERSON
# St. George's:ORG
# Hanover Square:FAC
# only half a dozen:CARDINAL
# Lancaster Gate:FAC
# Aloysius Doran:PERSON
# Two days later:DATE
# Wednesday:DATE
# Lord
# Backwater's:ORG
# Petersfield:GPE
# Holmes:PERSON
# morning:TIME
# yesterday:DATE
# Robert St. Simon:PERSON
# yesterday:DATE
# previous morning:TIME
# St. George's:FAC
# Hanover:ORG
# Aloysius Doran:PERSON
# Balmoral:FAC
# Eustace:PERSON
# Clara St. Simon:PERSON
# Lady Alicia
# Whittington:PERSON
# Aloysius Doran:PERSON
# Lancaster Gate:FAC
# One:CARDINAL
# Aloysius Doran:PERSON
# last night:TIME
# Only one:CARDINAL
# another of the morning:TIME
# Flora Millar:PERSON
# Allegro:ORG
# some years:DATE
# Watson:PERSON
# a few minutes after:TIME
# Watson:PERSON
# Robert St. Simon:PERSON
# white waistcoat:PERSON
# Good-day:DATE
# St. Simon:PERSON
# Holmes:PERSON
# Watson:PERSON
# Holmes:PERSON
# The King of Scandinavia:WORK_OF_ART
# Holmes:PERSON
# first:ORDINAL
# Hatty Doran:PERSON
# San Francisco:GPE
# a year ago:DATE
# States:GPE
# Pacific:LOC
# a few years ago:DATE
# Holmes:PERSON
# twenty:CARDINAL
# England:GPE
# Holmes:PERSON
# London:GPE
# London:GPE
# season:DATE
# Doran:PERSON
# the day:DATE
# Alice:PERSON
# American:NORP
# California:GPE
# America:GPE
# Alice:PERSON
# a few minutes:TIME
# American:NORP
# ten minutes:TIME
# Alice:PERSON
# Hyde Park:FAC
# Flora Millar:PERSON
# Doran:PERSON
# that
# morning:TIME
# some years:DATE
# Allegro:ORG
# Holmes:PERSON
# Doran:PERSON
# two:CARDINAL
# a
# row:DATE
# Lestrade:PERSON
# Scotland Yard:ORG
# Flora:PERSON
# Flora:PERSON
# Holmes:PERSON
# St. Simon:PERSON
# Sherlock Holmes:PERSON
# Holmes:PERSON
# Thoreau:PERSON
# Aberdeen:GPE
# some
# years back:DATE
# Munich:GPE
# the year:DATE
# the Franco-Prussian War:ORG
# Lestrade:PERSON
# Good-afternoon:TIME
# Lestrade:PERSON
# Holmes:PERSON
# all day:DATE
# Holmes:PERSON
# Serpentine:ORG
# Sherlock Holmes:PERSON
# Trafalgar Square:FAC
# one:CARDINAL
# Serpentine:ORG
# Serpentine:ORG
# Flora Millar:PERSON
# Lestrade:PERSON
# Holmes:PERSON
# two:CARDINAL
# as
# many minutes:TIME
# Flora Millar:PERSON
# F.H.M.:ORG
# Flora
# Millar:ORG
# Lestrade:PERSON
# Holmes:PERSON
# Lestrade:PERSON
# Oct. 4th:DATE
# 2s:CARDINAL
# 6d:CARDINAL
# 1s:CARDINAL
# 2s:CARDINAL
# 6d:CARDINAL
# glass sherry:PERSON
# Lestrade:PERSON
# -day:DATE
# Holmes:PERSON
# first:ORDINAL
# Just one:CARDINAL
# Lestrade:PERSON
# Holmes:PERSON
# Lady
# St. Simon:PERSON
# Lestrade:PERSON
# three:CARDINAL
# Holmes:PERSON
# Watson:PERSON
# five o'clock:TIME
# Sherlock Holmes:PERSON
# an hour:TIME
# two:CARDINAL
# Just before nine o'clock:TIME
# Sherlock Holmes:PERSON
# five:CARDINAL
# the afternoon:TIME
# Holmes:PERSON
# Duke:ORG
# one:CARDINAL
# St. Simon:PERSON
# Holmes:PERSON
# St. Simon:PERSON
# St. Simon:PERSON
# Francis Hay Moulton:PERSON
# Robert:PERSON
# Frank:PERSON
# Moulton:PERSON
# Europe:LOC
# America:GPE
# Frank:PERSON
# '84:DATE
# McQuire:GPE
# Rockies:LOC
# Frank:PERSON
# one day:DATE
# Frank:PERSON
# Frank:PERSON
# last pa
# :DATE
# Frisco:ORG
# Frank:PERSON
# Frank:PERSON
# the end of
# :DATE
# Frank:PERSON
# Frank:PERSON
# Montana:GPE
# Arizona:GPE
# Mexico:GPE
# Apache Indians:NORP
# Frank:PERSON
# months:DATE
# Frisco:GPE
# a
# year:DATE
# Frank:PERSON
# Frisco:GPE
# London:GPE
# Frank:PERSON
# Frank:PERSON
# first:ORDINAL
# first:ORDINAL
# California:GPE
# ten
# minutes:TIME
# Frank:PERSON
# Frank:PERSON
# Gordon Square:FAC
# Frank
# :PERSON
# Apaches:PRODUCT
# Frisco:ORG
# England:GPE
# second:ORDINAL
# American:NORP
# Frank:PERSON
# Frank:PERSON
# Paris:GPE
# Holmes:PERSON
# this evening:TIME
# Frank:PERSON
# Robert:PERSON
# Holmes:PERSON
# good-night:TIME
# Sherlock Holmes:PERSON
# American:NORP
# Moulton:PERSON
# some day:DATE
# Jack:PERSON
# Stars and Stripes:WORK_OF_ART
# Holmes:PERSON
# first:ORDINAL
# Scotland Yard:ORG
# first:ORDINAL
# two:CARDINAL
# a few minutes:TIME
# the
# morning:TIME
# America:GPE
# American:NORP
# American:NORP
# Lestrade:PERSON
# a week:DATE
# one:CARDINAL
# London:GPE
# Eight shillings:MONEY
# London:GPE
# second:ORDINAL
# Northumberland Avenue:FAC
# Francis H. Moulton:PERSON
# American:NORP
# only the day before:DATE
# 226:CARDINAL
# Gordon Square:PERSON
# Watson:PERSON
# Holmes:PERSON
# St. Simon:PERSON
# Holmes:PERSON
# one morning:TIME
# February:DATE
# morning:TIME
# the day:DATE
# Baker Street:FAC
# about fifty:CARDINAL
# Holmes:PERSON
# A few moments later:TIME
# Sherlock Holmes:PERSON
# Holmes:PERSON
# two:CARDINAL
# Holmes:PERSON
# Alexander Holder:PERSON
# Holder &
# Stevenson:ORG
# Threadneedle Street:FAC
# second:ORDINAL
# the City
# :GPE
# London:GPE
# London:GPE
# Baker Street:FAC
# Underground:ORG
# One:CARDINAL
# the last few years:DATE
# Yesterday morning:TIME
# earth:LOC
# England:GPE
# Holder:PERSON
# 50,000 pounds:QUANTITY
# ten:CARDINAL
# Next Monday:DATE
# morocco:GPE
# the Beryl Coronet:FAC
# One:CARDINAL
# I.:ORG
# thirty-nine:CARDINAL
# doubt--:PERSON
# four days:DATE
# Holder:PERSON
# Monday:DATE
# morning:TIME
# over fifty 1000
# pound:MONEY
# evening:TIME
# the next few days:DATE
# Streatham:GPE
# Holmes:PERSON
# three:CARDINAL
# Lucy
# Parr:PERSON
# second:ORDINAL
# a few
# months:DATE
# Arthur:PERSON
# Holmes:PERSON
# George Burnwell:PERSON
# George
# Burnwell:PERSON
# Arthur:PERSON
# Mary:PERSON
# five years ago:DATE
# Holmes:PERSON
# Arthur:PERSON
# Mary:PERSON
# Lucy Parr:PERSON
# Mary:PERSON
# Arthur:PERSON
# Arthur:PERSON
# night:TIME
# 200 pounds:MONEY
# third:ORDINAL
# the
# month:DATE
# Mary:PERSON
# Mary:PERSON
# Lucy:PERSON
# good-night:TIME
# Holmes:PERSON
# About two:CARDINAL
# house:ORG
# Arthur:PERSON
# half:CARDINAL
# One:CARDINAL
# three:CARDINAL
# three:CARDINAL
# Mary:PERSON
# first:ORDINAL
# Arthur:PERSON
# Arthur:PERSON
# five minutes:TIME
# I.:PERSON
# three:CARDINAL
# one:CARDINAL
# This morning:TIME
# 1000 pounds:QUANTITY
# one night:TIME
# Sherlock Holmes:PERSON
# some few minutes:TIME
# Arthur:PERSON
# George Burnwell:PERSON
# Arthur:PERSON
# Mary:PERSON
# four:CARDINAL
# I.:ORG
# Arthur:PERSON
# Holmes:PERSON
# first:ORDINAL
# three:CARDINAL
# thirty-nine:CARDINAL
# Holmes:PERSON
# Holder:PERSON
# Streatham:ORG
# an hour:TIME
# Holmes:PERSON
# Fairbank:ORG
# Fairbank:ORG
# two:CARDINAL
# two:CARDINAL
# Holmes:PERSON
# Holder:PERSON
# the morning:TIME
# Arthur:PERSON
# Arthur:PERSON
# Arthur:PERSON
# London:GPE
# Arthur:PERSON
# Holmes:PERSON
# Mary Holder:PERSON
# two:CARDINAL
# last night:TIME
# this morning:TIME
# last night:TIME
# two:CARDINAL
# Arthur:PERSON
# Holder:PERSON
# Francis Prosper:PERSON
# Holmes:PERSON
# Holmes:PERSON
# one:CARDINAL
# Holmes:PERSON
# Sherlock Holmes:PERSON
# thirty-six:CARDINAL
# three:CARDINAL
# Holder:PERSON
# Holmes:PERSON
# Holmes:PERSON
# Holder:PERSON
# a few yards:QUANTITY
# Holder:PERSON
# an
# hour:TIME
# Holmes:PERSON
# last night:TIME
# Baker Street:FAC
# morning:TIME
# between nine and ten:DATE
# evening:TIME
# three:CARDINAL
# a few minutes:TIME
# Watson:PERSON
# a few
# hours:TIME
# two:CARDINAL
# Streatham:ORG
# a few minutes later:TIME
# hunt:ORG
# midnight:TIME
# days:DATE
# what hour:TIME
# Watson:PERSON
# this
# :TIME
# morning:TIME
# nine now:DATE
# the morning:TIME
# Only two days ago:DATE
# Mary:PERSON
# this morning:TIME
# last night:TIME
# Holmes:PERSON
# Holder:PERSON
# the end of
# :DATE
# Holmes:PERSON
# 1000 pounds:QUANTITY
# ten:CARDINAL
# Three thousand:CARDINAL
# 4000 pounds:QUANTITY
# Holmes
# :PERSON
# three:CARDINAL
# one:CARDINAL
# Holder:PERSON
# Sherlock
# Holmes:PERSON
# one:CARDINAL
# Arthur:PERSON
# yesterday:DATE
# this morning:TIME
# first:ORDINAL
# George Burnwell:PERSON
# England:GPE
# a hundred:CARDINAL
# nearly every evening:TIME
# last night:TIME
# about one:CARDINAL
# Arthur:PERSON
# the middle of the night:DATE
# George
# Burnwell:PERSON
# Arthur:PERSON
# George:PERSON
# Holder:PERSON
# five minutes:TIME
# Holmes:PERSON
# one:CARDINAL
# second:ORDINAL
# first:ORDINAL
# a hundred
# yards:QUANTITY
# George Burnwell:PERSON
# Arthur
# :ORG
# George:PERSON
# the night:TIME
# six shillings:MONEY
# Streatham:ORG
# yesterday:DATE
# evening:TIME
# Holder:PERSON
# first:ORDINAL
# six hundred:CARDINAL
# 1000
# pounds:MONEY
# about two o'clock:TIME
# day:DATE
# A day:DATE
# England:GPE
# Mary:PERSON
# Holmes:PERSON
# George Burnwell:PERSON
# a more than
# :PERCENT
# Sherlock
# Holmes:PERSON
# Watson:PERSON
# a cold morning:TIME
# the early spring:DATE
# Baker Street:WORK_OF_ART
# china:GPE
# Sherlock Holmes:PERSON
# all the morning:TIME
# the King
# :ORG
# Bohemia:GPE
# Mary Sutherland:PERSON
# Pshaw:PERSON
# zero:CARDINAL
# Montague Place:PERSON
# the preceding evening:TIME
# half-past ten:DATE
# half-past ten:DATE
# first:ORDINAL
# Hunter:PERSON
# Holmes:PERSON
# five years:DATE
# Spence Munro:PERSON
# two months ago:DATE
# Halifax:GPE
# Nova Scotia:GPE
# America:GPE
# Westaway:ORG
# Stoper:PERSON
# one:CARDINAL
# last week:DATE
# Stoper:PERSON
# Stoper:PERSON
# 4 pounds:QUANTITY
# Spence
# Munro:PERSON
# I.
# ':ORG
# French:NORP
# German:NORP
# Tut:ORG
# three:CARDINAL
# 100 pounds:QUANTITY
# Holmes:PERSON
# half:CARDINAL
# I.:ORG
# Hampshire:GPE
# The Copper Beeches:FAC
# five miles:QUANTITY
# Winchester:GPE
# One:CARDINAL
# one:CARDINAL
# six years old:DATE
# Three:CARDINAL
# Holmes:PERSON
# I.:ORG
# Stoper:PERSON
# a few more
# :CARDINAL
# Stoper:PERSON
# Hunter:PERSON
# Holmes:PERSON
# two or:CARDINAL
# three:CARDINAL
# England:GPE
# 100 pounds:QUANTITY
# Next day:DATE
# the day:DATE
# The Copper Beeches:WORK_OF_ART
# Winchester:GPE
# Stoper:PERSON
# 30 pounds:QUANTITY
# 120 pounds:MONEY
# a
# year:DATE
# one:CARDINAL
# Alice:PERSON
# Philadelphia:GPE
# Winchester:GPE
# JEPHRO RUCASTLE:ORG
# Holmes:PERSON
# Hunter:PERSON
# Holmes:PERSON
# Holmes:PERSON
# only one:CARDINAL
# Rucastle:PERSON
# Holmes:PERSON
# 120 pounds:QUANTITY
# 40 pounds:QUANTITY
# some months:DATE
# Holmes:PERSON
# day:DATE
# night:TIME
# Hampshire:GPE
# Rucastle:PERSON
# Winchester:PERSON
# Holmes:PERSON
# Holmes:PERSON
# Holmes:PERSON
# half an hour:TIME
# Data:ORG
# late one night:TIME
# Holmes:PERSON
# one:CARDINAL
# Bradshaw:PERSON
# the Black Swan Hotel:FAC
# Winchester:GPE
# midday:TIME
# Holmes:PERSON
# half-past nine:DATE
# Bradshaw:PERSON
# Winchester:GPE
# 11:30:TIME
# the
# morning:TIME
# eleven o'clock the next day:TIME
# English:NORP
# Holmes:PERSON
# morning:TIME
# Hampshire:GPE
# an ideal
# :DATE
# spring day:DATE
# Aldershot:GPE
# Baker Street:FAC
# Holmes:PERSON
# Watson:PERSON
# Watson:PERSON
# London:GPE
# ,
# year in, year:DATE
# Winchester:GPE
# the five miles:QUANTITY
# Winchester:GPE
# seven:CARDINAL
# Hunter:PERSON
# The Black Swan:WORK_OF_ART
# Rucastle:PERSON
# three:CARDINAL
# this morning:TIME
# Holmes:PERSON
# first:ORDINAL
# Rucastle:PERSON
# Rucastle:PERSON
# the Copper Beeches:LOC
# three:CARDINAL
# Southampton:GPE
# Lord
# Southerton's:ORG
# Holmes:PERSON
# Baker Street:FAC
# Rucastle:PERSON
# seven years:DATE
# first:ORDINAL
# Philadelphia:GPE
# Rucastle:PERSON
# less than twenty:CARDINAL
# Rucastle:PERSON
# one:CARDINAL
# Holmes:PERSON
# one:CARDINAL
# only two:CARDINAL
# Toller:PERSON
# Rucastle:PERSON
# Rucastle:PERSON
# one:CARDINAL
# two days:DATE
# the Copper Beeches:FAC
# third:ORDINAL
# Rucastle:PERSON
# Hunter:PERSON
# Rucastle:PERSON
# three:CARDINAL
# this I was
# :DATE
# Rucastle:PERSON
# Rucastle:PERSON
# an hour:TIME
# Rucastle:PERSON
# the
# day:DATE
# Edward:PERSON
# Two days later:DATE
# about ten minutes:TIME
# Holmes:PERSON
# first:ORDINAL
# first:ORDINAL
# second:ORDINAL
# the Southampton Road:FAC
# Rucastle:PERSON
# Jephro:PERSON
# Hunter:PERSON
# Hunter:PERSON
# Rucastle:PERSON
# a week ago:DATE
# Holmes:PERSON
# the very first day:DATE
# Rucastle:PERSON
# 'Look in here!':WORK_OF_ART
# Rucastle:PERSON
# two:CARDINAL
# two:CARDINAL
# Carlo:PRODUCT
# Toller:PERSON
# Toller:PERSON
# night:TIME
# two nights later:DATE
# about two o'clock in the morning:TIME
# London:GPE
# One evening:TIME
# two:CARDINAL
# the first two
# :DATE
# third:ORDINAL
# first:ORDINAL
# only one:CARDINAL
# two:CARDINAL
# Holmes:PERSON
# one:CARDINAL
# the quarters of
# :DATE
# One day:DATE
# Rucastle:PERSON
# brow:PERSON
# four
# :CARDINAL
# three:CARDINAL
# Rucastle:PERSON
# one
# :CARDINAL
# Holmes:PERSON
# only yesterday:DATE
# Rucastle:PERSON
# Toller:PERSON
# yesterday:DATE
# evening:TIME
# Rucastle:PERSON
# three:CARDINAL
# two:CARDINAL
# one:CARDINAL
# Holmes:PERSON
# Rucastle:PERSON
# Holmes:PERSON
# about half a mile:QUANTITY
# Toller:PERSON
# awake half the night:TIME
# Winchester:GPE
# this
# morning:TIME
# three o'clock:TIME
# Rucastle:PERSON
# evening:TIME
# Holmes:PERSON
# Holmes:PERSON
# Toller:ORG
# Rucastle:PERSON
# one:CARDINAL
# the Copper Beeches:FAC
# seven o'clock:TIME
# I. The Rucastles:ORG
# Toller:PERSON
# Toller:PERSON
# only one:CARDINAL
# Alice
# :PERSON
# Rucastle:PERSON
# Rucastle:PERSON
# night:TIME
# Watson:PERSON
# first:ORDINAL
# Holmes:PERSON
# A
# thousand:CARDINAL
# seven o'clock:TIME
# that hour:TIME
# the Copper Beeches:LOC
# Holmes:PERSON
# Toller:PERSON
# Rucastle:PERSON
# Holmes:PERSON
# Miss
# Hunter:ORG
# Holmes:PERSON
# Holmes:PERSON
# Miss
# Hunter:PERSON
# Watson:PERSON
# Holmes:PERSON
# Hunter:PERSON
# Hunter:PERSON
# Watson:PERSON
# Hunter:PERSON
# Sherlock Holmes:PERSON
# Hunter:PERSON
# I.:ORG
# Holmes:PERSON
# two days:DATE
# Holmes:PERSON
# Toller:PERSON
# Rucastle:PERSON
# Toller:PERSON
# Hunter:PERSON
# Rucastle:PERSON
# Holmes:PERSON
# Toller:PERSON
# Alice:PERSON
# Alice:PERSON
# Fowler:PERSON
# Alice:PERSON
# Rucastle:PERSON
# six weeks:DATE
# Holmes:PERSON
# Rucastle:PERSON
# London:GPE
# Fowler:PERSON
# Fowler:PERSON
# Fowler:PERSON
# Toller:PERSON
# Toller:PERSON
# Holmes:PERSON
# Rucastle:PERSON
# Watson:PERSON
# Hunter:PERSON
# Winchester:GPE
# one:CARDINAL
# Rucastle:PERSON
# Rucastle:PERSON
# Fowler:PERSON
# Miss Rucastle:PERSON
# Southampton:GPE
# the day:DATE
# Mauritius:GPE
# Violet Hunter:PERSON
# Holmes:PERSON
# one:CARDINAL
# Walsall:GPE
# Gutenberg:PERSON
# The Adventures of Sherlock Holmes:WORK_OF_ART
# Arthur Conan Doyle:PERSON
# SHERLOCK HOLMES:PERSON
# 1661-8.txt or:TIME
# Gutenberg:PERSON
# Jose Menendez:PERSON
# United States:GPE
# Foundation:ORG
# the United States:GPE
# Gutenberg-tm:PERSON
# Gutenberg:WORK_OF_ART
# eBooks:ORG
# eBook:EVENT
# eBook:EVENT
# Project
# Gutenberg:WORK_OF_ART
# Gutenberg-tm License:ORG
# http://gutenberg.net/license:MONEY
# 1:CARDINAL
# Gutenberg-tm:PERSON
# Gutenberg-tm:ORG
# Gutenberg-tm:PERSON
# 1.E.8:CARDINAL
# 1.B.:DATE
# Gutenberg:WORK_OF_ART
# a few:CARDINAL
# Gutenberg-tm electronic:PERSON
# 1.C.:PERSON
# Literary Archive Foundation:ORG
# Foundation:ORG
# PGLAF:ORG
# the United States:GPE
# the United States:GPE
# the United States:GPE
# Gutenberg-tm:PERSON
# Gutenberg-tm:PERSON
# Gutenberg-tm License:ORG
# 1.D.:CARDINAL
# the United States:GPE
# Project:ORG
# Foundation:ORG
# the United
# States:GPE
# Gutenberg:PERSON
# Gutenberg-tm License:ORG
# Project Gutenberg:WORK_OF_ART
# Project
# Gutenberg:WORK_OF_ART
# eBook:EVENT
# the Project Gutenberg License:ORG
# eBook:EVENT
# 1.E.2:CARDINAL
# the United States:GPE
# Gutenberg:WORK_OF_ART
# Gutenberg-tm:PERSON
# 1.E.8 or
# 1.E.9:DATE
# any additional
# :CARDINAL
# 1.E.4:CARDINAL
# Gutenberg-tm
# License:ORG
# paragraph 1.E.1:DATE
# Gutenberg-tm License:ORG
# 1.E.6:CARDINAL
# Plain Vanilla ASCII:ORG
# Gutenberg-tm:ORG
# Plain Vanilla ASCII:WORK_OF_ART
# Gutenberg-tm
# License:ORG
# 1.E.1:CARDINAL
# 1.E.8:CARDINAL
# 1.E.8:CARDINAL
# Gutenberg-tm:PERSON
# 20%:PERCENT
# Literary Archive Foundation:ORG
# 60 days:DATE
# Literary Archive Foundation:ORG
# Section 4:LAW
# Literary Archive Foundation:ORG
# 30 days:DATE
# Gutenberg-tm
#      License:PERSON
# 1.F.3:CARDINAL
# 90 days:DATE
# Gutenberg-tm:PERSON
# Literary Archive Foundation:ORG
# Michael
# Hart:PERSON
# the
# Foundation:ORG
# Section 3:LAW
# 1.F.:CARDINAL
# 1.F.1:CARDINAL
# Gutenberg:PERSON
# Gutenberg-tm electronic:PERSON
# 1.F.2:CARDINAL
# 1.F.3:CARDINAL
# Gutenberg Literary Archive Foundation:ORG
# 1.F.3:CARDINAL
# 90 days:DATE
# second:ORDINAL
# second:ORDINAL
# 1.F.3:CARDINAL
# EXPRESS:ORG
# MERCHANTIBILITY:ORG
# 1.F.6:ORG
# Foundation:ORG
# Foundation:ORG
# Gutenberg-tm:PERSON
# Gutenberg-tm:PERSON
# Gutenberg-tm:PERSON
# 2:CARDINAL
# the Mission of Project:ORG
# Gutenberg-tm:PERSON
# Gutenberg-tm:ORG
# hundreds:CARDINAL
# Gutenberg-tm's:PERSON
# 2001:DATE
# Gutenberg Literary Archive Foundation:ORG
# Literary Archive Foundation:ORG
# Sections 3 and 4
# :LAW
# Foundation:ORG
# http://www.pglaf.org:ORG
# 3:CARDINAL
# Literary Archive
# Foundation:ORG
# Literary Archive Foundation:ORG
# 501(c)(3:CARDINAL
# Mississippi:GPE
# the Internal
# Revenue Service:ORG
# EIN:ORG
# 64-6221541:DATE
# 501(c)(3:CARDINAL
# Literary Archive Foundation:ORG
# U.S.:GPE
# Foundation:ORG
# S.
# :PERSON
# Fairbanks:GPE
# AK:GPE
# 99712:DATE
# Salt Lake City:GPE
# 801:CARDINAL
# 596-1887:DATE
# Foundation:ORG
# Gregory B. Newby:PERSON
# Literary Archive Foundation:ORG
# Gutenberg-tm:ORG
# $1 to $5,000:MONEY
# IRS:ORG
# Foundation:ORG
# 50:CARDINAL
# the United
# States:GPE
# the United States:GPE
# U.S.:GPE
# Section 5:LAW
# Gutenberg-tm electronic:PERSON
# Michael S. Hart:PERSON
# thirty years:DATE
# Gutenberg-tm eBooks:ORG
# U.S.:GPE
# eBooks:ORG
# Gutenberg-tm:PERSON
# Gutenberg Literary:PERSON
# eBooks:ORG
# eBooks:ORG

# %%
def new_dictionary3(document):
    ent_text3 = []
    for entity in document3.ents:
        ent_text3.append(entity.text)

    dict_ent_name3 = Counter(ent_text3)

    return dict_ent_name3

def new_dataframe3(document):
    df_ent3 = new_dictionary3(document)
    df_doc3 = pd.DataFrame(data = {'name' :df_ent3.keys(), 'count' : df_ent3.values()})
    return df_doc3

my_new_dict_3 = new_dictionary3(document3)
new_doc3 = new_dataframe3(my_new_dict_3)
new_doc3.head(5)
sorted_Holmes_1 = new_doc3.sort_values(by = 'count', ascending = False)
sorted_Holmes_1_20 = sorted_Holmes_1[:20]
sorted_Holmes_1_20.head()
# Out:
#                name  count
# 25           Holmes    353
# 24              one    106
# 50              two     98
# 6   Sherlock Holmes     82
# 40           Watson     80

# %%
def new_dictionary33(document):
    ent_label33 = []
    for entity in document3.ents:
        ent_label33.append(entity.label_)

    dict_ent_name33 = Counter(ent_label33)

    return dict_ent_name33

def new_dataframe33(document):
    df_ent33 = new_dictionary22(document)
    df_doc33 = pd.DataFrame(data = {'name' :df_ent33.keys(), 'count' : df_ent33.values()})
    return df_doc33

my_new_dict_33 = new_dictionary33(document3)
new_doc33 = new_dataframe33(my_new_dict_33)
sorted_Holmes_33 = new_doc33.sort_values(by = 'count', ascending = False)
#sorted_Holmes_22.head(20)

# %%
plt.bar(sorted_Holmes_1_20['name'], sorted_Holmes_1_20['count'], color = 'orange')
fig = plt.gcf()
fig.set_size_inches(13.5, 10.5)
plt.xticks(rotation = 45)
plt.title('20 Most Common Named Entities')
plt.xlabel('Names')
plt.ylabel('Count')
xs = sorted_Holmes_1_20['name']
ys = sorted_Holmes_1_20['count']
for x,y in zip(xs,ys):

    label = "{:.2f}".format(y)

    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') 
plt.show()

# %%
plt.bar(sorted_Holmes_33['name'], sorted_Holmes_33['count'], color= 'orange')
fig = plt.gcf()
fig.set_size_inches(10.5, 10.5)
plt.xticks(rotation = 45)
plt.rcParams["figure.figsize"] = (40,3)
plt.title('Count of Entities')
plt.xlabel('Entities')
plt.ylabel('Count')
xs = sorted_Holmes_33['name']
ys = sorted_Holmes_33['count']
for x,y in zip(xs,ys):

    label = "{:.2f}".format(y)

    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') 
plt.show()

# %% [markdown]
# ### Question 5 Answer
#
# When using spaCY to find the names entities in my document, I noticed there was a significant difference in the number of organizations found in Sherlock Holmes as opposed to the Great Gatsby or Monty Python and the Holy Grail. Additionally, the Great Gatsby used "Person" nearly twice as often as the other items. I used documents of similar size so I could compare the results against once another.
#
# Plotting the results helped depict the story of the data - Great Gatsby uses "Person" as the primary focus. If you read the story, you would recognize that this is the style of F. Scott Fitzgerald and this story specifically. Names are referenced constantly throughout the story. Alternatively, in Monty Python and Sherlock Holmes, they reference organizations frequently - which if you have watched Monty Python and the Holy Grail, they reference their organizations frequently, e.g. Knights of Camelot.
