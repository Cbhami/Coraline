# %% [markdown]
# <a href="https://colab.research.google.com/github/Cbhami/Coraline/blob/main/Notebook_of_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#The first thing we need to do is import the packages needed for the entire assignment
import textblob as tb
import numpy as np
import pandas as pd
import nltk as nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from pathlib import Path
from textblob import TextBlob
from operator import itemgetter
from pathlib import Path
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#Just for fun, comparing my last paper to one of the earliest I can find
from pathlib import Path
from textatistic import Textatistic
Paper1 = str(Path('Paper2010.txt').read_text())

textatistic_first = Paper1.read_text()
textatistic_diss = Path('Dissertation.txt').read_text()

readability_first = Textatistic(textatistic_first)
readability_diss = Textatistic(textatistic_diss)

# %precision 3
readability_first.dict()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\coleb\OneDrive\Cosmo\Notebook_of_Notes.ipynb Cell 13' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/coleb/OneDrive/Cosmo/Notebook_of_Notes.ipynb#ch0000012?line=2'>3</a> from textatistic import Textatistic
#       <a href='vscode-notebook-cell:/c%3A/Users/coleb/OneDrive/Cosmo/Notebook_of_Notes.ipynb#ch0000012?line=3'>4</a> Paper1 = str(Path('Paper2010.txt').read_text())
# ----> <a href='vscode-notebook-cell:/c%3A/Users/coleb/OneDrive/Cosmo/Notebook_of_Notes.ipynb#ch0000012?line=5'>6</a> textatistic_first = Paper1.read_text()
#       <a href='vscode-notebook-cell:/c%3A/Users/coleb/OneDrive/Cosmo/Notebook_of_Notes.ipynb#ch0000012?line=6'>7</a> textatistic_diss = Path('Dissertation.txt').read_text()
#       <a href='vscode-notebook-cell:/c%3A/Users/coleb/OneDrive/Cosmo/Notebook_of_Notes.ipynb#ch0000012?line=8'>9</a> readability_first = Textatistic(textatistic_first)
#
# AttributeError: 'str' object has no attribute 'read_text'

# %%
import spacy #import the large spaCY package
nlp_lg = spacy.load('en_core_web_lg') 
document4 =nlp_lg(Path('Dissertation.txt').read_text())  #converting my dissertation to a txt file_extension
document5 = nlp_lg(Path('Paper2010.txt').read_text())

# %%
docsim=document4.similarity(document5)
print(f'First Paper (2010) to Final Dissertation (2021) similarity is {docsim:.3}.')
# Out:
# First Paper (2010) to Final Dissertation (2021) similarity is 0.935.

# %%
from pathlib import Path
mydiss = open("Dissertation.txt", "r", encoding='utf8') #Remember to add encoding = utf8 inside the open command

DissertationText = Path('Dissertation.txt').read_text()
#DissertationManuscript = mydiss.read()

# %%
dissblob = TextBlob(DissertationText)
dissblob.word_counts
# Out:
# defaultdict(int,
#             {'a': 605,
#              'phenomenological': 73,
#              'study': 94,
#              'of': 1154,
#              'positive': 210,
#              'and': 1522,
#              'effective': 204,
#              'leadership': 428,
#              '’': 540,
#              's': 377,
#              'influence': 63,
#              'on': 235,
#              'success': 137,
#              'in': 607,
#              'iowa': 204,
#              'army': 400,
#              'recruiting': 411,
#              'companies': 207,
#              'dissertation': 34,
#              'manuscript': 3,
#              'submitted': 2,
#              'to': 1136,
#              'northcentral': 7,
#              'university': 13,
#              'school': 3,
#              'business': 18,
#              'partial': 2,
#              'fulfillment': 2,
#              'the': 2342,
#              'requirements': 13,
#              'for': 280,
#              'degree': 5,
#              'doctor': 1,
#              'philosophy': 1,
#              'by': 114,
#              'cole': 3,
#              'barrett': 1,
#              'hamilton': 2,
#              'la': 1,
#              'jolla': 1,
#              'california': 2,
#              'january': 5,
#              '2021': 2,
#              'abstract': 1,
#              'management': 55,
#              'practices': 49,
#              'associated': 70,
#              'with': 283,
#              'northern': 14,
#              'des': 10,
#              'moines': 10,
#              'city': 11,
#              'minneapolis': 1,
#              'battalion': 3,
#              'higher': 34,
#              'headquarters': 73,
#              'were': 162,
#              'examined': 4,
#              'determine': 28,
#              'how': 95,
#              'three': 66,
#              'similarly': 4,
#              'resourced': 1,
#              'situated': 1,
#              'obtained': 8,
#              'different': 12,
#              'levels': 84,
#              'or': 142,
#              'failures': 7,
#              'within': 121,
#              'recent': 8,
#              'history': 4,
#              'theoretical': 27,
#              'framework': 30,
#              'this': 148,
#              'was': 183,
#              'rooted': 7,
#              'locke': 86,
#              'goal-setting': 56,
#              'theory': 95,
#              'qualitative': 70,
#              'data': 111,
#              'gathered': 11,
#              'from': 175,
#              'recruiters': 203,
#              'station': 143,
#              'commanders': 123,
#              'throughout': 46,
#              'state': 22,
#              'understand': 6,
#              'an': 220,
#              'equal': 2,
#              'allocation': 1,
#              'funding': 1,
#              'equipment': 2,
#              'primary': 44,
#              'influencer': 3,
#              'failure': 25,
#              'may': 41,
#              'rest': 2,
#              'those': 26,
#              'persons': 12,
#              'charged': 7,
#              'leading': 5,
#              'results': 49,
#              'substantiated': 1,
#              'successful': 71,
#              'that': 281,
#              'be': 207,
#              'replicated': 3,
#              'across': 5,
#              'entire': 9,
#              'u.s': 46,
#              'command': 46,
#              'improving': 1,
#              'organization': 135,
#              'prove': 5,
#              'more': 78,
#              'viable': 2,
#              'approach': 35,
#              'achieving': 28,
#              'fiscal': 8,
#              'year': 12,
#              'beyond': 11,
#              'semistructured': 29,
#              'interviews': 38,
#              'four': 39,
#              'stations': 38,
#              'each': 24,
#              'company': 55,
#              'findings': 27,
#              'revealed': 6,
#              'clearly': 5,
#              'defined': 10,
#              'principles': 21,
#              'usarec': 119,
#              'implications': 14,
#              'describe': 13,
#              'leaders': 236,
#              'use': 26,
#              'their': 444,
#              'achieve': 89,
#              'mission': 101,
#              'indicated': 24,
#              'relationship': 96,
#              'between': 93,
#              'behaviors': 182,
#              'recommendations': 13,
#              'include': 26,
#              'further': 28,
#              'analysis': 51,
#              'driving': 19,
#              'factors': 26,
#              'research': 237,
#              'if': 52,
#              'other': 43,
#              'leverage': 27,
#              'is': 235,
#              'also': 43,
#              'recommended': 7,
#              'effects': 27,
#              'toxic': 45,
#              'organizations': 49,
#              'researchers': 26,
#              'should': 39,
#              'continue': 10,
#              'conduct': 15,
#              'realized': 8,
#              'perspectives': 14,
#              'second': 13,
#              'recommendation': 2,
#              'explore': 5,
#              'are': 228,
#              'considered': 9,
#              'hostile': 3,
#              'abusive': 7,
#              'destroy': 3,
#              'trust': 32,
#              'credibility': 11,
#              'while': 39,
#              'spurring': 2,
#              'resentment': 2,
#              'acknowledgments': 1,
#              'i': 40,
#              'want': 3,
#              'acknowledge': 3,
#              'my': 14,
#              'wife': 1,
#              'leslie': 1,
#              'our': 3,
#              'beautiful': 2,
#              'boys': 2,
#              'tireless': 2,
#              'support': 31,
#              'balanced': 1,
#              'professional': 22,
#              'academic': 5,
#              'personal': 25,
#              'goals': 70,
#              'they': 123,
#              'sacrificed': 1,
#              'equally': 8,
#              'not': 88,
#              'allowing': 3,
#              'me': 5,
#              'dedicate': 1,
#              'countless': 1,
#              'hours': 7,
#              'toward': 12,
#              'pursuing': 3,
#              'endeavors': 1,
#              'without': 7,
#              'family': 4,
#              'would': 64,
#              'never': 9,
#              'have': 108,
#              'accomplished': 5,
#              'set': 25,
#              'myself': 1,
#              'like': 19,
#              'parents': 1,
#              'sherry': 1,
#              'bo': 1,
#              'parents-in-law': 1,
#              'pamela': 1,
#              'ron': 1,
#              'being': 33,
#              'unconditionally': 2,
#              'supportive': 3,
#              'encouraging': 10,
#              'understanding': 15,
#              'achieved': 13,
#              'realize': 7,
#              'am': 4,
#              'blessed': 1,
#              'who': 106,
#              'supports': 2,
#              'encourages': 2,
#              'desire': 9,
#              'life-long': 1,
#              'education': 6,
#              'has': 47,
#              'been': 37,
#              'most': 33,
#              'exceptional': 2,
#              'system': 2,
#              'over': 26,
#              'last': 8,
#              '10': 28,
#              'years': 18,
#              'academia': 1,
#              'look': 4,
#              'forward': 1,
#              'passing': 1,
#              'along': 2,
#              'same': 13,
#              'level': 54,
#              'passion': 2,
#              'two': 28,
#              'wonderful': 1,
#              'dad': 1,
#              'wish': 1,
#              'you': 35,
#              'could': 33,
#              'here': 1,
#              'see': 9,
#              'us': 4,
#              'now': 2,
#              'table': 7,
#              'contents': 1,
#              'chapter': 20,
#              '1': 59,
#              'introduction': 7,
#              'statement': 11,
#              'problem': 17,
#              '3': 42,
#              'purpose': 37,
#              '4': 45,
#              '6': 24,
#              'methodology': 7,
#              'design': 40,
#              '8': 10,
#              'questions': 56,
#              '9': 7,
#              'significance': 5,
#              'definitions': 3,
#              'key': 7,
#              'terms': 9,
#              '13': 5,
#              'summary': 9,
#              '16': 3,
#              '2': 56,
#              'literature': 21,
#              'review': 43,
#              '18': 15,
#              '20': 14,
#              'behavior': 38,
#              '24': 3,
#              'task-oriented': 18,
#              '25': 22,
#              'relations-oriented': 22,
#              '28': 6,
#              'external': 30,
#              '37': 3,
#              'leader-member': 50,
#              'exchange': 68,
#              'lmx': 118,
#              '40': 2,
#              'measurement': 7,
#              'quality': 10,
#              '43': 1,
#              'antecedents': 19,
#              'member': 34,
#              'consequences': 14,
#              '46': 2,
#              'emotional': 63,
#              'intelligence': 56,
#              '63': 1,
#              '66': 3,
#              'method': 36,
#              '69': 3,
#              '71': 1,
#              'population': 47,
#              'sample': 31,
#              '77': 2,
#              'materials': 5,
#              'instrumentation': 3,
#              '80': 2,
#              'procedures': 18,
#              '82': 2,
#              'collection': 10,
#              '84': 1,
#              'assumptions': 10,
#              '87': 2,
#              'limitations': 13,
#              '88': 4,
#              'delimitations': 4,
#              '89': 1,
#              'ethical': 7,
#              'assurances': 3,
#              '90': 3,
#              '91': 3,
#              '93': 5,
#              'trustworthiness': 8,
#              '94': 3,
#              'transferability': 4,
#              '95': 6,
#              'dependability': 7,
#              'confirmability': 4,
#              '96': 3,
#              'question': 46,
#              '98': 3,
#              '101': 9,
#              '104': 1,
#              '107': 1,
#              'evaluation': 6,
#              '108': 2,
#              '112': 1,
#              '5': 22,
#              'conclusions': 5,
#              '113': 1,
#              '119': 1,
#              '120': 2,
#              '121': 1,
#              '123': 1,
#              '125': 1,
#              'practice': 12,
#              '127': 1,
#              'future': 25,
#              '129': 1,
#              '131': 1,
#              'references': 2,
#              '134': 1,
#              'appendices': 2,
#              '150': 2,
#              'appendix': 7,
#              'interview': 69,
#              '151': 1,
#              'b': 28,
#              'informed': 7,
#              'consent': 10,
#              'form': 18,
#              '152': 1,
#              'list': 2,
#              'tables': 1,
#              'domain': 5,
#              'approaches': 10,
#              '42': 3,
#              'demographic': 5,
#              'information': 22,
#              'respondents': 74,
#              '97': 3,
#              'figures': 1,
#              'figure': 28,
#              'commander': 25,
#              'visualization': 3,
#              'eight': 12,
#              'functions': 10,
#              '30': 3,
#              'network': 6,
#              '38': 5,
#              '47': 2,
#              'leader': 227,
#              'charisma': 6,
#              'contagion': 7,
#              'emotions': 16,
#              'followers': 23,
#              '56': 1,
#              'competencies': 9,
#              '64': 1,
#              '7': 11,
#              'concept': 20,
#              'experience': 36,
#              '81': 1,
#              'steps': 10,
#              '83': 3,
#              'human': 31,
#              'resource': 8,
#              'departments': 2,
#              'tasked': 5,
#              'critical': 49,
#              'role': 38,
#              'staffing': 2,
#              'right': 5,
#              'positions': 11,
#              'personnel': 14,
#              'gurchiek': 2,
#              '2008': 9,
#              'manage': 9,
#              'vital': 8,
#              'areas': 11,
#              'disastrous': 1,
#              'any': 18,
#              'there': 49,
#              'delicate': 1,
#              'balance': 4,
#              'hiring': 5,
#              'employees': 68,
#              'meet': 3,
#              'end-strength': 3,
#              'best-qualified': 1,
#              'candidates': 3,
#              'firm': 1,
#              'managers': 16,
#              'resources': 18,
#              'department': 16,
#              'even': 7,
#              'structuring': 1,
#              'executing': 2,
#              'objectives': 2,
#              'which': 63,
#              'will': 110,
#              'result': 13,
#              'attracting': 3,
#              'highly': 14,
#              'qualified': 5,
#              'performers': 1,
#              'team': 86,
#              'sartain': 2,
#              'n.d': 12,
#              'responsibility': 15,
#              'lies': 2,
#              'manager': 4,
#              'ensure': 17,
#              'units': 7,
#              'equipped': 2,
#              'tools': 10,
#              'furthermore': 20,
#              'essential': 12,
#              'element': 13,
#              'strategy': 20,
#              'davisu': 1,
#              '2006': 28,
#              'leveraging': 9,
#              'empowering': 16,
#              'operationalizing': 1,
#              'force': 10,
#              'strategic': 7,
#              'objective': 4,
#              'pertaining': 1,
#              'unit': 15,
#              'strength': 6,
#              'talent': 3,
#              'argue': 2,
#              '2015': 75,
#              'mbugua': 2,
#              'et': 158,
#              'al': 159,
#              'rovero': 2,
#              '2016': 11,
#              'directly': 16,
#              'connection': 9,
#              'its': 31,
#              'employee': 61,
#              'performance': 83,
#              'retention': 3,
#              'overall': 26,
#              'citizenship': 19,
#              'rafiei': 2,
#              'davari': 2,
#              'topic': 3,
#              'focused': 23,
#              'determining': 6,
#              'what': 52,
#              'recruiter': 37,
#              'efficiency': 17,
#              'fosters': 2,
#              'productive': 25,
#              'work': 76,
#              'environment': 18,
#              'boosts': 4,
#              'relationships': 62,
#              'amongst': 7,
#              'all': 50,
#              'sets': 4,
#              'guidelines': 5,
#              'promotes': 4,
#              'communication': 26,
#              'methods': 74,
#              'drives': 7,
#              'organizational': 108,
#              'values': 10,
#              'meaningfulness': 4,
#              'lis': 7,
#              'one': 85,
#              'characteristics': 40,
#              'ability': 69,
#              'improve': 25,
#              'efficiently': 8,
#              'influencing': 16,
#              'processes': 17,
#              'yukl': 72,
#              '2012': 122,
#              'definition': 5,
#              'aggregation': 3,
#              'concepts': 23,
#              'two-fold': 2,
#              'doctrine': 9,
#              'states': 38,
#              'must': 68,
#              '“': 98,
#              'people': 18,
#              'providing': 10,
#              'direction': 21,
#              'motivation': 65,
#              'accomplish': 13,
#              '”': 97,
#              '2019a': 27,
#              'p': 97,
#              '11': 11,
#              'first': 33,
#              'provide': 20,
#              '–': 8,
#              'stated': 36,
#              'fundamentals': 11,
#              'then': 6,
#              'able': 11,
#              'idea': 6,
#              'identified': 38,
#              'roots': 2,
#              'therefore': 27,
#              'conducted': 20,
#              'analyze': 26,
#              'culmination': 2,
#              'as': 219,
#              'single': 6,
#              'influences': 12,
#              'united': 34,
#              'both': 15,
#              'soldiers': 65,
#              'civilians': 1,
#              'meeting': 3,
#              'congressionally': 3,
#              'mandated': 3,
#              'new': 14,
#              'enlisted': 1,
#              'commissioned': 1,
#              'officers': 1,
#              'john': 8,
#              'mccain': 6,
#              'national': 17,
#              'defense': 8,
#              'authorization': 6,
#              'act': 13,
#              '2019': 31,
#              '2014': 9,
#              'requirement': 1,
#              'at': 64,
#              'start': 1,
#              'expected': 8,
#              'no': 20,
#              'matter': 4,
#              'economic': 2,
#              'sociological': 1,
#              'political': 3,
#              'climate': 8,
#              'whether': 13,
#              'during': 43,
#              'time': 39,
#              'conflict': 4,
#              'peace': 2,
#              'number': 26,
#              'required': 22,
#              'staff': 1,
#              'military': 17,
#              'sake': 2,
#              'security': 8,
#              'allow': 14,
#              'remain': 5,
#              'all-volunteer': 1,
#              'free': 5,
#              'mandatory': 2,
#              'conscripted': 1,
#              'service': 5,
#              'bartlett': 2,
#              '2009': 30,
#              'unique': 6,
#              'section': 5,
#              'it': 74,
#              'focuses': 16,
#              'private': 2,
#              'sales': 4,
#              'derrtouzos': 2,
#              'garber': 2,
#              'frieman': 2,
#              '1987': 3,
#              'finding': 5,
#              'join': 2,
#              'through': 58,
#              'means': 3,
#              'possible': 5,
#              'so': 9,
#              'long': 4,
#              'remains': 4,
#              'moral': 2,
#              'legal': 1,
#              'art': 4,
#              'science': 3,
#              'mirror': 3,
#              'civilian': 8,
#              'sector': 2,
#              'chonko': 2,
#              '1991': 6,
#              'stems': 3,
#              'motivational': 8,
#              'influential': 10,
#              'theories': 20,
#              'demonstrated': 8,
#              'psychology': 33,
#              'productivity': 53,
#              'applying': 5,
#              'psychological': 7,
#              'definitively': 3,
#              'impacted': 3,
#              'engagement': 26,
#              'lyngdoh': 2,
#              '2018': 95,
#              'additional': 5,
#              'reviews': 7,
#              'analyses': 12,
#              'frameworks': 6,
#              'coupled': 7,
#              'examination': 5,
#              'solidified': 2,
#              'need': 10,
#              'focus': 30,
#              '76,500': 1,
#              '15,600': 1,
#              'enlistees': 2,
#              'into': 53,
#              'active': 24,
#              'component': 24,
#              'reserve': 28,
#              'components': 25,
#              'respectively': 2,
#              'unfortunately': 3,
#              'after': 15,
#              'efforts': 7,
#              'only': 31,
#              '69,972': 1,
#              '11,327': 1,
#              'missions': 7,
#              'ausa': 2,
#              'option': 4,
#              'quotas': 2,
#              'inwards': 1,
#              'utilize': 6,
#              'motivate': 6,
#              'lead': 23,
#              'effectively': 15,
#              'addressed': 4,
#              'lack': 20,
#              'led': 10,
#              'inability': 5,
#              'these': 38,
#              'capabilities': 3,
#              'effectiveness': 40,
#              'analyzing': 17,
#              'sub-organizations': 3,
#              'gives': 2,
#              'insight': 14,
#              'why': 6,
#              'since': 6,
#              '2005': 17,
#              'missed': 5,
#              'combined': 3,
#              '11,500': 3,
#              'baldor': 5,
#              'another': 8,
#              'occurrence': 3,
#              'goal': 73,
#              'impact': 10,
#              'raise': 1,
#              'challenges': 5,
#              'current': 22,
#              'president': 5,
#              '2017': 38,
#              'ideal': 12,
#              'historical': 6,
#              'showed': 3,
#              'extreme': 5,
#              'fluctuations': 5,
#              'achievement': 7,
#              'five': 28,
#              'theoretically': 2,
#              'easily': 3,
#              'identifiable': 2,
#              'replicable': 2,
#              'implement': 9,
#              'strategies': 13,
#              'nearly': 9,
#              'decades': 6,
#              'war': 4,
#              'begun': 2,
#              'decline': 2,
#              'citizens': 3,
#              'propensity': 2,
#              'enlist': 4,
#              'spoehr': 5,
#              'handy': 5,
#              'reverted': 3,
#              'working': 13,
#              'six': 5,
#              'days': 4,
#              'week': 2,
#              'upwards': 2,
#              'day': 10,
#              'make': 15,
#              'up': 13,
#              'shortfalls': 6,
#              'myers': 3,
#              'increases': 4,
#              'applied': 21,
#              'pressure': 3,
#              'indicative': 6,
#              'historically': 3,
#              'destructive': 5,
#              'mcchesney': 7,
#              'surge': 2,
#              'catastrophic': 2,
#              'loss': 2,
#              'committing': 2,
#              'suicide': 2,
#              'houston': 2,
#              'reorganizes': 1,
#              'missing': 2,
#              'surfacing': 2,
#              'indicating': 2,
#              'reversion': 2,
#              'harmful': 1,
#              'techniques': 6,
#              'identify': 18,
#              'utilized': 14,
#              'maximize': 10,
#              'bring': 3,
#              'them': 29,
#              'account': 6,
#              '54': 2,
#              '3rd': 3,
#              'brigade': 3,
#              'representative': 2,
#              'than': 36,
#              '280': 3,
#              'comprised': 5,
#              'separate': 6,
#              'brigades': 3,
#              'narrowing': 3,
#              'scope': 4,
#              'errors': 3,
#              'greater': 10,
#              'insightfulness': 3,
#              're': 2,
#              'shape': 2,
#              'achieves': 5,
#              '12': 18,
#              'before': 12,
#              'attributes': 9,
#              'managerial': 7,
#              'methodologies': 7,
#              'training': 28,
#              'successes': 8,
#              'selected': 35,
#              'establishing': 12,
#              'constructive': 5,
#              'fruitful': 3,
#              'eliminate': 3,
#              'costly': 3,
#              'experienced': 8,
#              'streamlining': 4,
#              'deliver': 3,
#              'consistently': 9,
#              'implemented': 11,
#              'doing': 6,
#              'facilitate': 14,
#              'process': 71,
#              'define': 11,
#              'keep': 6,
#              'respective': 6,
#              'used': 41,
#              'ask': 3,
#              'open': 8,
#              'ended': 3,
#              'elicit': 10,
#              'enough': 12,
#              'reach': 3,
#              'proper': 9,
#              'saturation': 11,
#              'phenomena': 4,
#              'ideas': 10,
#              'helped': 7,
#              'researcher': 187,
#              'subordinates': 31,
#              'perceptions': 27,
#              'commitment': 25,
#              'power': 13,
#              'expertise': 3,
#              'target': 10,
#              'included': 20,
#              'covering': 7,
#              'purposeful': 1,
#              'sampling': 10,
#              'participants': 34,
#              'extends': 1,
#              'generalizability': 2,
#              'majority': 6,
#              'government': 2,
#              'operations': 50,
#              'can': 81,
#              '3.5': 1,
#              'times': 5,
#              'revenue': 1,
#              'growth': 7,
#              'twice': 1,
#              'profit': 1,
#              'margin': 1,
#              'focusing': 8,
#              'development': 33,
#              'strack': 2,
#              'flow': 1,
#              'capital': 4,
#              'pose': 1,
#              'significant': 14,
#              'value': 7,
#              'industry': 4,
#              'leverages': 3,
#              'cornerstone': 4,
#              'derived': 2,
#              'accredits': 1,
#              'multiple': 19,
#              'studies': 21,
#              'responsible': 8,
#              'citizen': 1,
#              'barbuto': 2,
#              'story': 3,
#              '2011': 22,
#              'fundamental': 10,
#              'sparking': 1,
#              'employ': 7,
#              'fuel': 1,
#              'previous': 7,
#              'covered': 6,
#              'answer': 10,
#              'yet': 3,
#              'uncovered': 1,
#              'however': 29,
#              'founded': 7,
#              'similar': 24,
#              'ideologies': 2,
#              'published': 3,
#              '1968': 9,
#              'refined': 1,
#              '1990s': 1,
#              'present': 3,
#              'original': 6,
#              'demonstrates': 1,
#              'thorough': 2,
#              'useful': 6,
#              'setting': 28,
#              'connected': 4,
#              'context': 5,
#              'when': 49,
#              'tool': 9,
#              'hard': 4,
#              'produce': 2,
#              'compared': 2,
#              'easy-to-achieve': 1,
#              'specificity': 1,
#              'challenging': 9,
#              'rather': 4,
#              'asking': 5,
#              'do': 31,
#              'best': 24,
#              'choice': 2,
#              'dictated': 2,
#              'behavioral': 6,
#              'intentions': 2,
#              'addition': 7,
#              'moderators': 7,
#              'feasibility': 1,
#              'latham': 61,
#              'follow': 7,
#              'refers': 17,
#              'person': 12,
#              'group': 20,
#              'knowledge': 11,
#              'skill': 6,
#              'task': 36,
#              'hand': 3,
#              'significantly': 10,
#              'out': 13,
#              'contribute': 3,
#              'hundred': 2,
#              'enlistments': 2,
#              'month': 6,
#              'reasonable': 1,
#              'expectation': 2,
#              'unlikely': 1,
#              'aspects': 5,
#              'implementing': 7,
#              'ensuring': 3,
#              'individual': 29,
#              'committed': 5,
#              'uncommitted': 1,
#              'attain': 2,
#              'nature': 6,
#              'abled': 1,
#              'feedback': 20,
#              'firms': 1,
#              'rely': 4,
#              'clear': 14,
#              'consistent': 5,
#              'maintain': 7,
#              'high-performance': 2,
#              'additionally': 11,
#              'suppose': 4,
#              'input': 3,
#              'given': 31,
#              'regularly': 8,
#              'openly': 1,
#              'case': 12,
#              'unaware': 3,
#              'situations': 7,
#              'increase': 6,
#              'decrease': 2,
#              'abandon': 2,
#              'workplace': 19,
#              'hindering': 1,
#              'entirely': 1,
#              'situational': 2,
#              'constraints': 3,
#              'prepare': 1,
#              'financial': 4,
#              'technological': 1,
#              'succeed': 13,
#              'cognizant': 1,
#              'avoid': 4,
#              'becoming': 2,
#              'burden': 2,
#              'employing': 5,
#              'randomized': 4,
#              'source': 3,
#              'gave': 11,
#              'discover': 4,
#              'trends': 5,
#              'experiences': 31,
#              'measures': 7,
#              'taken': 1,
#              'strictly': 1,
#              'captured': 11,
#              'willing': 8,
#              'give': 19,
#              'provided': 13,
#              'caliber': 1,
#              'successfully': 8,
#              'validate': 2,
#              'verify': 1,
#              'lesabe': 3,
#              'nkosi': 3,
#              '2007': 13,
#              'seymen': 2,
#              ...})

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /var/mobile/Containers/Data/Application/710D0097-9BAE-411D-89FF-B987D6DEDE0B/Documents/site-packages/nltk/corpus/util.py in __load(self)
#      83                 try:
# ---> 84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
#
# /var/mobile/Containers/Data/Application/710D0097-9BAE-411D-89FF-B987D6DEDE0B/Documents/site-packages/nltk/data.py in find(resource_name, paths)
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - '/var/mobile/Containers/Data/Application/710D0097-9BAE-411D-89FF-B987D6DEDE0B/Library/Application Support/com.rationalmatter.junoapp/python-home/nltk_data'
#     - '/var/mobile/Containers/Data/Application/710D0097-9BAE-411D-89FF-B987D6DEDE0B/Library/Application Support/com.rationalmatter.junoapp/python-home/nltk_data'
#     - '/var/mobile/Containers/Data/Application/710D0097-9BAE-411D-89FF-B987D6DEDE0B/Library/Application Support/com.rationalmatter.junoapp/python-home/share/nltk_data'
#     - '/var/mobile/Containers/Data/Application/710D0097-9BAE-411D-89FF-B987D6DEDE0B/Library/Application Support/com.rationalmatter.junoapp/python-home/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-5-07d0a208b879> in <module>
#       1 from nltk.corpus import stopwords
# ----> 2 stopwords = stopwords.words('english')
#
# /var/mobile/Containers/Data/Application/710D0097-9BAE-411D-89FF-B987D6DEDE0B/Documents/site-packages/nltk/corpus/util.py in __getattr__(self, attr)
#     119             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     120
# --> 121         self.__load()
#     122         # This looks circular, but its not, since __load() changes our
#     123         # __class__ to something new:
#
# /var/mobile/Containers/Data/Application/710D0097-9BAE-411D-89FF-B987D6DEDE0B/Documents/site-packages/nltk/corpus/util.py in __load(self)
#      84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
# ---> 86                     raise e
#      87
#      88         # Load the corpus.
#
# /var/mobile/Containers/Data/Application/710D0097-9BAE-411D-89FF-B987D6DEDE0B/Documents/site-packages/nltk/corpus/util.py in __load(self)
#      79         else:
#      80             try:
# ---> 81                 root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82             except LookupError as e:
#      83                 try:
#
# /var/mobile/Containers/Data/Application/710D0097-9BAE-411D-89FF-B987D6DEDE0B/Documents/site-packages/nltk/data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords
#
#   Searched in:
#     - '/var/mobile/Containers/Data/Application/710D0097-9BAE-411D-89FF-B987D6DEDE0B/Library/Application Support/com.rationalmatter.junoapp/python-home/nltk_data'
#     - '/var/mobile/Containers/Data/Application/710D0097-9BAE-411D-89FF-B987D6DEDE0B/Library/Application Support/com.rationalmatter.junoapp/python-home/nltk_data'
#     - '/var/mobile/Containers/Data/Application/710D0097-9BAE-411D-89FF-B987D6DEDE0B/Library/Application Support/com.rationalmatter.junoapp/python-home/share/nltk_data'
#     - '/var/mobile/Containers/Data/Application/710D0097-9BAE-411D-89FF-B987D6DEDE0B/Library/Application Support/com.rationalmatter.junoapp/python-home/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %%
items2 = dissblob.word_counts.items()    #Here we assign the word count
#print(items1)
print(len(items2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2a74a4e929ef> in <module>
# ----> 1 items2 = dissblob.word_counts.items()    #Here we assign the word count
#       2 #print(items1)
#       3 print(len(items2))
#
# NameError: name 'dissblob' is not defined

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words('english') #We're looking specifically for English stop words
items = [item for item in items2 if item[0] not in stopwords]
df = pd.DataFrame(items2,columns = ['column1','column2']) 
df.sort_values(by='column2', ascending=False)
#print(stopwords)
# Out:
#          column1  column2
# 28           the     2342
# 5            and     1522
# 3             of     1154
# 21            to     1136
# 13            in      607
# ...          ...      ...
# 2663         318        1
# 2656  excitement        1
# 2655     elation        1
# 2647    cohesion        1
# 4509       email        1
#
# [4510 rows x 2 columns]

# %%
items = [item for item in items if item[0] not in stopwords]
print(len(items))
# Out:
# 4387

# %%
sorted_diss = sorted(items, key=itemgetter(1), reverse=True)

# %%
stopwords1 = ['“', '”', '’', '...', '.', ',', '-', '‘', 'Army Recruiting', 'Army', 'Iowa Army', 'recruiting']
sorted_diss2 = [pair for pair in sorted_diss if pair[0] not in stopwords1]
print(len(sorted_diss2))
#print(sorted_diss2)
# Out:
# 4382

# %%
#df_diss = pd.DataFrame(list(sorted_diss2.items()),columns = ['column1','column2'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22892/141894019.py in <module>
# ----> 1 df_diss = pd.DataFrame(list(sorted_diss2.items()),columns = ['column1','column2'])
#
# AttributeError: 'list' object has no attribute 'items'

# %%
#df_diss.sort_values(by=['count'], ascending=False)
#df_diss.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22892/328217547.py in <module>
# ----> 1 df_diss.sort_values(by=['count'], ascending=False)
#       2 df_diss.head(10)
#
# NameError: name 'df_diss' is not defined

# %%
from PIL import Image
import numpy as np
from wordcloud import WordCloud   
import imageio

# %%
diss3 = imageio.imread('Python.png')

# %%
wordcloud = WordCloud(width=1000, height=1000, 
    colormap='prism', max_words = 100, mask=diss3, background_color='white')

# %%
from pathlib import Path
DissertationText = Path('Dissertation.txt').read_text()

# %%
#Disstext2 = [item for item in DissertationText if item[0] not in stopwords]
stopwords22 = ['Army Recruiting', 'Army']
#DT2 = [words for words in DissertationText if words not in stopwords22]
        
Diss_wordcloud = wordcloud.generate(DissertationText)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
plt.axis('off')
plt.imshow(Diss_wordcloud)

# %%
import pandas as pd

# %%
from textatistic import Textatistic
textatistic_first = Path('Paper2010.txt').read_text()
textatistic_diss = Path('Dissertation.txt').read_text()

readability_first = Textatistic(textatistic_first)
readability_diss = Textatistic(textatistic_diss)

# %precision 3
readability_first.dict()
readability_diss.dict()

first_df = pd.DataFrame([readability_first.dict()]) 
diss_df = pd.DataFrame([readability_diss.dict()]) 
print(first_df)
# Out:
#    char_count  word_count  sent_count  sybl_count  notdalechall_count  \
# 0        4576         969          89        1227                 168
#
#    polysyblword_count  flesch_score  fleschkincaid_score  gunningfog_score  \
# 0                  44     88.658968             3.597975          6.171362
#
#    smog_score  dalechall_score
# 0    7.145864         6.914112

# %%
diss_df['Title'] = 'Values'
diss_dfp = pd.pivot_table (diss_df, columns = 'Title')
diss_dfp
# Out:
# Title                       Values
# char_count           249937.000000
# dalechall_score          11.316059
# flesch_score             47.997148
# fleschkincaid_score       9.655958
# gunningfog_score         13.557365
# notdalechall_count    18266.000000
# polysyblword_count     8760.000000
# sent_count             3282.000000
# smog_score               12.462238
# sybl_count            70579.000000
# word_count            40839.000000

# %%
first_df['Title'] = 'Values'
first_dfp = pd.pivot_table (first_df, columns = 'Title')
diss_dfp['Values'] = diss_dfp['Values'].round(2)
first_dfp.head(13)
# Out:
# Title                     Values
# char_count           4576.000000
# dalechall_score         6.914112
# flesch_score           88.658968
# fleschkincaid_score     3.597975
# gunningfog_score        6.171362
# notdalechall_count    168.000000
# polysyblword_count     44.000000
# sent_count             89.000000
# smog_score              7.145864
# sybl_count           1227.000000
# word_count            969.000000

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center')

# %%
diss_dfp.plot.bar(color = 'blue', legend=False)
#diss_dfp.set_xticklabels(rotation=0)
plt.title('Dissertation Stats')
plt.gcf().tight_layout()

# %%
ax1 = first_dfp.plot.bar(color='blue', legend=True, title='First Paper (2010)')
ax2 = diss_dfp.plot.bar(color = 'blue', legend=False, title='Final Dissertation (2021)')


fig = first_dfp[1:5].plot(kind='bar')
fig.set_title('Amount Frequency')
fig.set_xlabel('Category')
fig.set_ylabel('Value')
#t
plt.title('2010 Paper Stats')
ax3 = plt.gcf().tight_layout()

fig = diss_dfp[1:5].plot(kind='bar')
fig.set_title('Amount Frequency')
fig.set_xlabel('Category')
fig.set_ylabel('Value')
plt.title('Dissertation Paper Stats')
ax4 = plt.gcf().tight_layout()

# %%
fig, ((first_dfp[1:5], diss_dfp[1:5]), (first_dfp, diss_dfp)) = plt.subplots(2, 2)
fig.suptitle('Sharing x per column, y per row')
ax1.plot()
ax2.plot( 'tab:orange')
ax3.plot('tab:green')
ax4.plot('tab:red')

for ax in fig.get_axes():
    ax.label_outer()

# %%
import tkinter as tk
from tkinter import filedialog
from tkinter.filedialog import askopenfile

# %%
from tkinter import *
from tkinter.ttk import *
from tkinter.filedialog import askopenfile 
import time

ws = Tk()
ws.title('PythonGuides')
ws.geometry('400x200') 


def open_file():
    file_path = askopenfile(mode='r', filetypes=[('Image Files', '*jpeg')])
    if file_path is not None:
        pass

def uploadFiles():
    pb1 = Progressbar(
        ws, 
        orient=HORIZONTAL, 
        length=300, 
        mode='determinate'
        )
    pb1.grid(row=4, columnspan=3, pady=20)
    for i in range(5):
        ws.update_idletasks()
        pb1['value'] += 20
        time.sleep(1)
    pb1.destroy()
    Label(ws, text='File Uploaded Successfully!', foreground='green').grid(row=4, columnspan=3, pady=10)
        
    
    
adhar = Label(
    ws, 
    text='Upload Government id in jpg format '
    )
adhar.grid(row=0, column=0, padx=10)
adharbtn = Button(
    ws, 
    text ='Choose File', 
    command = lambda:open_file()
    ) 
adharbtn.grid(row=0, column=1)

dl = Label(
    ws, 
    text='Upload Driving License in jpg format '
    )
dl.grid(row=1, column=0, padx=10)

dlbtn = Button(
    ws, 
    text ='Choose File ', 
    command = lambda:open_file()
    ) 
dlbtn.grid(row=1, column=1)

ms = Label(
    ws, 
    text='Upload Marksheet in jpg format '
    )
ms.grid(row=2, column=0, padx=10)

msbtn = Button(
    ws, 
    text ='Choose File', 
    command = lambda:open_file()
    ) 
msbtn.grid(row=2, column=1)

upld = Button(
    ws, 
    text='Upload Files', 
    command=uploadFiles
    )
upld.grid(row=3, columnspan=3, pady=10)



ws.mainloop()

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/Cbhami/Cosmo/master/df6.csv?token=GHSAT0AAAAAABSXJ2TQFZVRTNB5HVI335VCYR76Y4A'
df = pd.read_csv(url,index_col=0)

df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# c:\Users\coleb\OneDrive\Cosmo\Notebook_of_Notes.ipynb Cell 43' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/coleb/OneDrive/Cosmo/Notebook_of_Notes.ipynb#ch0000040?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/coleb/OneDrive/Cosmo/Notebook_of_Notes.ipynb#ch0000040?line=2'>3</a> url = 'https://raw.githubusercontent.com/Cbhami/Cosmo/master/df6.csv?token=GHSAT0AAAAAABSXJ2TQFZVRTNB5HVI335VCYR76Y4A'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/coleb/OneDrive/Cosmo/Notebook_of_Notes.ipynb#ch0000040?line=3'>4</a> df = pd.read_csv(url,index_col=0)
#       <a href='vscode-notebook-cell:/c%3A/Users/coleb/OneDrive/Cosmo/Notebook_of_Notes.ipynb#ch0000040?line=5'>6</a> df.head()
#
# File ~\mambaforge\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File ~\mambaforge\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=664'>665</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=665'>666</a>     dialect,
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=666'>667</a>     delimiter,
#    (...)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=675'>676</a>     defaults={"delimiter": ","},
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=676'>677</a> )
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=677'>678</a> kwds.update(kwds_defaults)
# --> <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=679'>680</a> return _read(filepath_or_buffer, kwds)
#
# File ~\mambaforge\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=571'>572</a> _validate_names(kwds.get("names", None))
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=573'>574</a> # Create the parser.
# --> <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=574'>575</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=576'>577</a> if chunksize or iterator:
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=577'>578</a>     return parser
#
# File ~\mambaforge\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=929'>930</a>     self.options["has_index_names"] = kwds["has_index_names"]
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=931'>932</a> self.handles: IOHandles | None = None
# --> <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=932'>933</a> self._engine = self._make_engine(f, self.engine)
#
# File ~\mambaforge\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=1212'>1213</a>     mode = "rb"
#    <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=1213'>1214</a> # error: No overload variant of "get_handle" matches argument types
#    <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=1214'>1215</a> # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=1215'>1216</a> # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=1216'>1217</a> self.handles = get_handle(  # type: ignore[call-overload]
#    <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=1217'>1218</a>     f,
#    <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=1218'>1219</a>     mode,
#    <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=1219'>1220</a>     encoding=self.options.get("encoding", None),
#    <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=1220'>1221</a>     compression=self.options.get("compression", None),
#    <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=1221'>1222</a>     memory_map=self.options.get("memory_map", False),
#    <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=1222'>1223</a>     is_text=is_text,
#    <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=1223'>1224</a>     errors=self.options.get("encoding_errors", "strict"),
#    <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=1224'>1225</a>     storage_options=self.options.get("storage_options", None),
#    <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=1225'>1226</a> )
#    <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=1226'>1227</a> assert self.handles is not None
#    <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/parsers/readers.py?line=1227'>1228</a> f = self.handles.handle
#
# File ~\mambaforge\lib\site-packages\pandas\io\common.py:670, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=666'>667</a>     codecs.lookup_error(errors)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=668'>669</a> # open URLs
# --> <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=669'>670</a> ioargs = _get_filepath_or_buffer(
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=670'>671</a>     path_or_buf,
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=671'>672</a>     encoding=encoding,
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=672'>673</a>     compression=compression,
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=673'>674</a>     mode=mode,
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=674'>675</a>     storage_options=storage_options,
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=675'>676</a> )
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=677'>678</a> handle = ioargs.filepath_or_buffer
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=678'>679</a> handles: list[BaseBuffer]
#
# File ~\mambaforge\lib\site-packages\pandas\io\common.py:339, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=336'>337</a> # assuming storage_options is to be interpreted as headers
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=337'>338</a> req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=338'>339</a> with urlopen(req_info) as req:
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=339'>340</a>     content_encoding = req.headers.get("Content-Encoding", None)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=340'>341</a>     if content_encoding == "gzip":
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=341'>342</a>         # Override compression based on Content-Encoding header
#
# File ~\mambaforge\lib\site-packages\pandas\io\common.py:239, in urlopen(*args, **kwargs)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=232'>233</a> """
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=233'>234</a> Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=234'>235</a> the stdlib.
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=235'>236</a> """
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=236'>237</a> import urllib.request
# --> <a href='file:///c%3A/Users/coleb/mambaforge/lib/site-packages/pandas/io/common.py?line=238'>239</a> return urllib.request.urlopen(*args, **kwargs)
#
# File ~\mambaforge\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=211'>212</a> else:
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=212'>213</a>     opener = _opener
# --> <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=213'>214</a> return opener.open(url, data, timeout)
#
# File ~\mambaforge\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=520'>521</a> for processor in self.process_response.get(protocol, []):
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=521'>522</a>     meth = getattr(processor, meth_name)
# --> <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=522'>523</a>     response = meth(req, response)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=524'>525</a> return response
#
# File ~\mambaforge\lib\urllib\request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=628'>629</a> # According to RFC 2616, "2xx" code indicates that the client's
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=629'>630</a> # request was successfully received, understood, and accepted.
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=630'>631</a> if not (200 <= code < 300):
# --> <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=631'>632</a>     response = self.parent.error(
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=632'>633</a>         'http', request, response, code, msg, hdrs)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=634'>635</a> return response
#
# File ~\mambaforge\lib\urllib\request.py:561, in OpenerDirector.error(self, proto, *args)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=558'>559</a> if http_err:
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=559'>560</a>     args = (dict, 'default', 'http_error_default') + orig_args
# --> <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=560'>561</a>     return self._call_chain(*args)
#
# File ~\mambaforge\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=491'>492</a> for handler in handlers:
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=492'>493</a>     func = getattr(handler, meth_name)
# --> <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=493'>494</a>     result = func(*args)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=494'>495</a>     if result is not None:
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=495'>496</a>         return result
#
# File ~\mambaforge\lib\urllib\request.py:641, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=639'>640</a> def http_error_default(self, req, fp, code, msg, hdrs):
# --> <a href='file:///c%3A/Users/coleb/mambaforge/lib/urllib/request.py?line=640'>641</a>     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found
