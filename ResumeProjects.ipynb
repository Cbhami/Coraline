# %%
import pandas as pd

# %%
df = pd.read_csv(r'https://raw.githubusercontent.com/Cbhami/Coraline/master/Resume%20Resources/Coursera%20Transcripts.csv', encoding = 'utf-8')

# %%
df.head(11)
# Out:
#     Unnamed: 0           Certificate Name  \
# 0            0      Google Data Analytics
# 1            5      Google Data Analytics
# 2            7      Google Data Analytics
# 3            8      Google Data Analytics
# 4            9      Google Data Analytics
# 5           13      Google Data Analytics
# 6           14      Google Data Analytics
# 7           15      Google Data Analytics
# 8           16  Google Project Management
# 9           17  Google Project Management
# 10          18  Google Project Management
#
#                                           Course Name Enrollment Date  \
# 0   Google Data Analytics Capstone: Complete a Cas...      12/28/2021
# 1                    Analyze Data to Answer Questions      12/26/2021
# 2         Share Data Through the Art of Visualization      11/28/2021
# 3                    Process Data from Dirty to Clean      11/15/2021
# 4                        Prepare Data for Exploration      11/14/2021
# ...

# %%
df['Grade Achieved'] = df['Grade Achieved'].astype(int)

# %%
df = df[df['Grade Achieved'] > 70]

# %%
df.head(11)
# Out:
#     Unnamed: 0           Certificate Name  \
# 0            0      Google Data Analytics
# 1            5      Google Data Analytics
# 2            7      Google Data Analytics
# 3            8      Google Data Analytics
# 4            9      Google Data Analytics
# 5           13      Google Data Analytics
# 6           14      Google Data Analytics
# 7           15      Google Data Analytics
# 8           16  Google Project Management
# 9           17  Google Project Management
# 10          18  Google Project Management
#
#                                           Course Name Enrollment Date  \
# 0   Google Data Analytics Capstone: Complete a Cas...      12/28/2021
# 1                    Analyze Data to Answer Questions      12/26/2021
# 2         Share Data Through the Art of Visualization      11/28/2021
# 3                    Process Data from Dirty to Clean      11/15/2021
# 4                        Prepare Data for Exploration      11/14/2021
# ...

# %%
df = df[['Certificate Name', 'Course Name', 'Enrollment Date', 'Grade Achieved']]

# %%
df.to_csv(r'C:\Users\coleb\OneDrive\Coraline\Resume Resources\Coursera Transcripts.csv', encoding = 'utf-8', index = False)
