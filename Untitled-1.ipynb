# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.12.2-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 366 kB/s eta 0:00:01
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.22-cp39-cp39-macosx_10_10_x86_64.whl (26.5 MB)
#      |████████████████████████████████| 26.5 MB 2.8 MB/s eta 0:00:01
# Collecting pyproj>=2.6.1.post1
#   Downloading pyproj-3.4.1-cp39-cp39-macosx_10_9_x86_64.whl (8.4 MB)
#      |████████████████████████████████| 8.4 MB 3.8 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=1.0.0 in /Users/cole/miniconda/lib/python3.9/site-packages (from geopandas) (1.4.4)
# Collecting shapely>=1.7
#   Downloading shapely-2.0.0-cp39-cp39-macosx_10_9_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 1.8 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/cole/miniconda/lib/python3.9/site-packages (from geopandas) (21.3)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: six>=1.7 in /Users/cole/miniconda/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: certifi in /Users/cole/miniconda/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2022.6.15)
# Requirement already satisfied: click>=4.0 in /Users/cole/miniconda/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (8.1.3)
# Collecting attrs>=17
#   Using cached attrs-22.1.0-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: setuptools in /Users/cole/miniconda/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (61.2.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/cole/miniconda/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (2022.2.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/cole/miniconda/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (1.23.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/cole/miniconda/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/cole/miniconda/lib/python3.9/site-packages (from packaging->geopandas) (3.0.9)
# Installing collected packages: munch, cligj, click-plugins, attrs, shapely, pyproj, fiona, geopandas
# Successfully installed attrs-22.1.0 click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.22 geopandas-0.12.2 munch-2.5.0 pyproj-3.4.1 shapely-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd

# %%
dataSource = gpd.datasets.get_path('naturalearth_lowres')

# %%
gdf = gpd.read_file(dataSource)

# %%
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
import random

print("Welcome to the dice rolling game!")

while True:
  # Prompt the user to roll the dice
  roll = input("Roll the dice? (y/n) ")
  
  if roll.lower() != "y":
    break
  
  # Roll the dice and print the result
  dice1 = random.randint(1, 6)
  dice2 = random.randint(1, 6)
  print(f"You rolled a {dice1} and a {dice2}.")

print("Thanks for playing!")
# Out:
# Welcome to the dice rolling game!
# You rolled a 4 and a 3.
# You rolled a 2 and a 5.
# You rolled a 3 and a 1.
# You rolled a 6 and a 2.
# Thanks for playing!
